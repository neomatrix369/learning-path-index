# %% [markdown]
# # Install required packages

# %%
# !pip install xlsxwriter -q
# !pip install keybert -q
# !pip install wordwise -q

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from pprint import pprint
import xlsxwriter
from keybert import KeyBERT
from wordwise import Extractor

# %% [markdown]
# # Load the Data

# %%
# url = "https://www.cloudskillsboost.google/course_templates/72?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&search_id=25346376"
# url = "https://www.cloudskillsboost.google/quests/132?catalog_rank=%7B%22rank%22%3A2%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&search_id=25346300"
url = "https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&search_id=25346338"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
ql_course = soup.find("ql-course")
modules = ql_course.attrs['modules']
print(type(modules))
print("\n\n")
print(modules)
# Out:
# <class 'str'>
#
#
#
# [{"id":"59338","title":"Introduction","description":"\u003cp\u003eIn this module, we introduce the course and agenda\u003c/p\u003e","steps":[{"id":"386567","prompt":null,"isOptional":true,"activities":[{"id":"379215","href":null,"isLocked":false,"duration":55000,"title":"Course Introduction","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59339","title":"Introduction to Building Batch Data Pipelines","description":"\u003cp\u003eThis module reviews different methods of data loading: EL, ELT and ETL and when to use what\u003c/p\u003e","steps":[{"id":"386568","prompt":null,"isOptional":true,"activities":[{"id":"379216","href":null,"isLocked":false,"duration":69000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386569","prompt":null,"isOptional":true,"activities":[{"id":"379217","href":null,"isLocked":false,"duration":220000,"title":"EL, ELT, ETL","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386570","prompt":null,"isOptional":true,"activities":[{"id":"379218","href":null,"isLocked":false,"duration":168000,"title":"Quality considerations","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386571","prompt":null,"isOptional":true,"activities":[{"id":"379219","href":null,"isLocked":false,"duration":180000,"title":"How to carry out operations in BigQuery","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386572","prompt":null,"isOptional":true,"activities":[{"id":"379220","href":null,"isLocked":false,"duration":208000,"title":"Shortcomings","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386573","prompt":null,"isOptional":true,"activities":[{"id":"379221","href":null,"isLocked":false,"duration":428000,"title":"ETL to solve data quality issues","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386574","prompt":null,"isOptional":false,"activities":[{"id":"379222","href":null,"isLocked":false,"duration":0,"title":"Introduction to Building Batch Data Pipelines","type":"quiz","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59340","title":"Executing Spark on Dataproc","description":"\u003cp\u003eThis module shows how to run Hadoop on Dataproc, how to leverage Cloud Storage, and how to optimize your Dataproc jobs.\u003c/p\u003e","steps":[{"id":"386575","prompt":null,"isOptional":true,"activities":[{"id":"379223","href":null,"isLocked":false,"duration":27000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386576","prompt":null,"isOptional":true,"activities":[{"id":"379224","href":null,"isLocked":false,"duration":286000,"title":"The Hadoop ecosystem","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386577","prompt":null,"isOptional":true,"activities":[{"id":"379225","href":null,"isLocked":false,"duration":602000,"title":"Running Hadoop on Dataproc","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386578","prompt":null,"isOptional":true,"activities":[{"id":"379226","href":null,"isLocked":false,"duration":379000,"title":"Cloud Storage instead of HDFS","type":"video","isComplete":false,"inProgress":false,"score":null}],"isComplete":false,"allActivitiesRequired":false},{"id":"386579","prompt":null,"isOptional":true,"activities":[{"id":"37922 ...

# %%
#convert to json
json_modules = json.loads(modules)
print(type(json_modules))
print("\n\n")
pprint(json_modules[0])
# Out:
# <class 'list'>
#
#
#
# {'description': '<p>In this module, we introduce the course and agenda</p>',
#  'expanded': False,
#  'id': '59338',
#  'steps': [{'activities': [{'duration': 55000,
#                             'href': None,
#                             'id': '379215',
#                             'inProgress': False,
#                             'isComplete': False,
#                             'isLocked': False,
#                             'score': None,
#                             'title': 'Course Introduction',
#                             'type': 'video'}],
#             'allActivitiesRequired': False,
#             'id': '386567',
#             'isComplete': False,
#             'isOptional': True,
#             'prompt': None}],
#  'title': 'Introduction'}

# %%
df = pd.DataFrame(json_modules)
df
# Out:
#       id                                              title  \
# 0  59338                                       Introduction
# 1  59339      Introduction to Building Batch Data Pipelines
# 2  59340                        Executing Spark on Dataproc
# 3  59341           Serverless Data Processing with Dataflow
# 4  59342  Manage Data Pipelines with Cloud Data Fusion a...
# 5  59343                                     Course Summary
# 6  59344                                   Course Resources
#
#                                          description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module shows how to run Hadoop on Data...
# 3  <p>This module covers using Dataflow to build ...
# 4  <p>This module shows how to manage data pipeli...
# 5                              <p>Course Summary</p>
# 6                    <p>PDF links to all modules</p>
#
#                                                steps  expanded
# 0  [{'id': '386567', 'prompt': None, 'isOptional'...     False
# 1  [{'id': '386568', 'prompt': None, 'isOptional'...     False
# 2  [{'id': '386575', 'prompt': None, 'isOptional'...     False
# 3  [{'id': '386587', 'prompt': None, 'isOptional'...     False
# 4  [{'id': '386604', 'prompt': None, 'isOptional'...     False
# 5  [{'id': '386620', 'prompt': None, 'isOptional'...     False
# 6  [{'id': '386621', 'prompt': None, 'isOptional'...     False

# %%
flatten_df = pd.json_normalize(json_modules, record_path=['steps', ['activities']], meta=['id','title', 'description'], meta_prefix='meta-', record_prefix='record-')
flatten_df.head(3)
# Out:
#   record-id record-href  record-isLocked  record-duration  \
# 0    379215        None            False            55000
# 1    379216        None            False            69000
# 2    379217        None            False           220000
#
#           record-title record-type  record-isComplete  record-inProgress  \
# 0  Course Introduction       video              False              False
# 1  Module introduction       video              False              False
# 2         EL, ELT, ETL       video              False              False
#
#   record-score meta-id                                     meta-title  \
# 0         None   59338                                   Introduction
# 1         None   59339  Introduction to Building Batch Data Pipelines
# 2         None   59339  Introduction to Building Batch Data Pipelines
#
#                                     meta-description
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...

# %%
flatten_df.drop(['record-href', 'record-isLocked', 'record-isComplete', 'record-inProgress','record-score','meta-id','record-id'], axis=1, inplace=True)

# %%
print(flatten_df.shape)
print("\n\n")
print(flatten_df.info())
# Out:
# (58, 5)
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   record-duration   58 non-null     int64
#  1   record-title      58 non-null     object
#  2   record-type       58 non-null     object
#  3   meta-title        58 non-null     object
#  4   meta-description  58 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.4+ KB
# None

# %% [markdown]
# # Aggregating and Grouping the Data

# %% [markdown]
# ## Using pd.groupby (approach 1)

# %%
# grouped_df = flatten_df.groupby(['meta-title', 'meta-description','record-title']) # 58
grouped_df = flatten_df.groupby(['meta-title', 'meta-description']) # 7
print(grouped_df.ngroups)
# print("\n\n")
# print(grouped_df.size())
# Out:
# 7

# %%
flatten_df['text'] = flatten_df.groupby(['meta-title', 'meta-description'])['record-title'].transform(lambda x:'. '.join(x))
flatten_df.head(10)
# Out:
#    record-duration                                   record-title record-type  \
# 0            55000                            Course Introduction       video
# 1            69000                            Module introduction       video
# 2           220000                                   EL, ELT, ETL       video
# 3           168000                         Quality considerations       video
# 4           180000        How to carry out operations in BigQuery       video
# 5           208000                                   Shortcomings       video
# 6           428000               ETL to solve data quality issues       video
# 7                0  Introduction to Building Batch Data Pipelines        quiz
# 8            27000                            Module introduction       video
# 9           286000                           The Hadoop ecosystem       video
#
#                                       meta-title  \
# 0                                   Introduction
# 1  Introduction to Building Batch Data Pipelines
# 2  Introduction to Building Batch Data Pipelines
# 3  Introduction to Building Batch Data Pipelines
# 4  Introduction to Building Batch Data Pipelines
# 5  Introduction to Building Batch Data Pipelines
# 6  Introduction to Building Batch Data Pipelines
# 7  Introduction to Building Batch Data Pipelines
# 8                    Executing Spark on Dataproc
# 9                    Executing Spark on Dataproc
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
# 5  <p>This module reviews different methods of da...
# 6  <p>This module reviews different methods of da...
# 7  <p>This module reviews different methods of da...
# 8  <p>This module shows how to run Hadoop on Data...
# 9  <p>This module shows how to run Hadoop on Data...
#
#                                                 text
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
# 5  Module introduction. EL, ELT, ETL. Quality con...
# 6  Module introduction. EL, ELT, ETL. Quality con...
# 7  Module introduction. EL, ELT, ETL. Quality con...
# 8  Module introduction. The Hadoop ecosystem. Run...
# 9  Module introduction. The Hadoop ecosystem. Run...

# %%
keywords_model = KeyBERT()

# %%
def get_keywords_keybert(text, model):
  keywords_arr = model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words=None)
  return [x[0] for x in keywords_arr]

# %%
# try wordwise (alternative to keyword extraction)
# def get_keywords_wordwise(text):
#   extractor = Extractor()
#   return extractor.generate(text)

# %%
flatten_df['keywords'] = flatten_df['text'].apply(lambda x: get_keywords_keybert(x, keywords_model))
flatten_df
# Out:
#     record-duration                                       record-title  \
# 0             55000                                Course Introduction
# 1             69000                                Module introduction
# 2            220000                                       EL, ELT, ETL
# 3            168000                             Quality considerations
# 4            180000            How to carry out operations in BigQuery
# 5            208000                                       Shortcomings
# 6            428000                   ETL to solve data quality issues
# 7                 0      Introduction to Building Batch Data Pipelines
# 8             27000                                Module introduction
# 9            286000                               The Hadoop ecosystem
# 10           602000                         Running Hadoop on Dataproc
# 11           379000                      Cloud Storage instead of HDFS
# 12           172000                                Optimizing Dataproc
# 13           567000                        Optimizing Dataproc storage
# 14           312000      Optimizing Dataproc templates and autoscaling
# 15           186000                     Optimizing Dataproc monitoring
# 16            28000   Lab Intro: Running Apache Spark jobs on Dataproc
# 17          5400000        Running Apache Spark jobs on Cloud Dataproc
# 18            34000                                            Summary
# 19                0                        Executing Spark on Dataproc
# 20            53000                                Module introduction
# 21           342000                           Introduction to Dataflow
# 22           171000                       Why customers value Dataflow
# 23           228000                Building Dataflow pipelines in code
# 24           127000        Key considerations with designing pipelines
# 25           188000                 Transforming data with PTransforms
# 26            10000     Lab Intro: Building a Simple Dataflow Pipeline
# 27          5400000            A Simple Dataflow Pipeline (Python) 2.5
# 28          5400000  Serverless Data Analysis with Dataflow: A Simp...
# 29           335000              Aggregate with GroupByKey and Combine
# 30            21000                       Lab Intro: MapReduce in Beam
# 31          5400000                     MapReduce in Beam (Python) 2.5
# 32          5400000  Serverless Data Analysis with Beam: MapReduce ...
# 33           283000                    Side inputs and windows of data
# 34            18000         Lab Intro: Practicing Pipeline Side Inputs
# 35          5400000  Serverless Data Analysis with Dataflow: Side I...
# 36          5400000  Serverless Data Analysis with Dataflow: Side I...
# 37           210000           Creating and re-using pipeline templates
# 38           126000                                            Summary
# 39                0           Serverless Data Processing with Dataflow
# 40            19000                                Module introduction
# 41           219000                  Introduction to Cloud Data Fusion
# 42            74000                    Components of Cloud Data Fusion
# 43            95000                               Cloud Data Fusion UI
# 44           291000                                   Build a pipeline
# 45           108000                        Explore data using wrangler
# 46            18000  Lab Intro: Building and executing a pipeline g...
# 47          9000000  Building and Executing a Pipeline Graph with D...
# 48            64000  Orchestrate work between Google Cloud services...
# 49            74000                         Apache Airflow environment
# 50           470000                                 DAGs and Operators
# 51           335000                                Workflow scheduling
# 52           208000                             Monitoring and Logging
# 53            22000       Lab Intro: An Introduction to Cloud Composer
# 54          5400000              An Introduction to Cloud Composer 2.5
# 55                0  Manage Data Pipelines with Cloud Data Fusion a...
# 56           197000                                     Course Summary
# 57                0      Building Batch Data Pipelines on Google Cloud
#
#    record-type                                         meta-title  \
# 0        video                                       Introduction
# 1        video      Introduction to Building Batch Data Pipelines
# 2        video      Introduction to Building Batch Data Pipelines
# 3        video      Introduction to Building Batch Data Pipelines
# 4        video      Introduction to Building Batch Data Pipelines
# 5        video      Introduction to Building Batch Data Pipelines
# 6        video      Introduction to Building Batch Data Pipelines
# 7         quiz      Introduction to Building Batch Data Pipelines
# 8        video                        Executing Spark on Dataproc
# 9        video                        Executing Spark on Dataproc
# 10       video                        Executing Spark on Dataproc
# 11       video                        Executing Spark on Dataproc
# 12       video                        Executing Spark on Dataproc
# 13       video                        Executing Spark on Dataproc
# 14       video                        Executing Spark on Dataproc
# 15       video                        Executing Spark on Dataproc
# 16       video                        Executing Spark on Dataproc
# 17         lab                        Executing Spark on Dataproc
# 18       video                        Executing Spark on Dataproc
# 19        quiz                        Executing Spark on Dataproc
# 20       video           Serverless Data Processing with Dataflow
# 21       video           Serverless Data Processing with Dataflow
# 22       video           Serverless Data Processing with Dataflow
# 23       video           Serverless Data Processing with Dataflow
# 24       video           Serverless Data Processing with Dataflow
# 25       video           Serverless Data Processing with Dataflow
# 26       video           Serverless Data Processing with Dataflow
# 27         lab           Serverless Data Processing with Dataflow
# 28         lab           Serverless Data Processing with Dataflow
# 29       video           Serverless Data Processing with Dataflow
# 30       video           Serverless Data Processing with Dataflow
# 31         lab           Serverless Data Processing with Dataflow
# 32         lab           Serverless Data Processing with Dataflow
# 33       video           Serverless Data Processing with Dataflow
# 34       video           Serverless Data Processing with Dataflow
# 35         lab           Serverless Data Processing with Dataflow
# 36         lab           Serverless Data Processing with Dataflow
# 37       video           Serverless Data Processing with Dataflow
# 38       video           Serverless Data Processing with Dataflow
# 39        quiz           Serverless Data Processing with Dataflow
# 40       video  Manage Data Pipelines with Cloud Data Fusion a...
# 41       video  Manage Data Pipelines with Cloud Data Fusion a...
# 42       video  Manage Data Pipelines with Cloud Data Fusion a...
# 43       video  Manage Data Pipelines with Cloud Data Fusion a...
# 44       video  Manage Data Pipelines with Cloud Data Fusion a...
# 45       video  Manage Data Pipelines with Cloud Data Fusion a...
# 46       video  Manage Data Pipelines with Cloud Data Fusion a...
# 47         lab  Manage Data Pipelines with Cloud Data Fusion a...
# 48       video  Manage Data Pipelines with Cloud Data Fusion a...
# 49       video  Manage Data Pipelines with Cloud Data Fusion a...
# 50       video  Manage Data Pipelines with Cloud Data Fusion a...
# 51       video  Manage Data Pipelines with Cloud Data Fusion a...
# 52       video  Manage Data Pipelines with Cloud Data Fusion a...
# 53       video  Manage Data Pipelines with Cloud Data Fusion a...
# 54         lab  Manage Data Pipelines with Cloud Data Fusion a...
# 55        quiz  Manage Data Pipelines with Cloud Data Fusion a...
# 56       video                                     Course Summary
# 57    document                                   Course Resources
#
#                                      meta-description  \
# 0   <p>In this module, we introduce the course and...
# 1   <p>This module reviews different methods of da...
# 2   <p>This module reviews different methods of da...
# 3   <p>This module reviews different methods of da...
# 4   <p>This module reviews different methods of da...
# 5   <p>This module reviews different methods of da...
# 6   <p>This module reviews different methods of da...
# 7   <p>This module reviews different methods of da...
# 8   <p>This module shows how to run Hadoop on Data...
# 9   <p>This module shows how to run Hadoop on Data...
# 10  <p>This module shows how to run Hadoop on Data...
# 11  <p>This module shows how to run Hadoop on Data...
# 12  <p>This module shows how to run Hadoop on Data...
# 13  <p>This module shows how to run Hadoop on Data...
# 14  <p>This module shows how to run Hadoop on Data...
# 15  <p>This module shows how to run Hadoop on Data...
# 16  <p>This module shows how to run Hadoop on Data...
# 17  <p>This module shows how to run Hadoop on Data...
# 18  <p>This module shows how to run Hadoop on Data...
# 19  <p>This module shows how to run Hadoop on Data...
# 20  <p>This module covers using Dataflow to build ...
# 21  <p>This module covers using Dataflow to build ...
# 22  <p>This module covers using Dataflow to build ...
# 23  <p>This module covers using Dataflow to build ...
# 24  <p>This module covers using Dataflow to build ...
# 25  <p>This module covers using Dataflow to build ...
# 26  <p>This module covers using Dataflow to build ...
# 27  <p>This module covers using Dataflow to build ...
# 28  <p>This module covers using Dataflow to build ...
# 29  <p>This module covers using Dataflow to build ...
# 30  <p>This module covers using Dataflow to build ...
# 31  <p>This module covers using Dataflow to build ...
# 32  <p>This module covers using Dataflow to build ...
# 33  <p>This module covers using Dataflow to build ...
# 34  <p>This module covers using Dataflow to build ...
# 35  <p>This module covers using Dataflow to build ...
# 36  <p>This module covers using Dataflow to build ...
# 37  <p>This module covers using Dataflow to build ...
# 38  <p>This module covers using Dataflow to build ...
# 39  <p>This module covers using Dataflow to build ...
# 40  <p>This module shows how to manage data pipeli...
# 41  <p>This module shows how to manage data pipeli...
# 42  <p>This module shows how to manage data pipeli...
# 43  <p>This module shows how to manage data pipeli...
# 44  <p>This module shows how to manage data pipeli...
# 45  <p>This module shows how to manage data pipeli...
# 46  <p>This module shows how to manage data pipeli...
# 47  <p>This module shows how to manage data pipeli...
# 48  <p>This module shows how to manage data pipeli...
# 49  <p>This module shows how to manage data pipeli...
# 50  <p>This module shows how to manage data pipeli...
# 51  <p>This module shows how to manage data pipeli...
# 52  <p>This module shows how to manage data pipeli...
# 53  <p>This module shows how to manage data pipeli...
# 54  <p>This module shows how to manage data pipeli...
# 55  <p>This module shows how to manage data pipeli...
# 56                              <p>Course Summary</p>
# 57                    <p>PDF links to all modules</p>
#
#                                                  text  \
# 0                                 Course Introduction
# 1   Module introduction. EL, ELT, ETL. Quality con...
# 2   Module introduction. EL, ELT, ETL. Quality con...
# 3   Module introduction. EL, ELT, ETL. Quality con...
# 4   Module introduction. EL, ELT, ETL. Quality con...
# 5   Module introduction. EL, ELT, ETL. Quality con...
# 6   Module introduction. EL, ELT, ETL. Quality con...
# 7   Module introduction. EL, ELT, ETL. Quality con...
# 8   Module introduction. The Hadoop ecosystem. Run...
# 9   Module introduction. The Hadoop ecosystem. Run...
# 10  Module introduction. The Hadoop ecosystem. Run...
# 11  Module introduction. The Hadoop ecosystem. Run...
# 12  Module introduction. The Hadoop ecosystem. Run...
# 13  Module introduction. The Hadoop ecosystem. Run...
# 14  Module introduction. The Hadoop ecosystem. Run...
# 15  Module introduction. The Hadoop ecosystem. Run...
# 16  Module introduction. The Hadoop ecosystem. Run...
# 17  Module introduction. The Hadoop ecosystem. Run...
# 18  Module introduction. The Hadoop ecosystem. Run...
# 19  Module introduction. The Hadoop ecosystem. Run...
# 20  Module introduction. Introduction to Dataflow....
# 21  Module introduction. Introduction to Dataflow....
# 22  Module introduction. Introduction to Dataflow....
# 23  Module introduction. Introduction to Dataflow....
# 24  Module introduction. Introduction to Dataflow....
# 25  Module introduction. Introduction to Dataflow....
# 26  Module introduction. Introduction to Dataflow....
# 27  Module introduction. Introduction to Dataflow....
# 28  Module introduction. Introduction to Dataflow....
# 29  Module introduction. Introduction to Dataflow....
# 30  Module introduction. Introduction to Dataflow....
# 31  Module introduction. Introduction to Dataflow....
# 32  Module introduction. Introduction to Dataflow....
# 33  Module introduction. Introduction to Dataflow....
# 34  Module introduction. Introduction to Dataflow....
# 35  Module introduction. Introduction to Dataflow....
# 36  Module introduction. Introduction to Dataflow....
# 37  Module introduction. Introduction to Dataflow....
# 38  Module introduction. Introduction to Dataflow....
# 39  Module introduction. Introduction to Dataflow....
# 40  Module introduction. Introduction to Cloud Dat...
# 41  Module introduction. Introduction to Cloud Dat...
# 42  Module introduction. Introduction to Cloud Dat...
# 43  Module introduction. Introduction to Cloud Dat...
# 44  Module introduction. Introduction to Cloud Dat...
# 45  Module introduction. Introduction to Cloud Dat...
# 46  Module introduction. Introduction to Cloud Dat...
# 47  Module introduction. Introduction to Cloud Dat...
# 48  Module introduction. Introduction to Cloud Dat...
# 49  Module introduction. Introduction to Cloud Dat...
# 50  Module introduction. Introduction to Cloud Dat...
# 51  Module introduction. Introduction to Cloud Dat...
# 52  Module introduction. Introduction to Cloud Dat...
# 53  Module introduction. Introduction to Cloud Dat...
# 54  Module introduction. Introduction to Cloud Dat...
# 55  Module introduction. Introduction to Cloud Dat...
# 56                                     Course Summary
# 57      Building Batch Data Pipelines on Google Cloud
#
#                                              keywords
# 0                              [introduction, course]
# 1             [bigquery, pipelines, batch, etl, data]
# 2             [bigquery, pipelines, batch, etl, data]
# 3             [bigquery, pipelines, batch, etl, data]
# 4             [bigquery, pipelines, batch, etl, data]
# 5             [bigquery, pipelines, batch, etl, data]
# 6             [bigquery, pipelines, batch, etl, data]
# 7             [bigquery, pipelines, batch, etl, data]
# 8              [hadoop, dataproc, hdfs, spark, cloud]
# 9              [hadoop, dataproc, hdfs, spark, cloud]
# 10             [hadoop, dataproc, hdfs, spark, cloud]
# 11             [hadoop, dataproc, hdfs, spark, cloud]
# 12             [hadoop, dataproc, hdfs, spark, cloud]
# 13             [hadoop, dataproc, hdfs, spark, cloud]
# 14             [hadoop, dataproc, hdfs, spark, cloud]
# 15             [hadoop, dataproc, hdfs, spark, cloud]
# 16             [hadoop, dataproc, hdfs, spark, cloud]
# 17             [hadoop, dataproc, hdfs, spark, cloud]
# 18             [hadoop, dataproc, hdfs, spark, cloud]
# 19             [hadoop, dataproc, hdfs, spark, cloud]
# 20  [dataflow, pipeline, pipelines, mapreduce, ser...
# 21  [dataflow, pipeline, pipelines, mapreduce, ser...
# 22  [dataflow, pipeline, pipelines, mapreduce, ser...
# 23  [dataflow, pipeline, pipelines, mapreduce, ser...
# 24  [dataflow, pipeline, pipelines, mapreduce, ser...
# 25  [dataflow, pipeline, pipelines, mapreduce, ser...
# 26  [dataflow, pipeline, pipelines, mapreduce, ser...
# 27  [dataflow, pipeline, pipelines, mapreduce, ser...
# 28  [dataflow, pipeline, pipelines, mapreduce, ser...
# 29  [dataflow, pipeline, pipelines, mapreduce, ser...
# 30  [dataflow, pipeline, pipelines, mapreduce, ser...
# 31  [dataflow, pipeline, pipelines, mapreduce, ser...
# 32  [dataflow, pipeline, pipelines, mapreduce, ser...
# 33  [dataflow, pipeline, pipelines, mapreduce, ser...
# 34  [dataflow, pipeline, pipelines, mapreduce, ser...
# 35  [dataflow, pipeline, pipelines, mapreduce, ser...
# 36  [dataflow, pipeline, pipelines, mapreduce, ser...
# 37  [dataflow, pipeline, pipelines, mapreduce, ser...
# 38  [dataflow, pipeline, pipelines, mapreduce, ser...
# 39  [dataflow, pipeline, pipelines, mapreduce, ser...
# 40     [pipeline, pipelines, fusion, cloud, workflow]
# 41     [pipeline, pipelines, fusion, cloud, workflow]
# 42     [pipeline, pipelines, fusion, cloud, workflow]
# 43     [pipeline, pipelines, fusion, cloud, workflow]
# 44     [pipeline, pipelines, fusion, cloud, workflow]
# 45     [pipeline, pipelines, fusion, cloud, workflow]
# 46     [pipeline, pipelines, fusion, cloud, workflow]
# 47     [pipeline, pipelines, fusion, cloud, workflow]
# 48     [pipeline, pipelines, fusion, cloud, workflow]
# 49     [pipeline, pipelines, fusion, cloud, workflow]
# 50     [pipeline, pipelines, fusion, cloud, workflow]
# 51     [pipeline, pipelines, fusion, cloud, workflow]
# 52     [pipeline, pipelines, fusion, cloud, workflow]
# 53     [pipeline, pipelines, fusion, cloud, workflow]
# 54     [pipeline, pipelines, fusion, cloud, workflow]
# 55     [pipeline, pipelines, fusion, cloud, workflow]
# 56                                  [summary, course]
# 57            [pipelines, batch, cloud, data, google]

# %% [markdown]
# ## Using set_index (approach 2)

# %%
index_df = flatten_df.set_index(['meta-title', 'meta-description','record-title'])

# %%
print(f'index names ----> {index_df.index.names}')
print('\n')
print(f'column names ----> {index_df.columns}')
# Out:
# index names ----> ['meta-title', 'meta-description', 'record-title']
#
#
# column names ----> Index(['record-duration', 'record-type', 'text', 'keywords'], dtype='object')

# %%
index_df.index.names = ['titles', 'description', 'activities']
index_df.rename(columns={'record-duration':'duration', 'record-type':'type'}, errors='raise')
# Out:
#                                                                                                                                                           duration  \
# titles                                             description                                        activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                    55000
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                    69000
#                                                                                                       EL, ELT, ETL                                          220000
#                                                                                                       Quality considerations                                168000
#                                                                                                       How to carry out operations in BigQuery               180000
#                                                                                                       Shortcomings                                          208000
#                                                                                                       ETL to solve data quality issues                      428000
#                                                                                                       Introduction to Building Batch Data Pipelines              0
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                    27000
#                                                                                                       The Hadoop ecosystem                                  286000
#                                                                                                       Running Hadoop on Dataproc                            602000
#                                                                                                       Cloud Storage instead of HDFS                         379000
#                                                                                                       Optimizing Dataproc                                   172000
#                                                                                                       Optimizing Dataproc storage                           567000
#                                                                                                       Optimizing Dataproc templates and autoscaling         312000
#                                                                                                       Optimizing Dataproc monitoring                        186000
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc       28000
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc          5400000
#                                                                                                       Summary                                                34000
#                                                                                                       Executing Spark on Dataproc                                0
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                    53000
#                                                                                                       Introduction to Dataflow                              342000
#                                                                                                       Why customers value Dataflow                          171000
#                                                                                                       Building Dataflow pipelines in code                   228000
#                                                                                                       Key considerations with designing pipelines           127000
#                                                                                                       Transforming data with PTransforms                    188000
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline         10000
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5              5400000
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...   5400000
#                                                                                                       Aggregate with GroupByKey and Combine                 335000
#                                                                                                       Lab Intro: MapReduce in Beam                           21000
#                                                                                                       MapReduce in Beam (Python) 2.5                       5400000
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...   5400000
#                                                                                                       Side inputs and windows of data                       283000
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs             18000
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...   5400000
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...   5400000
#                                                                                                       Creating and re-using pipeline templates              210000
#                                                                                                       Summary                                               126000
#                                                                                                       Serverless Data Processing with Dataflow                   0
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    19000
#                                                                                                       Introduction to Cloud Data Fusion                     219000
#                                                                                                       Components of Cloud Data Fusion                        74000
#                                                                                                       Cloud Data Fusion UI                                   95000
#                                                                                                       Build a pipeline                                      291000
#                                                                                                       Explore data using wrangler                           108000
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     18000
#                                                                                                       Building and Executing a Pipeline Graph with Da...   9000000
#                                                                                                       Orchestrate work between Google Cloud services ...     64000
#                                                                                                       Apache Airflow environment                             74000
#                                                                                                       DAGs and Operators                                    470000
#                                                                                                       Workflow scheduling                                   335000
#                                                                                                       Monitoring and Logging                                208000
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           22000
#                                                                                                       An Introduction to Cloud Composer 2.5                5400000
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...         0
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                        197000
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud              0
#
#                                                                                                                                                               type  \
# titles                                             description                                        activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                    video
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                    video
#                                                                                                       EL, ELT, ETL                                           video
#                                                                                                       Quality considerations                                 video
#                                                                                                       How to carry out operations in BigQuery                video
#                                                                                                       Shortcomings                                           video
#                                                                                                       ETL to solve data quality issues                       video
#                                                                                                       Introduction to Building Batch Data Pipelines           quiz
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                    video
#                                                                                                       The Hadoop ecosystem                                   video
#                                                                                                       Running Hadoop on Dataproc                             video
#                                                                                                       Cloud Storage instead of HDFS                          video
#                                                                                                       Optimizing Dataproc                                    video
#                                                                                                       Optimizing Dataproc storage                            video
#                                                                                                       Optimizing Dataproc templates and autoscaling          video
#                                                                                                       Optimizing Dataproc monitoring                         video
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc       video
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc              lab
#                                                                                                       Summary                                                video
#                                                                                                       Executing Spark on Dataproc                             quiz
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                    video
#                                                                                                       Introduction to Dataflow                               video
#                                                                                                       Why customers value Dataflow                           video
#                                                                                                       Building Dataflow pipelines in code                    video
#                                                                                                       Key considerations with designing pipelines            video
#                                                                                                       Transforming data with PTransforms                     video
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline         video
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5                  lab
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...       lab
#                                                                                                       Aggregate with GroupByKey and Combine                  video
#                                                                                                       Lab Intro: MapReduce in Beam                           video
#                                                                                                       MapReduce in Beam (Python) 2.5                           lab
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...       lab
#                                                                                                       Side inputs and windows of data                        video
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs             video
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...       lab
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...       lab
#                                                                                                       Creating and re-using pipeline templates               video
#                                                                                                       Summary                                                video
#                                                                                                       Serverless Data Processing with Dataflow                quiz
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    video
#                                                                                                       Introduction to Cloud Data Fusion                      video
#                                                                                                       Components of Cloud Data Fusion                        video
#                                                                                                       Cloud Data Fusion UI                                   video
#                                                                                                       Build a pipeline                                       video
#                                                                                                       Explore data using wrangler                            video
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     video
#                                                                                                       Building and Executing a Pipeline Graph with Da...       lab
#                                                                                                       Orchestrate work between Google Cloud services ...     video
#                                                                                                       Apache Airflow environment                             video
#                                                                                                       DAGs and Operators                                     video
#                                                                                                       Workflow scheduling                                    video
#                                                                                                       Monitoring and Logging                                 video
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           video
#                                                                                                       An Introduction to Cloud Composer 2.5                    lab
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...      quiz
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                         video
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud       document
#
#                                                                                                                                                                                                        text  \
# titles                                             description                                        activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                                               Course Introduction
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                 Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       EL, ELT, ETL                                        Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Quality considerations                              Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       How to carry out operations in BigQuery             Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Shortcomings                                        Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       ETL to solve data quality issues                    Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Introduction to Building Batch Data Pipelines       Module introduction. EL, ELT, ETL. Quality con...
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                 Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       The Hadoop ecosystem                                Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Running Hadoop on Dataproc                          Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Cloud Storage instead of HDFS                       Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc                                 Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc storage                         Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc templates and autoscaling       Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc monitoring                      Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc    Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc         Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Summary                                             Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Executing Spark on Dataproc                         Module introduction. The Hadoop ecosystem. Run...
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                 Module introduction. Introduction to Dataflow....
#                                                                                                       Introduction to Dataflow                            Module introduction. Introduction to Dataflow....
#                                                                                                       Why customers value Dataflow                        Module introduction. Introduction to Dataflow....
#                                                                                                       Building Dataflow pipelines in code                 Module introduction. Introduction to Dataflow....
#                                                                                                       Key considerations with designing pipelines         Module introduction. Introduction to Dataflow....
#                                                                                                       Transforming data with PTransforms                  Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline      Module introduction. Introduction to Dataflow....
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5             Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...  Module introduction. Introduction to Dataflow....
#                                                                                                       Aggregate with GroupByKey and Combine               Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: MapReduce in Beam                        Module introduction. Introduction to Dataflow....
#                                                                                                       MapReduce in Beam (Python) 2.5                      Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...  Module introduction. Introduction to Dataflow....
#                                                                                                       Side inputs and windows of data                     Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs          Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  Module introduction. Introduction to Dataflow....
#                                                                                                       Creating and re-using pipeline templates            Module introduction. Introduction to Dataflow....
#                                                                                                       Summary                                             Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Processing with Dataflow            Module introduction. Introduction to Dataflow....
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                 Module introduction. Introduction to Cloud Dat...
#                                                                                                       Introduction to Cloud Data Fusion                   Module introduction. Introduction to Cloud Dat...
#                                                                                                       Components of Cloud Data Fusion                     Module introduction. Introduction to Cloud Dat...
#                                                                                                       Cloud Data Fusion UI                                Module introduction. Introduction to Cloud Dat...
#                                                                                                       Build a pipeline                                    Module introduction. Introduction to Cloud Dat...
#                                                                                                       Explore data using wrangler                         Module introduction. Introduction to Cloud Dat...
#                                                                                                       Lab Intro: Building and executing a pipeline gr...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Building and Executing a Pipeline Graph with Da...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Orchestrate work between Google Cloud services ...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Apache Airflow environment                          Module introduction. Introduction to Cloud Dat...
#                                                                                                       DAGs and Operators                                  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Workflow scheduling                                 Module introduction. Introduction to Cloud Dat...
#                                                                                                       Monitoring and Logging                              Module introduction. Introduction to Cloud Dat...
#                                                                                                       Lab Intro: An Introduction to Cloud Composer        Module introduction. Introduction to Cloud Dat...
#                                                                                                       An Introduction to Cloud Composer 2.5               Module introduction. Introduction to Cloud Dat...
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...  Module introduction. Introduction to Cloud Dat...
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                                         Course Summary
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud           Building Batch Data Pipelines on Google Cloud
#
#                                                                                                                                                                                                    keywords
# titles                                             description                                        activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                                            [introduction, course]
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                           [bigquery, pipelines, batch, etl, data]
#                                                                                                       EL, ELT, ETL                                                  [bigquery, pipelines, batch, etl, data]
#                                                                                                       Quality considerations                                        [bigquery, pipelines, batch, etl, data]
#                                                                                                       How to carry out operations in BigQuery                       [bigquery, pipelines, batch, etl, data]
#                                                                                                       Shortcomings                                                  [bigquery, pipelines, batch, etl, data]
#                                                                                                       ETL to solve data quality issues                              [bigquery, pipelines, batch, etl, data]
#                                                                                                       Introduction to Building Batch Data Pipelines                 [bigquery, pipelines, batch, etl, data]
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                            [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       The Hadoop ecosystem                                           [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Running Hadoop on Dataproc                                     [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Cloud Storage instead of HDFS                                  [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Optimizing Dataproc                                            [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Optimizing Dataproc storage                                    [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Optimizing Dataproc templates and autoscaling                  [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Optimizing Dataproc monitoring                                 [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc               [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc                    [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Summary                                                        [hadoop, dataproc, hdfs, spark, cloud]
#                                                                                                       Executing Spark on Dataproc                                    [hadoop, dataproc, hdfs, spark, cloud]
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                 [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Introduction to Dataflow                            [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Why customers value Dataflow                        [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Building Dataflow pipelines in code                 [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Key considerations with designing pipelines         [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Transforming data with PTransforms                  [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline      [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5             [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...  [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Aggregate with GroupByKey and Combine               [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Lab Intro: MapReduce in Beam                        [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       MapReduce in Beam (Python) 2.5                      [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...  [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Side inputs and windows of data                     [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs          [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Creating and re-using pipeline templates            [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Summary                                             [dataflow, pipeline, pipelines, mapreduce, ser...
#                                                                                                       Serverless Data Processing with Dataflow            [dataflow, pipeline, pipelines, mapreduce, ser...
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Introduction to Cloud Data Fusion                      [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Components of Cloud Data Fusion                        [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Cloud Data Fusion UI                                   [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Build a pipeline                                       [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Explore data using wrangler                            [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Building and Executing a Pipeline Graph with Da...     [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Orchestrate work between Google Cloud services ...     [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Apache Airflow environment                             [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       DAGs and Operators                                     [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Workflow scheduling                                    [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Monitoring and Logging                                 [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       An Introduction to Cloud Composer 2.5                  [pipeline, pipelines, fusion, cloud, workflow]
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...     [pipeline, pipelines, fusion, cloud, workflow]
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                                      [summary, course]
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud                 [pipelines, batch, cloud, data, google]

# %% [markdown]
# # Save output to Excel workbook

# %%
with pd.ExcelWriter('demo_GCBS.xlsx', engine='xlsxwriter') as writer:
  # flatten_df.to_excel(writer, sheet_name="CLMG004")
  index_df.to_excel(writer, sheet_name="CLMG004")
