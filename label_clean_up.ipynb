# %%
import pandas as pd

# Load the data
materials = pd.read_csv('./data/Courses and Learning Material.csv')
lpi = pd.read_csv('./data/Leaning Pathway Index.csv')

# Display the first few rows of the dataset
materials.head()
# Out:
#   Tab name             Source               Course Level Duration  \
# 0  CLMML00  Google Developers                  Beginners  70 mins
# 1  CLMML01  Google Developers  Beginners to Intermediate      NaN
# 2  CLMML02  Google Developers  Beginners to Intermediate  45 mins
# 3  CLMML03  Google Developers  Beginners to Intermediate      NaN
# 4  CLMML04  Google Developers  Beginners to Intermediate      NaN
#
#      Prerequisites Prework                      Course / Learning material  \
# 0               No      No                Introduction to Machine Learning
# 1  Yes, a handful      Yes      Machine Learning Crash Course (Foundation)
# 2               No      No                    Problem Framing (ML related)
# 3               No      No  Data Preparation and Feature Engineering in ML
# 4              Yes      No                           Testing and Debugging
#
#                      Course / Learning material Link Type (Free or Paid)
# 0  https://developers.google.com/machine-learning...                Free
# 1  https://developers.google.com/machine-learning...                Free
# 2  https://developers.google.com/machine-learning...                Free
# 3  https://developers.google.com/machine-learning...                Free
# 4  https://developers.google.com/machine-learning...                Free

# %% [markdown]
# # Clean up Course Level

# %%
lpi["Course Level"].value_counts()
# Out:
# Course Level
# Intermediate to Advanced     899
# Beginner                     244
# Intermediate                  99
# Beginners to Intermediate     97
# Beginner to Intermediate      39
# Beginners                      4
# Name: count, dtype: int64

# %%
level_dict = {"Beginners":"Beginner","Beginners to Intermediate":"Beginner to Intermediate"}
lpi["Course Level"] = lpi["Course Level"].replace(level_dict)
lpi["Course Level"].value_counts()
# Out:
# Course Level
# Intermediate to Advanced    899
# Beginner                    248
# Beginner to Intermediate    136
# Intermediate                 99
# Name: count, dtype: int64

# %% [markdown]
# # Clean up keywords

# %% [markdown]
# ## Find out keywords that need to be corrected

# %%
keyword = lpi.copy()
keyword["Keywords / Tags / Skills / Interests / Categories"].value_counts()
# Out:
# Keywords / Tags / Skills / Interests / Categories
# Autoencoders, Model Initialization, Dropout Techniques, Attention Mechanisms, Super-resolution    67
# Machine Learning/Deployment/Cloud, Lab, AI, task,Qwik Start, Command Line, Challenge              24
# Machine learning/Cloud, ML Pipeline, TensorFlow, Pipeline, tfx                                    23
# ML system/Data distribution/System failure/ Data validation/Tensorflow                            20
# ML System/Training/Prediction/Keras                                                               19
#                                                                                                   ..
# data engineer, Big Data, Machine Learning, Google Cloud, storage                                   1
# data engineer, Big Data, Machine Learning, Google Cloud, lab, BigQuery                             1
# data engineer, Big Data, Machine Learning, Google Cloud, quiz                                      1
# data engineer, streaming data, Big data, Google Cloud, Machine Learning                            1
# data engineer, challenge, BigQuery, Batch Predicition                                              1
# Name: count, Length: 371, dtype: int64

# %%
# I will revert the col name in the end.
keyword.rename(columns={"Keywords / Tags / Skills / Interests / Categories":"Keywords"}, inplace=True)
keyword['Keywords'] = keyword['Keywords'].str.replace('/', ',')
keyword.head()
# Out:
#                    Course / Learning material             Source  \
# 0            Introduction to Machine Learning  Google Developers
# 1            Introduction to Machine Learning  Google Developers
# 2            Introduction to Machine Learning  Google Developers
# 3            Introduction to Machine Learning  Google Developers
# 4  Machine Learning Crash Course (Foundation)  Google Developers
#
#                Course Level Type (Free or Paid)  \
# 0                  Beginner                Free
# 1                  Beginner                Free
# 2                  Beginner                Free
# 3                  Beginner                Free
# 4  Beginner to Intermediate                Free
#
#                              Module Duration  \
# 0  Introduction to Machine Learning  20 mins
# 1          What is Machine Learning  20 mins
# 2               Supervised Learning  20 mins
# 3           Test your understanding  10 mins
# 4                Introduction to ML   3 mins
#
#   Module / Sub-module \nDifficulty level               Keywords  \
# 0                                   Easy       machine learning
# 1                                   Easy       machine learning
# 2                         Easy to Medium    supervised learning
# 3                                   Easy  machine learning test
# 4                                   Easy       machine learning
#
#                                                Links
# 0  https://developers.google.com/machine-learning...
# 1  https://developers.google.com/machine-learning...
# 2  https://developers.google.com/machine-learning...
# 3  https://developers.google.com/machine-learning...
# 4  https://developers.google.com/machine-learning...

# %%
# check if all '/' are gone
keyword.query("Keywords.str.contains('/', regex=False)").head(2)
# Out:
# Empty DataFrame
# Columns: [Course / Learning material, Source, Course Level, Type (Free or Paid), Module, Duration, Module / Sub-module
# Difficulty level, Keywords, Links]
# Index: []

# %%
# Split and explode the Keywords
keyword['Keywords'] = keyword['Keywords'].str.lower().str.split(',').apply(lambda x: [i.strip() for i in x])
keyword = keyword.explode('Keywords')

# %%
from nltk.stem import WordNetLemmatizer
import nltk
import numpy as np

# Download WordNet
nltk.download('wordnet')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Apply lemmatization
keyword['Keywords_lemmatized'] = keyword['Keywords'].apply(lambda x: lemmatizer.lemmatize(x))
keyword['Keywords_lemmatized'].replace("", np.nan, inplace=True)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/lorentzyeung/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# check if all space is gone
keyword[keyword['Keywords_lemmatized']==""]["Keywords_lemmatized"]
# Out:
# Series([], Name: Keywords_lemmatized, dtype: object)

# %%
cleaned_up = set(keyword.Keywords_lemmatized.unique())
before = set(keyword.Keywords.unique())
changed = before - cleaned_up
changed
# Out:
# {'',
#  'algorithms',
#  'bugs',
#  'categories',
#  'causes',
#  'classifications',
#  'components',
#  'crosses',
#  'dependencies',
#  'developers',
#  'epochs',
#  'ethics',
#  'examples',
#  'features',
#  'guidelines',
#  'inputs',
#  'keras',
#  'labels',
#  'logs',
#  'metrics',
#  'models',
#  'nodes',
#  'outliers',
#  'outputs',
#  'phases',
#  'pipelines',
#  'predictions',
#  'preferences',
#  'problems',
#  'qualities',
#  'queries',
#  'requirements',
#  'samples',
#  'sets',
#  'sinks',
#  'slices',
#  'sources',
#  'stars',
#  'statistics',
#  'steps',
#  'subsets',
#  'tables',
#  'technologies',
#  'tests',
#  'triggers',
#  'types',
#  'users',
#  'values',
#  'watermarks'}

# %%
# checking each key in the dict and how it should be changed
keyword[keyword['Keywords'].str.contains("llm's")][["Keywords", "Keywords_lemmatized"]]
# Out:
#     Keywords Keywords_lemmatized
# 746    llm's               llm's
# 747    llm's               llm's
# 748    llm's               llm's
# 749    llm's               llm's
# 750    llm's               llm's
# 751    llm's               llm's
# 752    llm's               llm's
# 753    llm's               llm's
# 754    llm's               llm's
# 755    llm's               llm's
# 756    llm's               llm's
# 757    llm's               llm's
# 758    llm's               llm's

# %%
# creating a dict to use in map function to clean up other keywords related columns
mapping_dict = {
 'artificial intelligence':'ai', # my preference
 'bigquery':'big query', # my preference
 'bigdata':'big data', # my preference
 'collaborative-filtering':'collaborative filtering', # my preference
 'cnns':'cnn', # my preference
 'content-based-filtering':'content based filtering', # my preference
 'convolutional neural networks (cnns)':'cnn', # my preference
 'databses':'database', # spelling
 'datatest':'datatset', # spelling
 'drop out':'dropout', # my preference
 'gaussain':'gaussian', # spelling
 'generalisation':'generalization', # my preference
 'inferencing':'inference', # my preference
 'intrepretation':'interpretation', # spelling
 'licence':'license', # spelling
 "llm's":'llm', # my preference
 'machine learning':'ml', # my preference
 'regrression':'regression', # my preference
 'monitoring':'monitor', # my preference
 'natural language processing (nlp)':'nlp', # my preference
 'natural language processing':'nlp', # my preference
 'pipleline':'pipeline', # my preference
 'rdds':'rdd', # my preference
 'systems':'system', # my preference
 'recurrent neural network':'rnn', # my preference
 'regularisation':'regularization', # my preference
 'regulisation':'regularization', # spelling
 'severless':'serverless', # spelling
 'explainations':'explanation', # spelling
 'ssampling':'sampling', # spelling
 'statis':'statistic', # spelling
 'stochastic gradient descent':'sgd', # my preference
 'super-resolution':'super resolution', # my preference
 'tensor flow':'tensorflow', # my preference
 'tune':'tunning', # my preference
 'vetex':'vertex', # spelling
 'visualisation':'visualization', # my preference




 'algorithms':'algorithm',
 'bugs':'bug',
 'categories':'category',
 'causes':'cause',
 'classifications':'classification',
 'components':"component",
 'crosses':'cross',
 'dependencies':'dependency',
 'developers':'developer',
 'epochs':'epoch',
 'ethics':'ethic',
 'examples':'example',
 'embeddings':'embedding', # lemmatization didn't handle
 'features':'feature',
 'guidelines':'guideline',
 'hyperparameter.':'hyperparameter', # spelling
 'hyperparameters':'hyperparameter', # lemmatization didn't handle
 'hyperparamters':'hyperparameter', # spelling
 'inputs':'input',
 'keras':'kera',
 'labels':'label',
 'logs':'log',
 'metrics':'metric',
 'models':'models',
 'networks':'network', # lemmatization didn't handle
 'nodes':'node',
 'outliers':'outliers',
 'outputs':'output',
 'phases':'phase',
 'pipelines':'pipeline',
 'predictions':'prediction',
 'predicition':'prediction', # spelling
 'preferences':'preference',
 'problems':'problem',
 'qualities':'quality',
 'queries':'query',
 'requirements':'requirement',
 'samples':'sample',
 'sets':'set', # be careful with this, there are partitioned datasets, querying datasets, subsets, datasets, sets
 'sinks':'sink',
 'slices':'slice',
 'sources':'source',
 'stars':'star',
 'statistics':'statistic',
 'steps':'step',
 'subsets':'subset',
 'tables':'table',
 'technologies':'technology',
 'tests':'test',
 'triggers':'trigger',
 'types':'types',
 'users':'user',
 'values':'value',
 'watermarks':'watermark'
 }

# %%
keyword.head(1)
# Out:
#          Course / Learning material             Source Course Level  \
# 0  Introduction to Machine Learning  Google Developers     Beginner
#
#   Type (Free or Paid)                            Module Duration  \
# 0                Free  Introduction to Machine Learning  20 mins
#
#   Module / Sub-module \nDifficulty level          Keywords  \
# 0                                   Easy  machine learning
#
#                                                Links Keywords_lemmatized
# 0  https://developers.google.com/machine-learning...    machine learning

# %%
# Apply the replacements
keyword["Keywords2"] = keyword.Keywords

for k, v in mapping_dict.items():
    keyword["Keywords2"] = keyword["Keywords2"].str.replace(k, v)

# Check the results
keyword[keyword['Keywords'].str.contains("machine learning|artificial intelligence")][["Keywords", "Keywords_lemmatized", "Keywords2"]]
# Out:
#                    Keywords    Keywords_lemmatized Keywords2
# 0          machine learning       machine learning        ml
# 1          machine learning       machine learning        ml
# 3     machine learning test  machine learning test   ml test
# 4          machine learning       machine learning        ml
# 7          machine learning       machine learning        ml
# ...                     ...                    ...       ...
# 1377       machine learning       machine learning        ml
# 1378       machine learning       machine learning        ml
# 1379       machine learning       machine learning        ml
# 1380       machine learning       machine learning        ml
# 1381       machine learning       machine learning        ml
#
# [473 rows x 3 columns]

# %%
keyword.head(1)
# Out:
#          Course / Learning material             Source Course Level  \
# 0  Introduction to Machine Learning  Google Developers     Beginner
#
#   Type (Free or Paid)                            Module Duration  \
# 0                Free  Introduction to Machine Learning  20 mins
#
#   Module / Sub-module \nDifficulty level          Keywords  \
# 0                                   Easy  machine learning
#
#                                                Links Keywords_lemmatized  \
# 0  https://developers.google.com/machine-learning...    machine learning
#
#   Keywords2
# 0        ml

# %%
keyword.Keywords2.unique()
# Out:
# array(['ml', 'supervised learning', 'ml test', 'problem statement',
#        'ml terminologies', 'linear regression', 'training', 'loss',
#        'reducing loss', 'iterative approach', 'gradient descent',
#        'learning rate', 'optimising', 'stochastic', 'practical',
#        'tensorflow', 'toolkit', 'generalization', 'overfitting', 'test',
#        'dataset', 'splitting', 'data', 'validation set', 'partition',
#        'representation', 'feature engineering', 'quality', 'good feature',
#        'cleaning', 'feature', 'cross', 'encoding', 'nonlinearity',
#        'one-hot vectors', 'regularization', 'simplicity', 'l2', 'lambda',
#        'logistic regression', 'probability', 'classification',
#        'threshold', 'confusion matrix', 'accuracy', 'precision', 'recall',
#        'roc', 'roc curve', 'auc', 'prediction', 'bias', 'sparcity', 'l1',
#        'neural network', 'softmax', 'embedding',
#        'collaborative filtering', 'categorical data',
#        'low dimensional space', 'production', 'ml system', 'statistic',
#        'dynamic', 'inference', 'dependency', 'fairness', 'types',
#        'identifying', 'evualting', 'real world', 'cancer', 'literature',
#        'guideline', 'glossary', 'ml problem', 'sample', 'solution',
#        'machine', 'label', 'problem', 'framing', 'approach', 'step',
#        'user', 'model', 'regression', 'metric', 'proxy', 'outcome',
#        'models', 'alert', 'server', 'license', 'content', 'code',
#        'preference', 'oracle', 'developer', 'advance ml',
#        'decision trees', 'decision forests', 'hyperparameter',
#        'uplift modeling', 'preprocessing', 'imputation', 'random forest',
#        'split', 'node', 'binary', 'non-binary', 'axis aligned',
#        'oblique condition', 'information gain', 'gini', 'shannon entropy',
#        'binary classification', 'pruning', 'variiable importance',
#        'feature importance', 'variable importance', 'ensemble', 'bagging',
#        'bootstrap', 'attribute sampling', 'out-of-bag evaluation',
#        'obb evaluation', 'tf-df', 'interpretation', 'shap',
#        'shapley additive explanation', 'gradient boosting', 'shrinkage',
#        "newton's method", 'early stopping', 'recommendation system',
#        'deep neural network', 'deep learning', 'query', 'item',
#        'candidate generation', 'scoring', 're-ranking',
#        'matrix factorization', 'content based filtering',
#        'euclidean distance', 'svd', 'single value decomposition', 'sgd',
#        'weighted alternating least sqaures', 'wals', 'softmax model',
#        'retrieval', 'clustering', 'k-means', 'unsupervised ml',
#        'segmentation', 'centroid based', 'density based',
#        'distribution based', 'hierarchichal clustering',
#        'gaussian distribution', 'normalization', 'quantile', 'centroid',
#        'magnitude', 'cardinality', 'spectral clustering', 'gan',
#        'generative ai', 'generator', 'discriminator', 'generative model',
#        'discriminative model', 'backpropagation', 'alternating training',
#        'convergence', 'minimax loss', 'wasserstein loss', 'critic loss',
#        'vanishing gradients', 'mode collapse', 'progressive gan',
#        'conditional gan', 'image to image translation', 'cyclegan',
#        'text to image synthesis', 'super resolution', 'face inpainting',
#        'text to speech', 'image classification',
#        'convulutional neural network', 'cnn', 'convulutional filter',
#        'pooling', 'stride', 'relu', 'data augmentation',
#        'dropout regularization', 'feature extraction', 'fine tuning',
#        'ai', 'what-if', 'fairness tools', 'fairness indicators',
#        'ai ethic', 'responsible ai', 'nlp', 'data ethic',
#        'model deployment', 'neural network fundamentals',
#        'convolutional neural network (cnn)', 'clustering algorithm',
#        'autoencoders', 'model initialization', 'dropout techniques',
#        'attention mechanisms', 'research papers', 'computer vision',
#        'bonus content', 'matrix operations', 'data science ethic.',
#        'image generation', 'text generation', 'ethic', 'transparency',
#        'ai principles', 'business case', 'responsible innovation',
#        'ethic concerns', 'review process', 'best practices',
#        'generative adversarial network', 'image synthesis',
#        'attention mechanism', 'transformer architecture',
#        'attention scores', 'attention weights', 'encode-decoder',
#        'sequence-to-sequence', 'tranformer model', 'bert',
#        'birectional encoder representations from transformer',
#        'pre-trained model', 'self attention', 'image captioning', 'rnn',
#        'natural language generation', 'nlg', 'generative ai studio',
#        'vertex ai', 'prompt design', 'palm', 'cloud', 'dataflow',
#        'serverless', 'data processing', 'data pipeline', 'beam',
#        'refresher', 'runner v2', 'cross language transform', 'streaming',
#        'shuffle', 'scheduling', 'storage', 'permission', 'iam', 'quota',
#        'pipeline', 'dofn', 'watermark', 'processing', 'trigger', 'source',
#        'sink', 'bigtable', 'schema', 'state', 'timer', 'api',
#        'error handling', 'pipeline optimizaion', 'sql', 'dataframes',
#        'notebook', 'google cloud', 'google console',
#        'google cloud project', 'apis', 'training data', 'big query ml',
#        'batch prediction', 'deployment', 'lab', 'task', 'qwik start',
#        'command line', 'challenge', 'data engineer', 'big query',
#        'cloud storage', 'partitioned dataset', 'querying dataset',
#        'data join', 'json', 'data structures', 'data warehouses',
#        'data preparation', 'data wrangling', 'data cleaning', 'data lake',
#        'etl pipeline', 'algorithm', 'correlation', 'sampling',
#        'causation', 'feature representation', 'log', 'latency', 'weight',
#        'imbalance', 'majority', 'minority', 'set', 'testing',
#        'validation', 'evaluation', 'generation', 'tail', 'example',
#        'transformation', 'computation', 'category', 'index', 'value',
#        'hashing', 'scaling', 'outliers', 'modeling', 'workflow',
#        'debugging', 'learning', 'cause', 'optimization', 'input', 'valus',
#        'distribution', 'check', 'monitor', 'layer', 'bug', 'baseline',
#        'batch', 'epoch', 'cost', 'rate', 'increase', 'fix', 'curve',
#        'error', 'slice', 'mean', 'subset', 'predictor', 'unicorn', 'star',
#        'mode', 'width', 'tuning', 'depth', 'tunning', 'component',
#        'datatset', 'integration', 'software', 'output', 'behavior',
#        'java', 'big data', 'compute', 'quiz', 'streaming data',
#        'architecture', 'apache beam', 'cloud dataflow', 'visualization',
#        'looker', 'data studio', 'analytics', 'demo', 'san francisco',
#        'bike share', 'predict', 'customer', 'phase', 'predicting',
#        'visitor purchases', 'pre-built apis', 'automl', 'custom training',
#        'ai solutions', 'model training', 'model evaluation', 'loan risk',
#        'data representations', 'and processing infrastructure',
#        'cloud engineer', 'cloud data cluster', 'requirement',
#        'encryption', 'strategy', 'bookmarking', 'sample questions',
#        'certification exam', 'technology', 'product', 'documentation',
#        'specialization', 'data engineering', 'designing data', 'database',
#        'serialization', 'rdd', 'tensor', 'hadoop', 'touchstone', "vm's",
#        'basic concepts', '', 'cloud dataproc', 'spark', 'framework',
#        'cloud pub', 'sub', 'cloud spanner', 'pub', 'infrastructure',
#        'table', 'cloud sql', 'cloud bigtable', 'mysql', 'nosql',
#        'windowing', 'cloud query', 'dataproc', 'apache airflow',
#        'cloud composer', 'and big query', 'analyzing', 'pre-trained',
#        'analysis', 'mse', 'rmse', 'validaion', 'underfitting',
#        'sentiment analysis', 'natural language', 'supervised',
#        'unsupervised learning', 'gcp', 'performance', 'denormalized',
#        'efficiency', 'select', 'limit', 'partitioning', 'groupbykey',
#        'combinebykey', 'timestamp', 'time series', 'query validator',
#        'pricing calculator', 'cloud analytics', 'analyst3', 'stackdriver',
#        'security', 'realibility', 'availability', 'failover',
#        'data security', 'dataprep', 'disaster recovery', 'graded',
#        'ungraded', 'storage cloud', 'console', 'development', 'mlops',
#        'llm', 'eda', 'regression models', 'explanable ai', 'ml models',
#        'hyperparameter tuning', 'loss function', 'kera', 'kera api',
#        'dnn', 'subclassing', 'statistictics', 'feature cross',
#        'transform', 'enterprise', 'vertex', 'model monitor',
#        'ai pipeline', 'ml development', 'data distribution',
#        'system failure', 'data validation', 'kubeflow', 'vision api',
#        'cv', 'image data', 'transfer learning', 'dialogflow api',
#        'text classification', 'text representation', 'tokeization',
#        'encoder', 'word2vec', 'tl', 'nlp models', 'transformer',
#        'content-based filtering', 'user focused', 'factorization',
#        'reinforcement learning', 'operation', 'ml lifecycle',
#        'feature store', 'ml pipeline', 'tfx', 'meta data', 'sdk',
#        'ml flow', 'model registry', 'tracking'], dtype=object)

# %%
keyword.rename(columns={"Keywords":"Keywords / Tags / Skills / Interests / Categories"}, inplace=True)

# %%
keyword.head()
# Out:
#                    Course / Learning material             Source  \
# 0            Introduction to Machine Learning  Google Developers
# 1            Introduction to Machine Learning  Google Developers
# 2            Introduction to Machine Learning  Google Developers
# 3            Introduction to Machine Learning  Google Developers
# 4  Machine Learning Crash Course (Foundation)  Google Developers
#
#                Course Level Type (Free or Paid)  \
# 0                  Beginner                Free
# 1                  Beginner                Free
# 2                  Beginner                Free
# 3                  Beginner                Free
# 4  Beginner to Intermediate                Free
#
#                              Module Duration  \
# 0  Introduction to Machine Learning  20 mins
# 1          What is Machine Learning  20 mins
# 2               Supervised Learning  20 mins
# 3           Test your understanding  10 mins
# 4                Introduction to ML   3 mins
#
#   Module / Sub-module \nDifficulty level  \
# 0                                   Easy
# 1                                   Easy
# 2                         Easy to Medium
# 3                                   Easy
# 4                                   Easy
#
#   Keywords / Tags / Skills / Interests / Categories  \
# 0                                  machine learning
# 1                                  machine learning
# 2                               supervised learning
# 3                             machine learning test
# 4                                  machine learning
#
#                                                Links    Keywords_lemmatized  \
# 0  https://developers.google.com/machine-learning...       machine learning
# 1  https://developers.google.com/machine-learning...       machine learning
# 2  https://developers.google.com/machine-learning...    supervised learning
# 3  https://developers.google.com/machine-learning...  machine learning test
# 4  https://developers.google.com/machine-learning...       machine learning
#
#              Keywords2
# 0                   ml
# 1                   ml
# 2  supervised learning
# 3              ml test
# 4                   ml

# %% [markdown]
# ## Execute on the original dataframe

# %%
lpi2 = lpi.copy()

# %%
# I will revert the col name in the end.
lpi2.rename(columns={"Keywords / Tags / Skills / Interests / Categories":"Keywords"}, inplace=True)
lpi2['Keywords'] = lpi2['Keywords'].str.replace('/', ',')
lpi2.tail(5)
# Out:
#                    Course / Learning material                    Source  \
# 1377  Machine Learning Engineer Learning Path  Google Cloud Skill Boost
# 1378  Machine Learning Engineer Learning Path  Google Cloud Skill Boost
# 1379  Machine Learning Engineer Learning Path  Google Cloud Skill Boost
# 1380  Machine Learning Engineer Learning Path  Google Cloud Skill Boost
# 1381  Machine Learning Engineer Learning Path  Google Cloud Skill Boost
#
#                   Course Level            Type (Free or Paid)  \
# 1377  Intermediate to Advanced  Free during mentorship period
# 1378  Intermediate to Advanced  Free during mentorship period
# 1379  Intermediate to Advanced  Free during mentorship period
# 1380  Intermediate to Advanced  Free during mentorship period
# 1381  Intermediate to Advanced  Free during mentorship period
#
#                                                  Module     Duration  \
# 1377  Build and Deploy Machine Learning Solutions on...  90 miniutes
# 1378  Build and Deploy Machine Learning Solutions on...   90 minutes
# 1379  Build and Deploy Machine Learning Solutions on...   90 minutes
# 1380  Build and Deploy Machine Learning Solutions on...   90 minutes
# 1381  Build and Deploy Machine Learning Solutions on...  120 minutes
#
#      Module / Sub-module \nDifficulty level  \
# 1377                         Medium to Hard
# 1378                         Medium to Hard
# 1379                         Medium to Hard
# 1380                         Medium to Hard
# 1381                         Medium to Hard
#
#                                                Keywords  \
# 1377  Machine Learning,Deployment,Cloud, Vertex AI, ...
# 1378  Machine Learning,Deployment,Cloud, Vertex AI, ...
# 1379  Machine Learning,Deployment,Cloud, Vertex AI, ...
# 1380  Machine Learning,Deployment,Cloud, Vertex AI, ...
# 1381  Machine Learning,Deployment,Cloud, Vertex AI, ...
#
#                                                   Links
# 1377  https://www.cloudskillsboost.google/course_ses...
# 1378  https://www.cloudskillsboost.google/course_ses...
# 1379  https://www.cloudskillsboost.google/course_ses...
# 1380  https://www.cloudskillsboost.google/course_ses...
# 1381                                 Link Not Available

# %%
# Apply the replacements
lpi2["Keywords2"] = lpi2["Keywords"]

for k, v in mapping_dict.items():
    lpi2["Keywords2"] = lpi2["Keywords2"].str.replace(k, v)

# Check the results
lpi2[lpi2['Keywords'].str.contains("machine learning|artificial intelligence")][["Keywords", "Keywords2"]]
# Out:
#                                               Keywords  \
# 0                                     machine learning
# 1                                     machine learning
# 3                                machine learning test
# 4                                     machine learning
# 7                                     machine learning
# 8                 machine learning, linear regrression
# 9                     machine learning, training, loss
# 85                          glossary, machine learning
# 539             data, samples, label, machine learning
# 550  data, label, split, training, testing, validat...
# 644  data engineering, pipeline, designing data, re...
# 667   data, SQL, analysis, machine learning, algorithm
# 668  data, machine learning, bigquery, dataflow, te...
# 669  data engineer, machine learning, model, MSE, R...
#
#                                              Keywords2
# 0                                                   ml
# 1                                                   ml
# 3                                              ml test
# 4                                                   ml
# 7                                                   ml
# 8                                ml, linear regression
# 9                                   ml, training, loss
# 85                                        glossary, ml
# 539                            data, sample, label, ml
# 550  data, label, split, training, testing, validat...
# 644  data engineering, pipeline, designing data, re...
# 667                 data, SQL, analysis, ml, algorithm
# 668  data, ml, big query, dataflow, tensorflow, Clo...
# 669  data engineer, ml, model, MSE, RMSE, gradient ...

# %%
lpi2.drop(columns="Keywords", axis=1, inplace=True)
lpi2.rename(columns={"Keywords2" : "Keywords / Tags / Skills / Interests / Categories"}, inplace=True)
lpi = lpi2.copy()

# %%
lpi[lpi["Keywords / Tags / Skills / Interests / Categories"].str.contains("ml|set")]
# Out:
#                             Course / Learning material  \
# 0                     Introduction to Machine Learning
# 1                     Introduction to Machine Learning
# 3                     Introduction to Machine Learning
# 4           Machine Learning Crash Course (Foundation)
# 6           Machine Learning Crash Course (Foundation)
# 7           Machine Learning Crash Course (Foundation)
# 8           Machine Learning Crash Course (Foundation)
# 9           Machine Learning Crash Course (Foundation)
# 21          Machine Learning Crash Course (Foundation)
# 22          Machine Learning Crash Course (Foundation)
# 23          Machine Learning Crash Course (Foundation)
# 24          Machine Learning Crash Course (Foundation)
# 25          Machine Learning Crash Course (Foundation)
# 26          Machine Learning Crash Course (Foundation)
# 73          Machine Learning Crash Course (Foundation)
# 82          Machine Learning Crash Course (Foundation)
# 83          Machine Learning Crash Course (Foundation)
# 84          Machine Learning Crash Course (Foundation)
# 85          Machine Learning Crash Course (Foundation)
# 88                        Problem Framing (ML related)
# 90                        Problem Framing (ML related)
# 526  Data Engineer - Quest: Build and Optimize Data...
# 539     Data Preparation and Feature Engineering in ML
# 549     Data Preparation and Feature Engineering in ML
# 550     Data Preparation and Feature Engineering in ML
# 551     Data Preparation and Feature Engineering in ML
# 557     Data Preparation and Feature Engineering in ML
# 558     Data Preparation and Feature Engineering in ML
# 559     Data Preparation and Feature Engineering in ML
# 560                              Testing and Debugging
# 561                              Testing and Debugging
# 567                              Testing and Debugging
# 571                              Testing and Debugging
# 572                              Testing and Debugging
# 574                              Testing and Debugging
# 644  Data Engineer - Preparing for the Google Cloud...
# 652  Data Engineer - Preparing for the Google Cloud...
# 663  Data Engineer - Preparing for the Google Cloud...
# 664  Data Engineer - Preparing for the Google Cloud...
# 667  Data Engineer - Preparing for the Google Cloud...
# 668  Data Engineer - Preparing for the Google Cloud...
# 669  Data Engineer - Preparing for the Google Cloud...
# 679  Data Engineer - Preparing for the Google Cloud...
#
#                        Source              Course Level  \
# 0           Google Developers                  Beginner
# 1           Google Developers                  Beginner
# 3           Google Developers                  Beginner
# 4           Google Developers  Beginner to Intermediate
# 6           Google Developers  Beginner to Intermediate
# 7           Google Developers  Beginner to Intermediate
# 8           Google Developers  Beginner to Intermediate
# 9           Google Developers  Beginner to Intermediate
# 21          Google Developers  Beginner to Intermediate
# 22          Google Developers  Beginner to Intermediate
# 23          Google Developers  Beginner to Intermediate
# 24          Google Developers  Beginner to Intermediate
# 25          Google Developers  Beginner to Intermediate
# 26          Google Developers  Beginner to Intermediate
# 73          Google Developers  Beginner to Intermediate
# 82          Google Developers  Beginner to Intermediate
# 83          Google Developers  Beginner to Intermediate
# 84          Google Developers  Beginner to Intermediate
# 85          Google Developers  Beginner to Intermediate
# 88          Google Developers  Beginner to Intermediate
# 90          Google Developers  Beginner to Intermediate
# 526  Google Cloud Skill Boost                  Beginner
# 539         Google Developers  Beginner to Intermediate
# 549         Google Developers  Beginner to Intermediate
# 550         Google Developers  Beginner to Intermediate
# 551         Google Developers  Beginner to Intermediate
# 557         Google Developers  Beginner to Intermediate
# 558         Google Developers  Beginner to Intermediate
# 559         Google Developers  Beginner to Intermediate
# 560         Google Developers  Beginner to Intermediate
# 561         Google Developers  Beginner to Intermediate
# 567         Google Developers  Beginner to Intermediate
# 571         Google Developers  Beginner to Intermediate
# 572         Google Developers  Beginner to Intermediate
# 574         Google Developers  Beginner to Intermediate
# 644  Google Cloud Skill Boost                  Beginner
# 652  Google Cloud Skill Boost                  Beginner
# 663  Google Cloud Skill Boost                  Beginner
# 664  Google Cloud Skill Boost                  Beginner
# 667  Google Cloud Skill Boost                  Beginner
# 668  Google Cloud Skill Boost                  Beginner
# 669  Google Cloud Skill Boost                  Beginner
# 679  Google Cloud Skill Boost                  Beginner
#
#                Type (Free or Paid)  \
# 0                             Free
# 1                             Free
# 3                             Free
# 4                             Free
# 6                             Free
# 7                             Free
# 8                             Free
# 9                             Free
# 21                            Free
# 22                            Free
# 23                            Free
# 24                            Free
# 25                            Free
# 26                            Free
# 73                            Free
# 82                            Free
# 83                            Free
# 84                            Free
# 85                            Free
# 88                            Free
# 90                            Free
# 526  Free during mentorship period
# 539                           Free
# 549                           Free
# 550                           Free
# 551                           Free
# 557                           Free
# 558                           Free
# 559                           Free
# 560                           Free
# 561                           Free
# 567                           Free
# 571                           Free
# 572                           Free
# 574                           Free
# 644  Free during mentorship period
# 652  Free during mentorship period
# 663  Free during mentorship period
# 664  Free during mentorship period
# 667  Free during mentorship period
# 668  Free during mentorship period
# 669  Free during mentorship period
# 679  Free during mentorship period
#
#                                                 Module    Duration  \
# 0                     Introduction to Machine Learning     20 mins
# 1                             What is Machine Learning     20 mins
# 3                              Test your understanding     10 mins
# 4                                   Introduction to ML      3 mins
# 6                         Framing - Key ML Terminology     15 mins
# 7                   Descending into ML - Video Lecture         NaN
# 8               Descending into ML - Linear Regression         NaN
# 9               Descending into ML - Training and Loss         NaN
# 21              Training and Test Sets - Video Lecture         NaN
# 22             Training and Test Sets - Splitting Data         NaN
# 23        Training and Test Sets - Playground Exercise         NaN
# 24                      Validation Set - Video lecture     65 mins
# 25                  Validation Set - Another Partition         NaN
# 26                Validation Set - Playground Exercise         NaN
# 73                               Production ML Systems      3 mins
# 82    Cancer Prediction - ML Systems in the Real World      5 mins
# 83           Literature - ML Systems in the Real World      5 mins
# 84           Guidelines - ML Systems in the Real World      2 mins
# 85   Glossary - Machine Learning Crash Course (Foun...         NaN
# 88      ML Problem Framing - Understanding the Problem  25 minutes
# 90                   Conclusion - Implementing a model      10mins
# 526  Build and Optimize Data Warehouses with BigQue...  15 minutes
# 539  Overview - The Process for Data Preparation an...       5mins
# 549   Sampling and Splitting Data - Data Split Example       5mins
# 550  Sampling and Splitting Data - Splitting Your Data       5mins
# 551        Sampling and Splitting Data - Randomization       5mins
# 557                               Programming Exercise  60 minutes
# 558               Programming Exercise - Data Modeling      50mins
# 559                        Conclusion - Course Summary      10mins
# 560                             Overview: Introduction      2 mins
# 561                      Debugging & Testing: Overview      2 mins
# 567  Debugging & Testing: Evaluate Models Using Met...      5 mins
# 571                   Testing in production: Overview       5 mins
# 572      Testing in production: Testing for Deployment     15 mins
# 574   Testing in production: Check Your Understanding:      5 mnis
# 644  Designing Data Processing Systems: Designing a...      10mins
# 652  Designing Data Processing Systems: Practice ex...       3 min
# 663  Building and Operationalizing Data Processing ...     2 hours
# 664  Building and Operationalizing Data Processing ...       2mins
# 667  Operationalizing Machine Learning Models: Anal...       3mins
# 668  Operationalizing Machine Learning Models: Mach...      33secs
# 669  Operationalizing Machine Learning Models: Mach...    4:45mins
# 679  Operationalizing Machine Learning Models: Divi...    1:46mins
#
#     Module / Sub-module \nDifficulty level  \
# 0                                     Easy
# 1                                     Easy
# 3                                     Easy
# 4                                     Easy
# 6                                     Easy
# 7                           Easy to Medium
# 8                           Easy to Medium
# 9                           Easy to Medium
# 21                                    Easy
# 22                                    Easy
# 23                                    Easy
# 24                                    Easy
# 25                                    Easy
# 26                                    Easy
# 73                                  Medium
# 82                          Easy to Medium
# 83                          Easy to Medium
# 84                          Easy to Medium
# 85                          Easy to Medium
# 88                                  Medium
# 90                                  Medium
# 526                                   Easy
# 539                                 Medium
# 549                                 Medium
# 550                                 Medium
# 551                                 Medium
# 557                                 Medium
# 558                                 Medium
# 559                                 Medium
# 560                                 Medium
# 561                                 Medium
# 567                                 Medium
# 571                                 Medium
# 572                                 Medium
# 574                                 Medium
# 644                                 Medium
# 652                                 Medium
# 663                                 Medium
# 664                                 Medium
# 667                                 Medium
# 668                                 Medium
# 669                                 Medium
# 679                                 Medium
#
#                                                  Links  \
# 0    https://developers.google.com/machine-learning...
# 1    https://developers.google.com/machine-learning...
# 3    https://developers.google.com/machine-learning...
# 4    https://developers.google.com/machine-learning...
# 6    https://developers.google.com/machine-learning...
# 7    https://developers.google.com/machine-learning...
# 8    https://developers.google.com/machine-learning...
# 9    https://developers.google.com/machine-learning...
# 21   https://developers.google.com/machine-learning...
# 22   https://developers.google.com/machine-learning...
# 23   https://developers.google.com/machine-learning...
# 24   https://developers.google.com/machine-learning...
# 25   https://developers.google.com/machine-learning...
# 26   https://developers.google.com/machine-learning...
# 73   https://developers.google.com/machine-learning...
# 82   https://developers.google.com/machine-learning...
# 83   https://developers.google.com/machine-learning...
# 84   https://developers.google.com/machine-learning...
# 85   https://developers.google.com/machine-learning...
# 88   https://developers.google.com/machine-learning...
# 90   https://developers.google.com/machine-learning...
# 526  https://www.cloudskillsboost.google/focuses/14...
# 539  https://developers.google.com/machine-learning...
# 549  https://developers.google.com/machine-learning...
# 550  https://developers.google.com/machine-learning...
# 551  https://developers.google.com/machine-learning...
# 557  https://developers.google.com/machine-learning...
# 558  https://developers.google.com/machine-learning...
# 559  https://developers.google.com/machine-learning...
# 560  https://developers.google.com/machine-learning...
# 561  https://developers.google.com/machine-learning...
# 567  https://developers.google.com/machine-learning...
# 571  https://developers.google.com/machine-learning...
# 572  https://developers.google.com/machine-learning...
# 574  https://developers.google.com/machine-learning...
# 644  https://www.cloudskillsboost.google/course_ses...
# 652  https://www.cloudskillsboost.google/course_ses...
# 663  https://www.cloudskillsboost.google/course_ses...
# 664  https://www.cloudskillsboost.google/course_ses...
# 667  https://www.cloudskillsboost.google/course_ses...
# 668  https://www.cloudskillsboost.google/course_ses...
# 669  https://www.cloudskillsboost.google/course_ses...
# 679  https://www.cloudskillsboost.google/course_ses...
#
#      Keywords / Tags / Skills / Interests / Categories
# 0                                                   ml
# 1                                                   ml
# 3                                              ml test
# 4                                                   ml
# 6                                     ml terminologies
# 7                                                   ml
# 8                                ml, linear regression
# 9                                   ml, training, loss
# 21                             training, test, dataset
# 22            training, test, dataset, splitting, data
# 23                             training, test, dataset
# 24                                      validation set
# 25                           validation set, partition
# 26                                      validation set
# 73                               production, ml system
# 82           real world, cancer, prediction, ml system
# 83                   real world, literature, ml system
# 84                    real world, guideline, ml system
# 85                                        glossary, ml
# 88   data, ml, solution, dataset, user, prediction,...
# 90   model, models, data, prediction, outcome, infe...
# 526  data engineer, big query, partitioned dataset,...
# 539                            data, sample, label, ml
# 549         data, label, split, set, training, testing
# 550  data, label, split, training, testing, validat...
# 551  data,sample, evaluation, generation, dataset, ...
# 557  data, transformation, label, sample, dataset, ...
# 558  data, transformation, label, sample, dataset, ...
# 559    data, dataset,algorithm, workflow, sample, code
# 560      debugging, learning, testing, ml, model, code
# 561  debugging, learning, testing, ml, model, code,...
# 567  data, metric, model, error, quality, slice, me...
# 571  pipeline, ml, test, testing, model, component,...
# 572  datatset, server, model, api, test, integratio...
# 574  data, behavior, model, quality, dataset, predi...
# 644  data engineering, pipeline, designing data, re...
# 652  data, big query, cloud storage, dataset, cloud...
# 663  data, SQL, big query, dataset, pipeline, dataproc
# 664  data, SQL, big query, dataset, pipeline, dataproc
# 667                 data, SQL, analysis, ml, algorithm
# 668  data, ml, big query, dataflow, tensorflow, Clo...
# 669  data engineer, ml, model, MSE, RMSE, gradient ...
# 679  data, partitioning, big query, ,ml, GroupByKey...

# %% [markdown]
# # cleaning up units in duration

# %%
lpi.Duration.value_counts()
# Out:
# Duration
# 1 min          121
# 2 minutes      113
# 5 min           91
# 2 min           63
# 1 minute        61
#               ...
# 1mins            1
# 4:34mins         1
# 2hrs             1
# 24 secs          1
# 90 miniutes      1
# Name: count, Length: 185, dtype: int64

# %%
import pandas as pd
import re
import numpy as np

# Function to extract string units
def extract_unit(text):
    if isinstance(text, str):  # Check if the input is a string
        # Extract the unit (min, hour, sec, etc.)
        unit = re.search(r'[a-zA-Z]+', text).group().lower()
        return unit
    else:
        return None  # Return None if the input is not a string

# Apply the function to create a new column for units
lpi['Unit'] = lpi['Duration'].apply(extract_unit)

# Count the occurrences of each distinct unit
unit_counts = lpi['Unit'].value_counts()

print(unit_counts)
# Out:
# Unit
# min         594
# minutes     518
# mins        115
# minute       61
# hours        19
# secs          4
# to            3
# minutess      1
# miinutes      1
# hr            1
# mnis          1
# sec           1
# hrs           1
# miniutes      1
# Name: count, dtype: int64

# %%
unit_counts.index
# Out:
# Index(['min', 'minutes', 'mins', 'minute', 'hours', 'secs', 'to', 'minutess',
#        'miinutes', 'hr', 'mnis', 'sec', 'hrs', 'miniutes'],
#       dtype='object', name='Unit')

# %%
time_map = {}
for i in unit_counts.index:
    time_map[i] = "abc"

time_map
# Out:
# {'min': 'abc',
#  'minutes': 'abc',
#  'mins': 'abc',
#  'minute': 'abc',
#  'hours': 'abc',
#  'secs': 'abc',
#  'to': 'abc',
#  'minutess': 'abc',
#  'miinutes': 'abc',
#  'hr': 'abc',
#  'mnis': 'abc',
#  'sec': 'abc',
#  'hrs': 'abc',
#  'miniutes': 'abc'}

# %%
# just copy and paste the above and change the values to your liking like below
##### remember to hastag "to"

time_map = {'min': 'minutes',
 'minutes': 'minutes',
 'mins': 'minutes',
 'minute': 'minutes',
 'hours': 'hours',
 'secs': 'seconds',
 # 'to': 'to', ##### <----------
 'minutess': 'minutes',
 'miinutes': 'minutes',
 'hr': 'hours',
 'mnis': 'minutes',
 'sec': 'seconds',
 'hrs': 'hours',
 'miniutes': 'minutes'}

# %%
def duration_cleanup(text):
    if isinstance(text, str):  # Check if the input is a string
        if "to" in text:  # Skip if the string contains "to"
            return text  # You can return the original text or None, as you prefer
        # Extract the numerical value
        num = float(re.search(r'\d+', text).group())
        # Extract the unit (min, hour, sec, etc.)
        unit = time_map.get(re.search(r'[a-zA-Z]+', text).group().lower(), "unknown")
        return str(num) + " " + unit
    else:
        return None  # Return None if the input is not a string

# %%
# Apply the function to create a new column
lpi['Duration2'] = lpi['Duration'].apply(duration_cleanup)

# %%
lpi.query('Unit.str.contains("miinutes|to|mnis|miniutes|sec|hrs", case=False, na=False)').head(20)
# Out:
#                              Course / Learning material  \
# 405   Data Engineer - Serverless Data Processing wit...
# 425   Data Engineer - Serverless Data Processing wit...
# 510   Data Engineer - Quest: Perform Foundational Da...
# 532   Data Engineer - Quest: Engineer Data in Google...
# 574                               Testing and Debugging
# 662   Data Engineer - Preparing for the Google Cloud...
# 668   Data Engineer - Preparing for the Google Cloud...
# 681   Data Engineer - Preparing for the Google Cloud...
# 684   Data Engineer - Preparing for the Google Cloud...
# 685   Data Engineer - Preparing for the Google Cloud...
# 696   Data Engineer - Preparing for the Google Cloud...
# 1377            Machine Learning Engineer Learning Path
#
#                         Source              Course Level  \
# 405   Google Cloud Skill Boost              Intermediate
# 425   Google Cloud Skill Boost              Intermediate
# 510   Google Cloud Skill Boost                  Beginner
# 532   Google Cloud Skill Boost                  Beginner
# 574          Google Developers  Beginner to Intermediate
# 662   Google Cloud Skill Boost                  Beginner
# 668   Google Cloud Skill Boost                  Beginner
# 681   Google Cloud Skill Boost                  Beginner
# 684   Google Cloud Skill Boost                  Beginner
# 685   Google Cloud Skill Boost                  Beginner
# 696   Google Cloud Skill Boost                  Beginner
# 1377  Google Cloud Skill Boost  Intermediate to Advanced
#
#                 Type (Free or Paid)  \
# 405   Free during mentorship period
# 425   Free during mentorship period
# 510   Free during mentorship period
# 532   Free during mentorship period
# 574                            Free
# 662   Free during mentorship period
# 668   Free during mentorship period
# 681   Free during mentorship period
# 684   Free during mentorship period
# 685   Free during mentorship period
# 696   Free during mentorship period
# 1377  Free during mentorship period
#
#                                                  Module        Duration  \
# 405           Beam Portability: Quiz - Beam Portability      5 miinutes
# 425   Serverless Data Processing with Dataflow: Deve...  35 to 36 hours
# 510   Perform Foundational Data, ML, and AI Tasks in...    7 to 8 hours
# 532                       Engineer Data in Google Cloud    5 to 6 hours
# 574    Testing in production: Check Your Understanding:          5 mnis
# 662   Building and Operationalizing Data Processing ...           19sec
# 668   Operationalizing Machine Learning Models: Mach...          33secs
# 681   Operationalizing Machine Learning Models: Pric...         43 secs
# 684   Operationalizing Machine Learning Models: Chal...         24 secs
# 685   Operationalizing Machine Learning Models: PDE ...            2hrs
# 696        Resources and Next Steps: Practice exam quiz          14secs
# 1377  Build and Deploy Machine Learning Solutions on...     90 miniutes
#
#      Module / Sub-module \nDifficulty level  \
# 405                          Easy to Medium
# 425                          Medium to Hard
# 510                          Easy to Medium
# 532                          Easy to Medium
# 574                                  Medium
# 662                                  Medium
# 668                                  Medium
# 681                                  Medium
# 684                                  Medium
# 685                                  Medium
# 696                                  Medium
# 1377                         Medium to Hard
#
#                                                   Links  \
# 405   https://www.cloudskillsboost.google/course_ses...
# 425   https://www.cloudskillsboost.google/course_tem...
# 510   https://www.cloudskillsboost.google/course_tem...
# 532   https://www.cloudskillsboost.google/course_tem...
# 574   https://developers.google.com/machine-learning...
# 662   https://www.cloudskillsboost.google/course_ses...
# 668   https://www.cloudskillsboost.google/course_ses...
# 681   https://www.cloudskillsboost.google/course_ses...
# 684   https://www.cloudskillsboost.google/course_ses...
# 685   https://www.cloudskillsboost.google/course_ses...
# 696   https://www.cloudskillsboost.google/course_ses...
# 1377  https://www.cloudskillsboost.google/course_ses...
#
#       Keywords / Tags / Skills / Interests / Categories      Unit  \
# 405   Cloud, Dataflow, Severless, Data Processing, D...  miinutes
# 425   Cloud, Dataflow, Severless, Data Processing, D...        to
# 510   Machine Learning,Deployment,Cloud, Lab, AI, ta...        to
# 532   data engineer, data preparation, data wranglin...        to
# 574   data, behavior, model, quality, dataset, predi...      mnis
# 662   data, SQL, big query, apache airflow, pipeline...       sec
# 668   data, ml, big query, dataflow, tensorflow, Clo...      secs
# 681   data, big query, query validator, pricing calc...      secs
# 684   data, bigtable, cloud storage, big query, SQL,...      secs
# 685   data, bigtable, cloud storage, big query, SQL,...       hrs
# 696   data, data security,, data security, scaling, ...      secs
# 1377  Machine Learning,Deployment,Cloud, Vertex AI, ...  miniutes
#
#            Duration2
# 405      5.0 minutes
# 425   35 to 36 hours
# 510     7 to 8 hours
# 532     5 to 6 hours
# 574      5.0 minutes
# 662     19.0 seconds
# 668     33.0 seconds
# 681     43.0 seconds
# 684     24.0 seconds
# 685        2.0 hours
# 696     14.0 seconds
# 1377    90.0 minutes

# %%
# Apply the function to create a new column for units
lpi[lpi['Duration2'].str.contains("unknown", na=False)]
# Out:
# Empty DataFrame
# Columns: [Course / Learning material, Source, Course Level, Type (Free or Paid), Module, Duration, Module / Sub-module
# Difficulty level, Links, Keywords / Tags / Skills / Interests / Categories, Unit, Duration2]
# Index: []

# %%
# Apply the function to create a new column for units
lpi['Duration2'].apply(extract_unit).value_counts()
# Out:
# Duration2
# minutes    1292
# hours        21
# seconds       5
# to            3
# Name: count, dtype: int64

# %%
lpi.head()
# Out:
#                    Course / Learning material             Source  \
# 0            Introduction to Machine Learning  Google Developers
# 1            Introduction to Machine Learning  Google Developers
# 2            Introduction to Machine Learning  Google Developers
# 3            Introduction to Machine Learning  Google Developers
# 4  Machine Learning Crash Course (Foundation)  Google Developers
#
#                Course Level Type (Free or Paid)  \
# 0                  Beginner                Free
# 1                  Beginner                Free
# 2                  Beginner                Free
# 3                  Beginner                Free
# 4  Beginner to Intermediate                Free
#
#                              Module Duration  \
# 0  Introduction to Machine Learning  20 mins
# 1          What is Machine Learning  20 mins
# 2               Supervised Learning  20 mins
# 3           Test your understanding  10 mins
# 4                Introduction to ML   3 mins
#
#   Module / Sub-module \nDifficulty level  \
# 0                                   Easy
# 1                                   Easy
# 2                         Easy to Medium
# 3                                   Easy
# 4                                   Easy
#
#                                                Links  \
# 0  https://developers.google.com/machine-learning...
# 1  https://developers.google.com/machine-learning...
# 2  https://developers.google.com/machine-learning...
# 3  https://developers.google.com/machine-learning...
# 4  https://developers.google.com/machine-learning...
#
#   Keywords / Tags / Skills / Interests / Categories  Unit     Duration2
# 0                                                ml  mins  20.0 minutes
# 1                                                ml  mins  20.0 minutes
# 2                               supervised learning  mins  20.0 minutes
# 3                                           ml test  mins  10.0 minutes
# 4                                                ml  mins   3.0 minutes

# %%
lpi.drop(columns=["Duration", "Unit"], axis=1, inplace=True)
lpi.rename(columns={"Duration2" : "Duration"}, inplace=True)
lpi.head()
# Out:
#                    Course / Learning material             Source  \
# 0            Introduction to Machine Learning  Google Developers
# 1            Introduction to Machine Learning  Google Developers
# 2            Introduction to Machine Learning  Google Developers
# 3            Introduction to Machine Learning  Google Developers
# 4  Machine Learning Crash Course (Foundation)  Google Developers
#
#                Course Level Type (Free or Paid)  \
# 0                  Beginner                Free
# 1                  Beginner                Free
# 2                  Beginner                Free
# 3                  Beginner                Free
# 4  Beginner to Intermediate                Free
#
#                              Module Module / Sub-module \nDifficulty level  \
# 0  Introduction to Machine Learning                                   Easy
# 1          What is Machine Learning                                   Easy
# 2               Supervised Learning                         Easy to Medium
# 3           Test your understanding                                   Easy
# 4                Introduction to ML                                   Easy
#
#                                                Links  \
# 0  https://developers.google.com/machine-learning...
# 1  https://developers.google.com/machine-learning...
# 2  https://developers.google.com/machine-learning...
# 3  https://developers.google.com/machine-learning...
# 4  https://developers.google.com/machine-learning...
#
#   Keywords / Tags / Skills / Interests / Categories      Duration
# 0                                                ml  20.0 minutes
# 1                                                ml  20.0 minutes
# 2                               supervised learning  20.0 minutes
# 3                                           ml test  10.0 minutes
# 4                                                ml   3.0 minutes

# %% [markdown]
# # viola! all cleaned up!
