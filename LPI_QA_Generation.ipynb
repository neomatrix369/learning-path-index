# %% [markdown]
# <a href="https://colab.research.google.com/github/neomatrix369/learning-path-index/blob/advanced-rag/LPI_QA_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook demonstrates
# * Colab notebook authenticating to a GCP account (with specific project_id and region )
# * Tests prompting Gemini models via VertexAI
# * Test QA on a TEXT sent with prompt

# %% [markdown]
# # Install required packages

# %%
# %%time
# !pip install --upgrade -q google-cloud-aiplatform
# !pip install -q google-colab
# !pip install -q  loguru
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.1 MB/s eta 0:00:00
# CPU times: user 180 ms, sys: 24.8 ms, total: 205 ms
# Wall time: 22.4 s

# %% [markdown]
# # Import required packages

# %%
from google.colab import userdata
from google.colab import auth
from google.cloud import aiplatform
from pathlib import Path
import os
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from loguru import logger
import json
import time

# %% [markdown]
# # Authenticate to GCP account

# %%
# %%time
PROJECT_ID = "generated-mote-434518-u9" # Set this to a valid project id in your google cloud account
REGION = 'us-central1' # Set this to the GCP region you want to use
auth.authenticate_user(project_id=PROJECT_ID) # First time, this might prompt you to login to your google cloud account
# !gcloud config get core/account # This will validate if your authentication was successful and echo the login email
# !gcloud config get-value project # Verify by echo'ing the project config
# !gcloud config set compute/region {REGION} # Set the region
# !gcloud config get-value compute/region # Verify by echo'ing the region config
# Out:
# hirejorgecampos@gmail.com
# generated-mote-434518-u9
# WARNING: Property validation for compute/region was skipped.
# Updated property [compute/region].
# us-central1
# CPU times: user 405 ms, sys: 50.5 ms, total: 455 ms
# Wall time: 29.1 s

# %% [markdown]
# # **Send a prompt and Text File To Gemini 1.5**
#
# ---

# %% [markdown]
# ## Creating the Prompt and system instructions

# %%
prompt = """Using the following list of course files, generate a dataset of 10 question-answer pairs in JSON format. Each question should reflect a student\'s perspective, seeking courses to learn machine learning and AI concepts at various proficiency levels. Include questions from beginners, intermediates, and advanced learners interested in areas like LLMs, NLP, RAG pipelines, fine-tuning models, and vector databases. Ensure the answers provide a tailored set of recommended courses that match the student\'s learning objectives and skill level.
The format for each question-answer pair should be as follows:
{"Question":"I am a beginner and want to learn about NLP. Which courses should I take to understand the fundamentals?","Answer":"Given your beginner level and interest in NLP, I recommend the following courses and modules:\\n\\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\\n|---------------|--------|-------|----------------------|----------|--------|\\n| **NLP Basics** | Coursera | Beginner | 4-6 weeks | NLP, text preprocessing, tokenization, embeddings | Covers foundational NLP techniques for building text processing models. |\\n| **Python for Data Science** | DataCamp | Beginner | 4-8 weeks | Python, data manipulation, basic ML | Essential for understanding coding basics required in NLP workflows. |\"}"""

LLM_instructions = """You task is to create a syntenic conversational dataset from a dataset containing Machine Learning courses from various sites.
Diversity in Questions:
Include questions at varying skill levels (beginner, intermediate, advanced).
Address specific interests (e.g., NLP, fine-tuning LLMs, vector databases, retrieval techniques).
Incorporate scenarios like wanting to focus on a specific machine learning concept or pipeline.
Answer Structure:
Use a table to list multiple recommended courses/modules.
For each course, include:
Course/Module Name
Source (e.g., Coursera, edX, official documentation)
Level (Beginner, Intermediate, Advanced)
Duration Estimate (e.g., 4-6 weeks, 10 hours)
Keywords (relevant topics covered)
Reason (brief explanation of why the course fits the student’s need)
Ensure Answer Completeness:
For each answer, list at least 3-5 relevant courses that progressively cover the required concepts.
Each course/module should be aligned with the student’s stated goals and background level.
JSON Output Format:
The final output should be a JSON array containing \'x\' amount of qa pairs asked by the user"""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 0.5,
    "top_p": 1,
}

# %% [markdown]
# ## Creating Function to check dataset size

# %%
def size_of_file(file: str) -> int:
    """
    This function assumes a JSONL file and returns how many rows are in the file.
    """

        # Check if the file exists
    if not os.path.exists(file):
        print(f"File '{file}' not found.")
        return 0

    # Reopen the file in read mode to check the size
    with open(file, "r") as f:
        lines = f.readlines()
    return len(lines)

# %% [markdown]
# ## Main Function script and call to vertex ai

# %%
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from loguru import logger
import json
import time
def multiturn_generate_content(
    output_path:str,
    num_sets:int,
    ) -> None:
    """
    This function generates a q-a dataset for a given input file using a gemini variant model and returns the response.
    Args:
        output_path (str): The path to the output file.
        num_sets (int): The number of q-a sets to generate per file.

    Returns:
        None

    """

    vertexai.init(project="generated-mote-434518-u9", location="us-central1")
    model = GenerativeModel(
        "gemini-1.5-pro-001",
        system_instruction=[LLM_instructions]
    )

    dataset_size = 0
    iteration = 0
    start_time = time.time()

    # Loop until the dataset size is num_sets

    while dataset_size < num_sets:

      # Sending call to api can i start chat once would that improve speed? I'm  I reinitializing the call?
      chat = model.start_chat(response_validation=False)
      response = chat.send_message(
              [document, prompt],
              generation_config=generation_config,
      )

      ## postprocessing depends on how data is outputted
      q_a_data = response.text.replace('jsonl','').replace("```",'').strip().splitlines()

      # Increment the iteration
      iteration += 1
      logger.info(f'Iteration {iteration}, Amount of q-a sets generated: {len(q_a_data)} ')



      # Open the file in append mode
      with open(output_path, "a") as f:

          # Iterate over the generator and write each item as a JSON string
          logger.debug('Appending data into file.....')

          for item in q_a_data:
            item = item.strip().rstrip(',')
            breakpoint()
            #error handling
            try:
              # Convert the item to a JSON string
              json_item = json.loads(item)
              dataset_size += 1
              # Write the JSON string to the file
              json.dump(json_item, f)
              f.write("\n")  # Write a newline character to ensure each entry starts on a new line
              logger.info(f"Successfully processs Q-A set: {json_item}")
            except json.JSONDecodeError as e:
              logger.error(f"Error decoding JSON: {e}. Skipping this q-a set: {json.item}")
              continue
            except Exception as e:
              # Handle any other exceptions that may occur
              logger.error(f"Unexpected error: {str(e)}. Skipping this Q&A set.")
              continue  # Skip to the next Q&A set



      # Reopen the file in read mode to check the size
      #dataset_size = size_of_file(file = output_path)


      # End the timer
      end_time = time.time()

      # Calculate the elapsed time
      time_taken = end_time - start_time

      logger.info(f"Final results \n dataset size: {dataset_size}\n time elapse: {time_taken}")


     # Outputting chat metadata?
    #logger.info( f""" \n MetaData:\n{response}  """)

    # Outputting Gemini Response
    #logger.info(f"\n Gemini Ouput:\n{response.text}")

    # TODO:
    #   How do convert string data to json file?
    #     - Split on each newline or "{" then convert that one line into a jsonl then write to a file
    #     - What about the text before the json? Could use replace or strip function
    #   How do I get a full 1000 q-a sets
    #     - Probelm is output token limit. Must loop over calls and append to json file
    #     - Check length of json file or store it in dictionary convert it at end
    #   Prompt limit size
    #     - Needle probelm llm usually considers top and bottom as important
    #     - Chunk the pdf into chapters generate 200 q-a prompts for that chapter
    #     - Append it to the json  file  (20 chapters = 4000  Q-A)
    #
    return response


from pathlib import Path

# Specify the folder path
folder_path = Path('/content/qa-data')

# Specify the file path
output_path = "/content/QA_LPI.jsonl"

# Record the start time
start_time = time.time()
# Loop through each file in the folder
for file_path in folder_path.iterdir():

    logger.info(f'Processing file: {file_path.name}')

    # Encoding text
    encoded_data = base64.b64encode( open(file_path, "rb").read() ).decode("utf-8")


    # Not sure about this can't find documentation
    document = Part.from_data(data=base64.b64decode(encoded_data),
      mime_type="text/plain", # change to application/pdf to process pdfs
    )
    multiturn_generate_content(output_path, num_sets=50)
    # Record the end time
    end_time = time.time()

    # Calculate the elapsed time
    elapsed_time = end_time - start_time
    logger.info(f"\nFinal results \n dataset size: {size_of_file(output_path)}\n time elapse: {elapsed_time:.2f} Seconds")
# Out:
# 2024-10-27 17:21:20.342 | INFO     | __main__:<cell line: 125>:127 - Processing file: LPI_index.txt
# 2024-10-27 17:22:51.908 | INFO     | __main__:multiturn_generate_content:48 - Iteration 1, Amount of q-a sets generated: 43
# 2024-10-27 17:22:51.911 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:22:51.913 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.915 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.919 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.920 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.923 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.924 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.925 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.928 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.929 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.930 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.934 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.935 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.936 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.938 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.940 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.941 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.942 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.943 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.945 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.946 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.948 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.949 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.951 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.952 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.956 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.961 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.963 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.965 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.967 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.970 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.972 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.974 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.976 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.979 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.981 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.983 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.987 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.988 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.990 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:22:51.992 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:22:51.993 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:22:51.995 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.997 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:22:51.999 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 0
#  time elapse: 91.64716744422913
# 2024-10-27 17:24:01.258 | INFO     | __main__:multiturn_generate_content:48 - Iteration 2, Amount of q-a sets generated: 13
# 2024-10-27 17:24:01.260 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:24:01.262 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:24:01.265 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:24:01.266 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I am a complete beginner with no coding experience. Where should I start my machine learning journey?', 'Answer': "Given your background, it's best to start with introductory courses focusing on both basic coding and machine learning concepts. Here are some recommendations:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Introduction to Machine Learning** | Google Developers | Beginner | ~1 hour | machine learning, supervised learning | Provides a high-level overview of ML without requiring coding. |\n| **Python for Everybody** | Coursera | Beginner | 4-6 weeks | Python, programming basics | Equips you with fundamental Python skills necessary for ML. |\n| **Machine Learning Crash Course (Foundation)** | Google Developers | Intermediate | ~6 hours | machine learning, TensorFlow | A more hands-on introduction to ML with practical exercises using TensorFlow. |"}
# 2024-10-27 17:24:01.270 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I have some Python knowledge and want to learn about building NLP applications. What courses would you suggest?', 'Answer': 'Since you have Python basics covered, you can dive into NLP-specific courses. Here are some recommendations:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Natural Language Processing Specialization** | DeepLearning.AI | Intermediate | 4 months | NLP, embeddings, transformers, chatbots | Comprehensive specialization covering various NLP techniques and applications. |\n| **ChatGPT Prompt Engineering for Developers** | DeepLearning.AI | Beginner | 1 hour | GenAI applications, prompt engineering, transformers | Focuses on using LLMs for text generation and building conversational AI. |\n| **Practical Deep Learning for Coders** | Fast.ai | Advanced | ~40 hours | Deep learning, NLP, data ethics | Hands-on course covering deep learning techniques for NLP, including ethical considerations. |'}
# 2024-10-27 17:24:01.272 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm an intermediate learner and want to understand how to fine-tune large language models for specific tasks. Any recommendations?", 'Answer': 'Fine-tuning LLMs requires a good understanding of deep learning. Here are some courses to help you:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Deep Learning Specialization** | DeepLearning.AI | Intermediate | 6 months | Computer vision, deep learning, NLP, supervised learning | Provides a solid foundation in deep learning concepts and techniques. |\n| **Finetuning Large Language Models** | DeepLearning.AI | Intermediate | 1 hour | Deep learning, fine-tuning, transformers | Focuses specifically on fine-tuning techniques for LLMs. |\n| **Reinforcement Learning from Human Feedback** | DeepLearning.AI | Intermediate | Variable | Fine-tuning, generative models, LLMOps, transformers | Covers advanced techniques for aligning LLMs with human preferences. |'}
# 2024-10-27 17:24:01.273 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I want to learn about building retrieval augmented generation (RAG) pipelines. Which courses cover this topic?', 'Answer': 'RAG pipelines combine information retrieval with LLM generation. These courses can help you understand this concept:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **LangChain for LLM Application Development** | DeepLearning.AI | Beginner | 1 hour | AI frameworks, agents, generative models, prompt engineering, RAG | Introduces LangChain, a framework for building LLM applications, including RAG. |\n| **LangChain: Chat with Your Data** | DeepLearning.AI | Beginner | 1 hour | Embeddings, RAG, vector databases | Focuses on using LangChain to build conversational AI that retrieves information from your data. |\n| **Building and Evaluating Advanced RAG Applications** | DeepLearning.AI | Beginner | Variable | AI frameworks, RAG, search and retrieval | Covers advanced techniques for building and evaluating RAG pipelines. |'}
# 2024-10-27 17:24:01.277 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm interested in learning about vector databases and their use in machine learning. What are some good resources?", 'Answer': "Vector databases are essential for efficient similarity search in ML applications. Here's where you can learn about them:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Vector Databases: from Embeddings to Applications** | DeepLearning.AI | Intermediate | Variable | Embeddings, RAG, search and retrieval, vector databases | A comprehensive course covering vector databases and their applications in ML. |\n| **Large Language Models with Semantic Search** | DeepLearning.AI | Beginner | 1 hour | Embeddings, NLP, RAG, search and retrieval, vector databases | Focuses on using vector databases for semantic search with LLMs. |\n| **Building Applications with Vector Databases** | DeepLearning.AI | Beginner | Variable | Anomaly detection, embeddings, multimodal, vector databases | Explores various applications of vector databases in ML, including anomaly detection and multimodal search. |"}
# 2024-10-27 17:24:01.279 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm a data scientist familiar with traditional ML algorithms. How can I transition to deep learning?", 'Answer': 'Transitioning to deep learning requires understanding neural networks. Here are some courses to help you:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Deep Learning Specialization** | DeepLearning.AI | Intermediate | 6 months | Computer vision, deep learning, NLP, supervised learning | A comprehensive deep learning specialization covering fundamentals and advanced concepts. |\n| **Practical Deep Learning for Coders** | Fast.ai | Advanced | ~40 hours | Deep learning, machine learning, NLP, data ethics | Hands-on deep learning course with a practical approach and real-world applications. |\n| **TensorFlow Developer Professional Certificate** | DeepLearning.AI | Intermediate | 2-4 weeks | AI frameworks, computer vision, deep learning, NLP | Focuses on using TensorFlow for building and deploying deep learning models. |'}
# 2024-10-27 17:24:01.281 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I want to learn about deploying machine learning models in production. What resources are available?', 'Answer': 'Deploying ML models requires understanding MLOps principles. Here are some relevant courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Machine Learning in Production** | DeepLearning.AI | Intermediate | 4 months | Data engineering, deep learning, MLOps | Covers the entire ML lifecycle, including deployment and monitoring in production. |\n| **TensorFlow: Data and Deployment Specialization** | DeepLearning.AI | Intermediate | 2-6 months | Data processing, MLOps, on-device AI | Focuses on data handling and deployment strategies for TensorFlow models. |\n| **LLMOps** | DeepLearning.AI | Beginner | Variable | AI safety, data processing, evaluation and monitoring, fine-tuning, LLMOps | Introduces LLMOps principles and best practices for managing LLMs in production. |'}
# 2024-10-27 17:24:01.282 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm an advanced learner and want to explore cutting-edge topics like generative adversarial networks (GANs). What courses do you recommend?", 'Answer': 'For advanced learners interested in GANs, these courses are a good fit:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **Generative Adversarial Networks (GANs) Specialization** | DeepLearning.AI | Intermediate | 3 months | Computer vision, deep learning, generative models | Comprehensive specialization covering various GAN architectures and applications. |\n| **How Diffusion Models Work** | DeepLearning.AI | Intermediate | 1 hour | Deep learning, diffusion models, GenAI applications, generative models | Focuses on diffusion models, a powerful type of generative model used for image synthesis. |\n| **Building Generative AI Applications with Gradio** | DeepLearning.AI | Beginner | 1 hour | Chatbots, diffusion models, GenAI applications, generative models | Teaches how to build and deploy generative AI applications using Gradio, a user interface library. |'}
# 2024-10-27 17:24:01.289 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm concerned about the ethical implications of AI. Are there any courses that address responsible AI?", 'Answer': 'Responsible AI is crucial. These courses can help you understand ethical considerations:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| **AI for Everyone** | DeepLearning.AI | Beginner | 6 hours | Deep learning, machine learning, NLP, data ethics | Includes a module on the societal impacts and ethical considerations of AI. |\n| **What is AI Ethics?** | IBM | Intermediate | ~10 minutes | AI ethics, artificial intelligence, responsible AI | Provides a brief but informative overview of AI ethics principles. |\n| **Introduction to Generative AI** | Google Cloud Skill Boost | Beginner | ~2 hours | Responsible AI, ethics, AI ethics, fairness, bias, transparency | Discusses responsible AI principles in the context of generative AI. |'}
# 2024-10-27 17:24:01.292 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Unterminated string starting at: line 1 column 119 (char 118). Skipping this q-a set
# 2024-10-27 17:24:01.294 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:24:01.297 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 9
#  time elapse: 160.9457724094391
# 2024-10-27 17:25:16.372 | INFO     | __main__:multiturn_generate_content:48 - Iteration 3, Amount of q-a sets generated: 43
# 2024-10-27 17:25:16.375 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:25:16.376 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.378 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.381 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.385 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.386 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.391 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.392 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.396 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.398 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.400 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.402 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.404 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.406 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.411 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.414 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.415 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.419 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.421 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.422 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.424 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.426 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.428 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.430 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.432 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.434 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.436 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.438 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.440 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.442 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.444 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.447 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.449 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.451 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.453 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.455 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.458 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.460 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.462 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.464 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:25:16.466 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:25:16.468 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:25:16.470 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.472 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:25:16.476 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 9
#  time elapse: 236.12454080581665
# 2024-10-27 17:26:29.459 | INFO     | __main__:multiturn_generate_content:48 - Iteration 4, Amount of q-a sets generated: 13
# 2024-10-27 17:26:29.462 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:26:29.463 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:26:29.465 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:26:29.466 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I am a complete beginner with no prior knowledge of machine learning. Where should I start?', 'Answer': 'Given your beginner status, I recommend starting with introductory courses that cover the fundamentals of machine learning:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Introduction to Machine Learning | Google Developers | Beginner | ~1 hour | machine learning, supervised learning | Provides a gentle introduction to core ML concepts and terminology. |\n| Machine Learning Crash Course (Foundation) | Google Developers | Intermediate | ~4 hours | machine learning, framing, terminology, linear regression | Covers essential ML terminology, problem framing, and basic algorithms like linear regression. |\n| AI for Everyone | DeepLearning.AI | Beginner | 6 hours | Deep Learning, Machine Learning | This course will provide you with a high-level understanding of AI concepts and applications. |'}
# 2024-10-27 17:26:29.469 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I have some basic understanding of ML. I want to learn more about neural networks. What courses would you suggest?', 'Answer': 'Since you have a basic understanding of ML, you can dive into neural networks with these courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Machine Learning Crash Course (Foundation) | Google Developers | Intermediate | ~4 hours | neural networks, structure, training | Introduces the structure of neural networks and basic training concepts. |\n| Deep Learning Specialization | DeepLearning.AI | Intermediate | ~6 months | Computer Vision, Deep Learning, NLP, Supervised Learning, Transformers | This specialization covers various deep learning architectures, including convolutional and recurrent neural networks, and their applications in computer vision and NLP. |\n| TensorFlow Developer Professional Certificate | DeepLearning.AI | Intermediate | 2-4 weeks | AI Frameworks, Computer Vision, Deep Learning, NLP, Time Series | This certificate program focuses on using TensorFlow to build and deploy deep learning models. |'}
# 2024-10-27 17:26:29.471 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm interested in learning about Large Language Models (LLMs) and how they work. Could you recommend some relevant courses?", 'Answer': 'Given your interest in LLMs, here are some courses that explore their architecture and applications:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Introduction to Generative AI | Google Cloud Skill Boost | Beginner | ~45 minutes | Generative AI, Deep Learning, Artificial Intelligence, Image Generation, Text Generation | Provides an overview of Generative AI and LLMs, their capabilities, and responsible AI considerations. |\n| ChatGPT Prompt Engineering for Developers | DeepLearning.AI | Beginner | 1 hour | GenAI Applications, Prompt Engineering, Transformers | This course teaches you how to effectively interact with and utilize LLMs like ChatGPT through prompt engineering techniques. |\n| Large Language Models with Semantic Search | DeepLearning.AI | Beginner | 1 hour | Embeddings, NLP, RAG, Search and Retrieval, Vector Databases | This course explores using LLMs for semantic search applications and introduces concepts like embeddings and vector databases. |'}
# 2024-10-27 17:26:29.473 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm an intermediate learner and want to focus on Natural Language Processing (NLP). Which courses should I take?", 'Answer': "For an intermediate learner interested in NLP, I recommend these courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Natural Language Processing Specialization | DeepLearning.AI | Intermediate | ~4 months | Chatbots, Embeddings, NLP, Transformers | Covers a wide range of NLP techniques, including word embeddings, sequence models, and attention mechanisms. |\n| Natural Language (NLP) | Fast.ai | Advanced | ~100 minutes | Deep Learning, Machine Learning, NLP | Provides a practical approach to NLP using deep learning techniques. |\n| Natural Language Processing on Google Cloud | Google Cloud Skill Boost | Advanced | ~12 hours | Machine Learning, NLP, Cloud, Dialogflow API | Focuses on applying NLP techniques using Google Cloud's tools and services. |"}
# 2024-10-27 17:26:29.475 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I want to learn about building Retrieval Augmented Generation (RAG) pipelines. What resources can you recommend?', 'Answer': 'To learn about building RAG pipelines, consider these resources:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| LangChain for LLM Application Development | DeepLearning.AI | Beginner | 1 hour | AI Frameworks, Agents, Chatbots, Generative Models, Prompt Engineering, RAG | Introduces LangChain, a framework for building LLM-powered applications, including RAG pipelines. |\n| LangChain: Chat with Your Data | DeepLearning.AI | Beginner | 1 hour | Computer Vision, Document Processing, Embeddings, RAG, Vector Databases | This course focuses on using LangChain to build a chatbot that can access and retrieve information from your own data. |\n| Building and Evaluating Advanced RAG Applications | DeepLearning.AI | Beginner | N/A | AI Frameworks, Evaluation and Monitoring, GenAI Applications, LLMOps, RAG, Search and Retrieval | This course delves into building more sophisticated RAG applications and covers evaluation and monitoring techniques. |'}
# 2024-10-27 17:26:29.477 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I have a good understanding of ML and want to learn about fine-tuning models. Any suggestions?', 'Answer': 'For fine-tuning models, these courses are suitable for advanced learners:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Finetuning Large Language Models | DeepLearning.AI | Intermediate | 1 hour | Deep Learning, Fine-Tuning, Transformers | Focuses specifically on fine-tuning large language models for specific tasks and domains. |\n| Reinforcement Learning from Human Feedback | DeepLearning.AI | Intermediate | N/A | Fine-Tuning, Generative Models, LLMOps, Transformers | This course explores advanced techniques for fine-tuning LLMs using human feedback to improve performance and alignment. |\n| Efficiently Serving LLMs | DeepLearning.AI | Intermediate | N/A | Fine-Tuning, Generative Models, LLMOps, LLM Serving, Transformers | This course covers fine-tuning techniques in the context of efficiently deploying and serving LLMs. |'}
# 2024-10-27 17:26:29.478 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm interested in using vector databases for my AI projects. Which courses should I explore?", 'Answer': 'To learn about vector databases and their applications, check out these courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Large Language Models with Semantic Search | DeepLearning.AI | Beginner | 1 hour | Embeddings, NLP, RAG, Search and Retrieval, Vector Databases | Introduces vector databases in the context of semantic search with LLMs. |\n| LangChain: Chat with Your Data | DeepLearning.AI | Beginner | 1 hour | Computer Vision, Document Processing, Embeddings, RAG, Vector Databases | This course demonstrates using a vector database to store and retrieve information for a LangChain-powered chatbot. |\n| Vector Databases: from Embeddings to Applications | DeepLearning.AI | Intermediate | N/A | Embeddings, GenAI Applications, RAG, Search and Retrieval, Vector Databases | This course provides a comprehensive overview of vector databases, their use cases, and how to integrate them into AI applications. |'}
# 2024-10-27 17:26:29.479 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm a data engineer and need to learn about serverless data processing on Google Cloud. What courses would you recommend?", 'Answer': 'For serverless data processing on Google Cloud, these courses are relevant for data engineers:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Data Engineer - Serverless Data Processing with Dataflow: Foundations | Google Cloud Skill Boost | Intermediate | ~2 hours | Cloud, Dataflow, Serverless, Data Processing, Data Pipelines | Provides a foundation for understanding serverless data processing concepts and Dataflow. |\n| Data Engineer - Serverless Data Processing with Dataflow: Develop Pipelines | Google Cloud Skill Boost | Intermediate | ~35-36 hours | Cloud, Dataflow, Serverless, Data Processing, Data Pipelines, Beam | This course dives deeper into developing data pipelines using Dataflow and Apache Beam. |\n| Dataflow: Qwik Start - Templates & Python | Google Cloud Skill Boost | Beginner | ~1 hour | Machine Learning, Deployment, Cloud, Lab, AI, task, Qwik Start, Command Line, Challenge | Offers a quick introduction to using Dataflow templates and Python for data processing tasks. |'}
# 2024-10-27 17:26:29.481 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm concerned about AI ethics and bias. Are there any courses that address these issues?", 'Answer': "Yes, there are courses that specifically focus on AI ethics and bias:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| AI Ethics Resources | IBM | Intermediate | ~25 minutes | AI Ethics, Artificial Intelligence, AI, Responsible AI | Introduces the concepts of AI ethics, responsible AI principles, and practical considerations. |\n| Introduction to Generative AI | Google Cloud Skill Boost | Beginner | ~20 minutes | Responsible AI, Ethics, AI Ethics, Fairness, Bias, Transparency | This module within the Generative AI course covers responsible AI principles and their application in developing and using generative AI models. |\n| Fairness in Perspective API | Google Developers | Advanced | ~90 minutes | Machine Learning, Advance Machine Learning, Neural Network, Fairness, AI, Bias | Explores fairness considerations in machine learning models using Google's Perspective API, a tool for analyzing text for toxicity and bias. |"}
# 2024-10-27 17:26:29.482 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Unterminated string starting at: line 1 column 173 (char 172). Skipping this q-a set
# 2024-10-27 17:26:29.487 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:26:29.497 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 18
#  time elapse: 309.14535188674927
# 2024-10-27 17:27:47.923 | INFO     | __main__:multiturn_generate_content:48 - Iteration 5, Amount of q-a sets generated: 43
# 2024-10-27 17:27:47.926 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:27:47.927 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.929 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.935 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.936 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.937 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.939 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.940 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.945 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.947 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.948 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.949 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.955 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.956 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.957 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.958 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.964 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.965 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.966 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.972 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.974 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.975 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.976 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.980 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.981 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.982 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.984 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.985 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.988 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.990 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.991 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.992 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:47.993 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:47.995 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:47.998 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:47.999 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:48.000 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:48.002 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:48.003 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:48.006 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:27:48.007 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:27:48.008 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:27:48.009 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:48.011 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:27:48.012 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 18
#  time elapse: 387.6609046459198
# 2024-10-27 17:29:00.548 | INFO     | __main__:multiturn_generate_content:48 - Iteration 6, Amount of q-a sets generated: 13
# 2024-10-27 17:29:00.550 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:29:00.552 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:29:00.554 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# ...
# 2024-10-27 17:36:24.497 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:36:24.500 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:36:24.502 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:36:24.503 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:36:24.506 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:36:24.508 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 11 (char 10). Skipping this q-a set
# 2024-10-27 17:36:24.510 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Extra data: line 1 column 9 (char 8). Skipping this q-a set
# 2024-10-27 17:36:24.512 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:36:24.514 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:36:24.518 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 46
#  time elapse: 904.1669540405273
# 2024-10-27 17:37:37.874 | INFO     | __main__:multiturn_generate_content:48 - Iteration 13, Amount of q-a sets generated: 13
# 2024-10-27 17:37:37.877 | DEBUG    | __main__:multiturn_generate_content:56 - Appending data into file.....
# 2024-10-27 17:37:37.879 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:37:37.881 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 2 (char 1). Skipping this q-a set
# 2024-10-27 17:37:37.883 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I am a complete beginner with no prior knowledge of machine learning. Where should I start?', 'Answer': 'Given your beginner status, I recommend starting with introductory courses that cover the basics of machine learning:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Introduction to Machine Learning | Google Developers | Beginner | ~1 hour | machine learning, supervised learning | A quick overview of core ML concepts. |\n| Machine Learning Crash Course (Foundation) | Google Developers | Intermediate | ~4 hours | machine learning, framing, terminology, linear regression, training, loss, TensorFlow |  A more in-depth crash course covering essential ML terminology and techniques. |\n| AI for Everyone | DeepLearning.AI | Beginner | 6 hours | Deep Learning, Machine Learning | This course provides a broad understanding of AI concepts without delving into technical details. |\n| Machine Learning Specialization | DeepLearning.AI, Stanford Online | Beginner | 2.5 Months | Anomaly Detection, Deep Learning, Machine Learning, Supervised Learning, Unsupervised Learning | A comprehensive specialization covering various aspects of machine learning. |'}
# 2024-10-27 17:37:37.885 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I have some basic understanding of ML. I want to learn about Natural Language Processing. What courses would you suggest?', 'Answer': 'Since you have basic ML knowledge, you can dive into NLP with these courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Natural Language Processing | Google Developers | Intermediate | ~2 hours | neural networks, embeddings, production ML systems |  Focuses on practical NLP techniques using neural networks. |\n| Natural Language Processing Specialization | DeepLearning.AI | Intermediate | 4 months | Chatbots, Embeddings, NLP, Transformers |  A specialization covering various NLP concepts, including chatbots and transformers. |\n| Understanding and Applying Text Embeddings | DeepLearning.AI | Beginner | 1 Hour | Embeddings, GenAI Applications, NLP, RAG, Search and Retrieval | This course focuses on text embeddings, a fundamental concept in NLP. |'}
# 2024-10-27 17:37:37.887 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm interested in building a Retrieval Augmented Generation (RAG) pipeline. What resources can help me get started?", 'Answer': 'Building a RAG pipeline requires understanding several components. Here are some courses that can help you:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Understanding and Applying Text Embeddings | DeepLearning.AI | Beginner | 1 Hour | Embeddings, GenAI Applications, NLP, RAG, Search and Retrieval |  This course covers text embeddings, a crucial part of RAG pipelines. |\n| LangChain for LLM Application Development | DeepLearning.AI | Beginner | 1 Hour | AI Frameworks, Agents, Chatbots, Generative Models, Prompt Engineering, RAG | Introduces LangChain, a framework for building LLM applications, including RAG. |\n| LangChain: Chat with Your Data | DeepLearning.AI | Beginner | 1 Hour | Computer Vision, Document Processing, Embeddings, RAG, Vector Databases | This course teaches you how to use LangChain to build a chatbot that interacts with your data using RAG. |\n| Building and Evaluating Advanced RAG Applications | DeepLearning.AI | Beginner | Beginner | AI Frameworks, Evaluation and Monitoring, GenAI Applications, LLMOps, RAG, Search and Retrieval | This course covers advanced RAG concepts and techniques for building and evaluating RAG applications. |'}
# 2024-10-27 17:37:37.889 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm an intermediate learner and want to explore fine-tuning large language models. What courses would you recommend?", 'Answer': "For fine-tuning LLMs, you'll need a good grasp of deep learning. These courses can help:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Deep Learning Specialization | DeepLearning.AI | Intermediate | 6 months | Computer Vision, Deep Learning, NLP, Supervised Learning, Transformers | Covers deep learning fundamentals and advanced architectures like transformers. |\n| Finetuning Large Language Models | DeepLearning.AI | Intermediate | 1 Hour | Deep Learning, Fine-Tuning, Transformers | This course focuses specifically on fine-tuning large language models. |\n| Reinforcement Learning from Human Feedback | DeepLearning.AI | Intermediate | Intermediate | Fine-Tuning, Generative Models, LLMOps, Transformers | Explores advanced techniques for fine-tuning LLMs using human feedback. |"}
# 2024-10-27 17:37:37.893 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I want to learn about vector databases and their applications. Which courses are relevant?', 'Answer': 'Vector databases are essential for many AI applications. Here are some courses to learn about them:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| LangChain: Chat with Your Data | DeepLearning.AI | Beginner | 1 Hour | Computer Vision, Document Processing, Embeddings, RAG, Vector Databases | Introduces vector databases in the context of building a chatbot with LangChain. |\n| Vector Databases: from Embeddings to Applications | DeepLearning.AI | Intermediate | Intermediate | Embeddings, GenAI Applications, RAG, Search and Retrieval, Vector Databases | A comprehensive course covering vector database concepts and their applications. |\n| Large Language Models with Semantic Search | DeepLearning.AI | Beginner | 1 Hour | Embeddings, NLP, RAG, Search and Retrieval, Vector Databases | Shows how to use vector databases for semantic search with LLMs. |\n| Building Applications with Vector Databases | DeepLearning.AI | Beginner | Beginner | Anomaly Detection, Embeddings, MultiModal, Vector Databases | This course focuses on practical applications of vector databases. |'}
# 2024-10-27 17:37:37.895 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm fascinated by Generative AI and want to build applications with it. What courses should I take?", 'Answer': 'Generative AI is a hot topic! Here are some courses to get you started with building applications:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Introduction to Generative AI | Google Cloud Skill Boost | Beginner | 45 minutes | Generative AI, Deep Learning, Artificial Intelligence, AI, Image Generation, Text Generation | Provides a foundational understanding of Generative AI concepts. |\n| Generative AI for Developers | Google Cloud Skill Boost | Beginner | ~4 hours | Image Generation, GAN, Generative Adversarial Networks, Deep Learning, Neural Network, Image Synthesis, Computer Vision | Focuses on building image generation applications using Generative Adversarial Networks (GANs). |\n| ChatGPT Prompt Engineering for Developers | DeepLearning.AI | Beginner | 1 Hour | GenAI Applications, Prompt Engineering, Transformers | This course teaches you how to use prompt engineering to build applications with ChatGPT. |\n| Building Systems with the ChatGPT API | DeepLearning.AI | Beginner | 1 hour | AI Safety, Chatbots, GenAI Applications, Generative Models, Prompt Engineering | This course focuses on using the ChatGPT API to build more complex applications. |'}
# 2024-10-27 17:37:37.897 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I am an experienced ML engineer and want to learn about deploying and scaling ML models in production. What resources would you recommend?', 'Answer': 'For experienced ML engineers like you, these resources focus on productionizing ML models:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Machine Learning in Production | DeepLearning.AI | Intermediate | 4 months | Data Engineering, Deep Learning, MLOps | Covers the entire ML lifecycle, including deployment and scaling in production. |\n| TensorFlow: Data and Deployment Specialization | DeepLearning.AI | Intermediate | 2-6 Months | Data Processing, MLOps, On-Device AI | Focuses on data processing and deployment techniques for TensorFlow models. |\n| LLMOps | DeepLearning.AI | Beginner | Beginner | AI Safety, Chatbots, Data Processing, Evaluation and Monitoring, Fine-Tuning, LLMOps | This course provides an introduction to LLMOps, covering best practices for deploying and managing LLMs in production. |'}
# 2024-10-27 17:37:37.898 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': 'I want to learn about the ethical considerations and potential biases in AI. What courses can help me understand these issues?', 'Answer': "Understanding AI ethics is crucial. These courses can provide valuable insights:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| AI Ethics Resources | IBM | Intermediate | ~30 minutes | AI Ethics, Artificial Intelligence, AI, Responsible AI | Explores fundamental AI ethics principles and concerns. |\n| Introduction to Responsibe AI | Google Cloud Skill Boost | Beginner | 20 minutes | Responsible AI, Ethics, AI Ethics, Fairness, BIas, Transparency | Introduces responsible AI principles and how to apply them in practice. |\n| Fairness in Perspective API | Google Developers | Advanced | ~1.5 hours | Fairness, AI, Bias |  Focuses on identifying and mitigating bias in AI systems using Google's Perspective API. |\n| AI for Good | DeepLearning.AI | Beginner | 2-4 Weeks | Computer Vision, Data Processing, GenAI Applications, NLP, Supervised Learning | This course explores how AI can be used for social good, including ethical considerations. |"}
# 2024-10-27 17:37:37.899 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm interested in exploring advanced techniques for optimizing machine learning models. What courses would you suggest?", 'Answer': 'For advanced model optimization, consider these courses:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Machine Learning Advance Courses | Google Developers | Advanced | Variable | Decision Forests, Recommendation Systems, Clustering, GAN, Image Classification, Fairness | A collection of advanced courses covering specific ML areas like decision forests, recommendation systems, and GANs. |\n| TensorFlow: Advanced Techniques Specialization | DeepLearning.AI | Intermediate | 5 months | | Delves into advanced TensorFlow techniques for optimizing model performance. |\n| Optimization | Google Cloud Skill Boost | Advanced | ~1 hour | Optimization, loss function, Gradient descent, confusion Matrix, Model evaluation | This course focuses on optimization techniques for machine learning models. |\n| Vertex Vizier Hyperparameter Tuning | Google Cloud Skill Boost | Advanced | ~3 hours | Vertex, Hyperparameter tuning | This course teaches you how to use Vertex Vizier for hyperparameter tuning. |'}
# 2024-10-27 17:37:37.904 | INFO     | __main__:multiturn_generate_content:69 - Successfully processs Q-A set: {'Question': "I'm a data scientist and want to improve my skills in data preparation and feature engineering for machine learning. What courses can help me?", 'Answer': 'Data preparation and feature engineering are essential for successful ML. These courses can enhance your skills:\n\n| Course/Module | Source | Level | Duration (Estimate) | Keywords | Reason |\n|---------------|--------|-------|----------------------|----------|--------|\n| Data Preparation and Feature Engineering in ML | Google Developers | Intermediate | ~2 hours | data preparation, feature engineering, model, algorithm | Covers key concepts and techniques for preparing data and engineering features. |\n| Feature Engineering | Google Cloud Skill Boost | Advanced | 7 hours | Tensorflow, Machine learning, Features, Vertex AI |  A comprehensive course on feature engineering, including advanced techniques using TensorFlow and Vertex AI. |\n| Data Engineering | DeepLearning.AI | Intermediate | 15 weeks | Data Engineering, Data Processing, Deep Learning, Search and Retrieval | This course focuses on data engineering principles and practices. |'}
# 2024-10-27 17:37:37.905 | ERROR    | __main__:multiturn_generate_content:71 - Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping this q-a set
# 2024-10-27 17:37:37.907 | INFO     | __main__:multiturn_generate_content:90 - Final results
#  dataset size: 56
#  time elapse: 977.5552821159363
# 2024-10-27 17:37:37.914 | INFO     | __main__:<cell line: 125>:143 -
# Final results
#  dataset size: 68
#  time elapse: 977.57 Seconds

# %% [markdown]
# ## Data Postprocessing

# %%
import json
from loguru import logger


# Open the original JSONL file and read the contents
with open("/content/Q_A (1).jsonl", "r") as f:
    lines = f.readlines()

# Create a new list to store the modified lines
modified_lines = []

# Loop through each line, parse it as JSON, modify, and store it
for line in lines:
    try:
        # Parse the line into a dictionary
        data = json.loads(line)

        # Normalize the 'answer' key to account for different cases
        answer_key = "answer" if "answer" in data else "Answer"

        # Modify the dictionary
        new_data = {
            "instruction": data["question"],  # Change 'question' to 'instruction'
            "context": "",                    # Add a blank 'context' field
            "output": data[answer_key]        # Use the normalized 'answer' or 'Answer'
        }

        # Convert the modified dictionary back to a JSON-formatted string
        modified_line = json.dumps(new_data)

        # Append to the list of modified lines
        modified_lines.append(modified_line)

    except KeyError:
        # Skip this entry if the expected key is missing
        logger.warning(f"Skipping entry due to missing 'answer' or 'Answer' key: {line}")
        continue

# Write the modified lines to a new JSONL file
with open("/content/modified_Q_A.jsonl", "w") as f:
    for line in modified_lines:
        f.write(line + "\n")

logger.info("File transformation complete.")

# %%
import json

# Open the original JSONL file and read the contents
with open("/content/QA_LPI.jsonl, "r") as f:
    lines = f.readlines()

for line in lines:
  try:

    data = json.loads(line)
    # Normalize the 'answer' key to account for different cases
    answer_key = "answer" if "answer" in data else "Answer"

    new_data = {
        "question": data["question"],  # Change 'question' to 'instruction'                   #
        "answer": data[answer_key]        # Use the normalized 'answer' or 'Answer'
    }

    with open("/content/new_CAD_QA.jsonl", "a") as f:
      json.dump(new_data, f)
      f.write("\n")  # Write a newline character to ensure each entry starts on a new line

  except json.JSONDecodeError:
    logger.warning(f"Skipping entry due to missing json stuff' {line}")

  except KeyError as e:
        logger.warning(f"Skipping entry due to missing 'answer' or 'Answer' key: {line}")
        continue  # Skip this iteration if a key is missing
