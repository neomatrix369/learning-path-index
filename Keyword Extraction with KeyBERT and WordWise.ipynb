# %% [markdown]
# <a href="https://www.kaggle.com/code/manishkr1754/keyword-extraction-with-keybert-and-wordwise?scriptVersionId=145452236" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <center><h1> Keyword Extraction with KeyBERT and WordWise</h1></center>
#
# ---
#
# <center><h3>Comparison, Parameter Tuning & Evaluation</h3></center>

# %% [markdown]
# # Process Flow of the Keyword Extraction
# ---
#
# - 1. Getting System Ready
# - 2. Data Collection
# - 3. Data Eyeballing
# - 4. Data Preprocessing
# - 5. Keyword Extraction
#     - 5.1 KeyBERT
#     - 5.2 WordWise
# - 6. Exporting Output as Excel File

# %% [markdown]
# ## 1) Getting System Ready
# ---
#
# Importing Required Packages

# %%
# !pip install xlsxwriter -q
# !pip install keybert -q
# !pip install wordwise -q

# %% [markdown]
# 1. `!pip install xlsxwriter -q`: This installs the `xlsxwriter` library, which is used for creating Excel files in Python. The `-q` flag suppresses verbose output, so you won't see detailed installation messages.
#
# 2. `!pip install keybert -q`: This installs the `keybert` library, which is a Python library for keyword extraction using BERT embeddings. Again, the `-q` flag suppresses verbose output during installation.
#
# 3. `!pip install wordwise -q`: This installs the `wordwise` library, which is another library for keyword extraction. The `-q` flag is used to keep the installation process quiet.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from pprint import pprint
import xlsxwriter
from keybert import KeyBERT
from wordwise import Extractor

# %% [markdown]
# - `requests`: This library allows you to send HTTP requests to web servers and retrieve data from websites. It's commonly used for web scraping and accessing web APIs.
#
# - `BeautifulSoup`: BeautifulSoup is a popular Python library for parsing and navigating HTML and XML documents. It helps you extract and manipulate data from web pages easily.
#
# - `pandas`: Pandas is a powerful data manipulation and analysis library. It provides data structures like DataFrames and Series, making it efficient for data cleaning, transformation, and analysis.
#
# - `json`: The `json` module in Python is used for working with JSON (JavaScript Object Notation) data. It allows you to parse JSON strings and serialize Python objects into JSON format.
#
# - `pprint`: The `pprint` module provides a way to pretty-print Python data structures, making complex data easier to read and understand when printed to the console.
#
# - `xlsxwriter`: XlsxWriter is a Python library for creating Excel files (XLSX format). It allows you to generate Excel spreadsheets with various formatting options.
#
# - `KeyBERT`: KeyBERT is a Python library for keyword extraction that leverages BERT embeddings. It's useful for extracting meaningful keywords from text data.
#
# - `wordwise`: Wordwise is another Python library for keyword extraction. It provides a different approach to keyword extraction compared to BERT-based methods.

# %% [markdown]
# ## 2) Data Collection
# ---
# We aim to gather the necessary data from the **Google Cloud Skill Boost Course** website like module and submodule names along with their descriptions, which will serve as our input for keyword extraction.
#
# - **Data Source:** Our primary data source is the "Google Cloud Skill Boost Course" website which contains information about various modules and submodules within the course. These modules are accompanied by descriptions that provide insights into their content.
#
# - **Data Extraction Technique:** We will utilize **Web Scraping** techniques to extract the relevant data from the website. Specifically, we will use the Python library **BeautifulSoup** to parse the HTML content of the web pages and extract module and submodule names along with their descriptions.

# %% [markdown]
# #### Step-1: Define url of the Course Page

# %%
url = "https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&search_id=25346338"
url
# Out:
# 'https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&search_id=25346338'

# %% [markdown]
# #### Step-2: Send an HTTP GET request to fetch the page content

# %%
response_from_page = requests.get(url)
response_from_page
# Out:
# <Response [200]>

# %% [markdown]
# The **<Response [200]>** is standard HTTP response code indicating a successful request. It means that the request to the website was successful and the server has returned the expected response. We can now proceed to parse the content of the web page using BeautifulSoup or another HTML parsing library.
#
# **Common Response Code**
# - `200 OK`: The request was successful and the server has returned the requested data.
# - `404 Not Found`: The requested resource was not found on the server.
# - `403 Forbidden`: Access to the requested resource is forbidden.
# - `500 Internal Server Error`: An error occurred on the server while processing the request.

# %% [markdown]
# #### Step-3: Parse the HTML content with BeautifulSoup

# %%
soup = BeautifulSoup(response_from_page.content, "html.parser")

# %% [markdown]
# - `soup = BeautifulSoup(response_from_page.content, "html.parser")`: This line of code parses the HTML content of the page using BeautifulSoup's HTML parser and stores the parsed data in the `soup` variable. Now, we can navigate and extract information from the parsed HTML.

# %% [markdown]
# #### Step-4: Extracting Information from Parsed HTML Data

# %%
ql_course = soup.find("ql-course")
modules = ql_course.attrs['modules']

# %% [markdown]
# - `ql_course = soup.find("ql-course")`: Here `find()` method is used to locate the first occurrence of an HTML element with the tag name "ql-course" within the parsed HTML. The result is stored in the `ql_course` variable.
#
# - `modules = ql_course.attrs['modules']`: Assuming that the "ql-course" element has an attribute named "modules," this line extracts the value of that attribute and stores it in the `modules` variable.

# %% [markdown]
# ## 3) Data Eyeballing
# ---

# %% [markdown]
# #### Parsed HTML Data

# %%
print(type(soup))
print("\n\n")
print(soup)
# Out:
# <class 'bs4.BeautifulSoup'>
#
#
#
#
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Building Batch Data Pipelines on Google Cloud | Google Cloud Skills Boost</title>
# <meta content="/cable" name="action-cable-url"/>
# <script>
# //<![CDATA[
# window.gon={};gon.deployment="google-run";
# //]]>
# </script>
# <script>
#   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer',"GTM-5XSKHDX");
# </script>
# <script async="async" src="https://www.googletagmanager.com/gtag/js?id=G-2X30ZRBDSG"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', "G-2X30ZRBDSG", {
#     user_id: ""
#   });
# </script>
# <script src="https://cdn.qwiklabs.com/assets/hallofmirrors/polyfills/webcomponents-loader-8583b47b01e40e6ea7bf1ad443a20b7e79bbdd5eafac009806a228c91a97282c.js"></script>
# <script src="https://cdn.qwiklabs.com/assets/vendor-613520545532a2795a401a8168ca8b698b9ee765a66f5ad9ead806b5c32eabe8.js"></script>
# <script src="https://cdn.qwiklabs.com/assets/application-c2770981ed24312fa69ad807ef5d06802f708af0e74810f52be4c583f7ed041b.js"></script>
# <script src="https://cdn.qwiklabs.com/assets/hallofmirrors/hallofmirrors-a6c0129b2af190dd61671b901bc50cb81175f5b4b8df491a433759be034ea9ab.js"></script>
# <!--[if lt IE 9]>  <![endif]-->
# <script src="http://html5shim.googlecode.com/svn/trunk/html5.js" type="text/javascript"></script>
# <!--[endif]>  <![endif]-->
# <script type="application/ld+json">
# {"@context":"https://schema.org/","@id":"https://www.cloudskillsboost.google/course_templates/53","@type":"Course","name":"Building Batch Data Pipelines on Google Cloud","description":"\u003cp\u003eData pipelines typically fall under one of the Extra-Load, Extract-Load-Transform or Extract-Transform-Load paradigms. This course describes which paradigm should be used and when for batch data. Furthermore, this course covers several technologies on Google Cloud for data transformation including BigQuery, executing Spark on Dataproc, pipeline graphs in Cloud Data Fusion and serverless data processing with Dataflow. Learners will get hands-on experience building data pipeline components o...","educationalLevel":"Beginner","image":["https://cdn.qwiklabs.com/8uLByazcRHEALOwxBVZqyJgmaD8%2FQTvrCDwP1c07dmo%3D"],"provider":{"@type":"Organization","name":"Google Cloud Skills Boost","url":"https://cloudskillsboost.google"},"publisher":{"@type":"Organization","name":"Google Cloud","url":"https://cloud.google.com/learn"},"datePublished":"2023-05-17","inLanguage":"en","availableLanguage":["en"],"offers":[{"@type":"Offer","category":"Partially Free"},{"@type":"Offer","category":"Subscription"}],"hasCourseInstance":[{"@type":"CourseInstance","courseMode":"Online","courseWorkload":"P1D"}]}
# </script>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="cS05F54Wq3Qqi7oyPTjKx3sZBhGsuSekUP10p3TL/+WmQsquX86FiHK0FH1beJA8El050uSwG1uUjfbT3n1Mog==" name="csrf-token"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="1rRsY0INj8RvwB5EF5pwdxt2A2P9aDgAlsICaJ0d5w0" name="google-site-verification"/>
# <meta content="#3681E4" property="msapplication-TileColor"/>
# <meta content="/favicon-144.png" property="msapplication-TileImage"/>
# <meta content='[{"id":"recaptcha_experiment","optimize_id":"dpViOcLkT3qS4TvL2mRojA","title":"No Recaptcha shown for trusted users","variant_index":0,"variant":"original"}]' name="active-experiments"/>
# <meta content='{"userId":null,"experimentIds":["course_upgrade","canonical_domain_redirect","program_resources","program_learning_assignment","program_announcements","peer_assignment","teams","oauth_risc_shutoff","search_updates","show_annual_purchase_now","programs","used_in","barker","program_groups","enforce_codebuild_verdicts","chat_off_for_signed_out_users","community_forum","alexandria_show_bundle_errors"]}' name="help-api-product-data"/>
# <meta content='{"groupIds":[]}' name="help-api-custom-data"/>
# <meta content="&amp;lt;p&amp;gt;Data pipelines typically fall under one of the Extra-Load, Extract-Load-Transform or Extract-Transform-Load paradigms. This course describes which paradigm should be used and when for batch data. Furthermore, this course covers several technologies on Google Cloud for data transformation including BigQuery, executing Spark on Dataproc, pipeline graphs in Cloud Data Fusion and serverless data processing with Dataflow. Learners will get hands-on experience building data pipeline components on Google Cloud using Qwiklabs.&amp;lt;/p&amp;gt;" name="description"/>
# <meta content="Qwiklabs" name="author"/>
# <meta content="Building Batch Data Pipelines on Google Cloud | Google Cloud Skills Boost" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="/favicon-144.png" property="og:image"/>
# <meta content="Qwiklabs" property="og:site_name"/>
# <meta content="&amp;lt;p&amp;gt;Data pipelines typically fall under one of the Extra-Load, Extract-Load-Transform or Extract-Transform-Load paradigms. This course describes which paradigm should be used and when for batch data. Furthermore, this course covers several technologies on Google Cloud for data transformation including BigQuery, executing Spark on Dataproc, pipeline graphs in Cloud Data Fusion and serverless data processing with Dataflow. Learners will get hands-on experience building data pipeline components on Google Cloud using Qwiklabs.&amp;lt;/p&amp;gt;" property="og:description"/>
# <meta content="/qwiklabs_logo_900x887.png" property="og:logo" size="900x887"/>
# <meta content="/qwiklabs_logo_994x187.png" property="og:logo" size="994x187"/>
# <meta content="https://www.cloudskillsboost.google/course_templates/53" property="og:url"><link href="https://www.cloudskillsboost.google/course_templates/53" rel="canonical"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ar&amp;search_id=25346338" hreflang="ar" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=de&amp;search_id=25346338" hreflang="de" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=es&amp;search_id=25346338" hreflang="es" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=fr&amp;search_id=25346338" hreflang="fr" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=fr_CA&amp;search_id=25346338" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=he&amp;search_id=25346338" hreflang="he" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=id&amp;search_id=25346338" hreflang="id" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=it&amp;search_id=25346338" hreflang="it" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ja&amp;search_id=25346338" hreflang="ja" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ko&amp;search_id=25346338" hreflang="ko" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pl&amp;search_id=25346338" hreflang="pl" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pt_BR&amp;search_id=25346338" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pt_PT&amp;search_id=25346338" hreflang="pt-PT" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ru&amp;search_id=25346338" hreflang="ru" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=tr&amp;search_id=25346338" hreflang="tr" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=uk&amp;search_id=25346338" hreflang="uk" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=zh&amp;search_id=25346338" hreflang="zh" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=zh_TW&amp;search_id=25346338" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;search_id=25346338" hreflang="en" rel="alternate"/>
# <link href="https://www.cloudskillsboost.google/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;search_id=25346338" hreflang="x-default" rel="alternate"/>
# <link color="#3681E4" href="/favicon-svg.svg" rel="mask-icon"/>
# <link href="/favicon-180.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://cdn.qwiklabs.com/X46FrQX4iLxHW5MxL8jICvgZM0evMEKscCeQO%2BazGdo%3D" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com/css?family=Oswald:400|Roboto+Mono:400,700|Roboto:300,400,500,700|Google+Sans:300,400,500,700|Google+Sans+Display:400|Material+Icons|Google+Material+Icons|Google+Sans+Text:400,500,700" media="screen" rel="stylesheet">
# <link href="https://cdn.qwiklabs.com/assets/application-e9a2156b865ab64b2dad2836aa309fedf85704d2ab19d4c8a3cdd85cabbd8364.css" media="all" rel="stylesheet">
# <link href="https://www.gstatic.com/glue/cookienotificationbar/cookienotificationbar.min.css" media="screen" rel="stylesheet">
# <style>
#   :root {
#     --primary-text-on-surface-color: #1a73e8;
#     --primary-text-on-surface-color-dark: #1568d6;
#     --primary-text-on-surface-color-darker: #135ec1;
#     --primary-text-on-surface-color-darkest: #1154ac;
#     --primary-surface-color: #1a73e8;
#     --primary-surface-color-rgb: 26,115,232;
#     --primary-surface-color-light: #d1e3fa;
#     --primary-surface-color-lightest: #e8f1fd;
#     --text-on-primary-color: #ffffff;
#     --accent-text-on-surface-color: #f29900;
#     --accent-surface-color: #f9ab00;
#     --accent-surface-color-rgb: 249,171,0;
#     --accent-surface-color-light: #ffefcc;
#     --text-on-accent-color: #202124;
#   }
# </style>
# <style>
#   :root {
#     --navbar-height: 112px;
#   }
# </style>
# </link></link></link></meta></head>
# <body class="course-template-show-body course-layout-body l-full no-nav learner-layout-body">
# <ql-drawer-container class="body-container">
# <ql-drawer id="app-nav" mode="over" slot="drawer" width="288">
# <div class="nav-panel__logo">
# <div class="custom-logo"><img alt="Google Cloud Skills Boost" aria-label="Google Cloud Skills Boost" height="24" src="https://cdn.qwiklabs.com/PGyhmgS3zZncIEGywnx5UXsKwepRRFQ9BhAg%2FWHNrlQ%3D"/></div>
# </div>
# <nav class="ql-sidenav">
# <ql-sidenav-item href="/" icon="home" label="Paths"></ql-sidenav-item>
# <ql-sidenav-item href="/catalog" icon="school" label="Explore"></ql-sidenav-item>
# </nav>
# </ql-drawer>
# <ql-drawer-content class="body-content" slot="drawer-content">
# <ql-toolbar class="sticky app-toolbar" jumpenabled="" role="banner">
# <div class="toolbar-navigation" slot="navigation">
# <ql-toggle-button class="" for="app-nav" icon="menu" label="Toggle navigation drawer" tip="Menu"></ql-toggle-button>
# </div>
# <div class="toolbar-title ql-headline-6" slot="title"><a aria-label="Google Cloud Skills Boost" class="custom-logo" href="/"><div class="custom-logo"><img alt="Google Cloud Skills Boost" aria-label="Google Cloud Skills Boost" height="24" src="https://cdn.qwiklabs.com/PGyhmgS3zZncIEGywnx5UXsKwepRRFQ9BhAg%2FWHNrlQ%3D"/></div></a>
# </div>
# <div class="toolbar-tabs" role="tablist" slot="tabs"><ql-tab href="/" label="Paths"></ql-tab>
# <ql-tab active="" href="/catalog" label="Explore"></ql-tab>
# <ql-tab href="/subscriptions" label="Subscriptions"></ql-tab>
# </div>
# <div class="toolbar-actions" slot="action">
# <ql-icon-button class="mobile-hide" icon="help_outline" id="help-menu-button" label="Open help menu" tip="Help"></ql-icon-button>
# <ql-menu for="help-menu-button" id="help-menu">
# <ql-menu-item data-analytics-action="opened_help" data-analytics-label="course" label="Help Center" onclick='hallofmirrors.helpService.startHelp({"productData":{"userId":null},"context":"course"})'></ql-menu-item>
# <ql-menu-item href="mailto:support@qwiklabs.com" label="Email support"></ql-menu-item>
# </ql-menu>
# <ql-icon-button class="mobile-hide" icon="language" id="language" label="Select your language preference" tip="Language"></ql-icon-button>
# <ql-menu for="language">
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="ar" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ar&amp;search_id=25346338" label="العربية‬‎" lang="ar"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="de" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=de&amp;search_id=25346338" label="Deutsch" lang="de"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="en" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=en&amp;search_id=25346338" label="English" lang="en"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="es" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=es&amp;search_id=25346338" label="español (Latinoamérica)" lang="es"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="fr" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=fr&amp;search_id=25346338" label="français" lang="fr"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="fr_CA" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=fr_CA&amp;search_id=25346338" label="français (Canada)" lang="fr-CA"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="he" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=he&amp;search_id=25346338" label="עברית" lang="he"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="id" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=id&amp;search_id=25346338" label="bahasa Indonesia" lang="id"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="it" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=it&amp;search_id=25346338" label="Italiano" lang="it"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="ja" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ja&amp;search_id=25346338" label="日本語" lang="ja"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="ko" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ko&amp;search_id=25346338" label="한국어" lang="ko"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="pl" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pl&amp;search_id=25346338" label="Polski" lang="pl"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="pt_BR" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pt_BR&amp;search_id=25346338" label="português (Brasil)" lang="pt-BR"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="pt_PT" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=pt_PT&amp;search_id=25346338" label="português (Portugal)" lang="pt-PT"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="ru" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=ru&amp;search_id=25346338" label="русский" lang="ru"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="tr" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=tr&amp;search_id=25346338" label="Türkçe" lang="tr"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="uk" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=uk&amp;search_id=25346338" label="український" lang="uk"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="zh" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=zh&amp;search_id=25346338" label="简体中文" lang="zh"></ql-menu-item>
# <ql-menu-item data-analytics-action="changed_locale" data-analytics-label="zh_TW" href="/course_templates/53?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&amp;locale=zh_TW&amp;search_id=25346338" label="繁體中文" lang="zh-TW"></ql-menu-item>
# </ql-menu>
# <ql-button data-analytics-action="clicked_header_sign_in" href="/users/sign_in" label="Sign in" text=""></ql-button>
# <ql-button data-analytics-action="clicked_header_join" href="/users/sign_up" label="Join"></ql-button>
# </div>
# </ql-toolbar>
# <ql-toolbar class="sticky page-toolbar">
# <h1 class="toolbar-title ql-headline-6" slot="title">Google Cloud Skills Boost</h1>
# <div class="toolbar-actions" slot="action"></div>
# </ql-toolbar>
# <main id="jump-content">
# <ql-drawer-container class="course-container">
# <ql-drawer class="course-drawer course-drawer-left" open="" slot="drawer" width="240">
# <div class="course-outline-header">
# <div class="course-info">
# <h2 class="ql-title-medium">
# Building Batch Data Pipelines on Google Cloud
# </h2>
# </div>
# </div>
# <ql-course-outline coursepath="/course_templates/53" modules='[{"id":"59338","title":"Introduction","description":"\u003cp\u003eIn this module, we introduce the course and agenda\u003c/p\u003e","steps":[{"id":"386567","prompt":null,"isOptional":true,"activities":[{"id":"379215","href":null,"isLocked":false,"duration":55000,"title":"Course Introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59339","title":"Introduction to Building Batch Data Pipelines","description":"\u003cp\u003eThis module reviews different methods of data loading: EL, ELT and ETL and when to use what\u003c/p\u003e","steps":[{"id":"386568","prompt":null,"isOptional":true,"activities":[{"id":"379216","href":null,"isLocked":false,"duration":69000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386569","prompt":null,"isOptional":true,"activities":[{"id":"379217","href":null,"isLocked":false,"duration":220000,"title":"EL, ELT, ETL","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386570","prompt":null,"isOptional":true,"activities":[{"id":"379218","href":null,"isLocked":false,"duration":168000,"title":"Quality considerations","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386571","prompt":null,"isOptional":true,"activities":[{"id":"379219","href":null,"isLocked":false,"duration":180000,"title":"How to carry out operations in BigQuery","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386572","prompt":null,"isOptional":true,"activities":[{"id":"379220","href":null,"isLocked":false,"duration":208000,"title":"Shortcomings","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386573","prompt":null,"isOptional":true,"activities":[{"id":"379221","href":null,"isLocked":false,"duration":428000,"title":"ETL to solve data quality issues","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386574","prompt":null,"isOptional":false,"activities":[{"id":"379222","href":null,"isLocked":false,"duration":0,"title":"Introduction to Building Batch Data Pipelines","type":"quiz","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59340","title":"Executing Spark on Dataproc","description":"\u003cp\u003eThis module shows how to run Hadoop on Dataproc, how to leverage Cloud Storage, and how to optimize your Dataproc jobs.\u003c/p\u003e","steps":[{"id":"386575","prompt":null,"isOptional":true,"activities":[{"id":"379223","href":null,"isLocked":false,"duration":27000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386576","prompt":null,"isOptional":true,"activities":[{"id":"379224","href":null,"isLocked":false,"duration":286000,"title":"The Hadoop ecosystem","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386577","prompt":null,"isOptional":true,"activities":[{"id":"379225","href":null,"isLocked":false,"duration":602000,"title":"Running Hadoop on Dataproc","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386578","prompt":null,"isOptional":true,"activities":[{"id":"379226","href":null,"isLocked":false, ...
# </ql-drawer>
# <ql-drawer-content class="course-activity" slot="drawer-content">
# <div class="course-activity-header">
# <div class="breadcrumbs ql-label-medium">
# <a href="/course_templates/53">Building Batch Data Pipelines on Google Cloud</a>
# <ql-icon>navigate_next</ql-icon>
# Overview
# </div>
# </div>
# <div class="course-activity-content">
# <div class="course-wrapper">
# <div class="course-top-matter">
# <div class="course-title">
# <ql-activity-label activity="course"></ql-activity-label>
# <div class="title-text">
# <h1 class="ql-headline-1">Building Batch Data Pipelines on Google Cloud</h1>
# </div>
# </div>
# <div class="course-details">
# <span class="course-detail">
# <ql-icon icon="date_range"></ql-icon>
# 3 days
# </span>
# <span class="course-detail">
# <ql-icon icon="show_chart"></ql-icon>
# Introductory
# </span>
# <span class="course-detail">
# <ql-icon>universal_currency_alt</ql-icon>
# 45 Credits
# </span>
# </div>
# <div class="course-description"><p>Data pipelines typically fall under one of the Extra-Load, Extract-Load-Transform or Extract-Transform-Load paradigms. This course describes which paradigm should be used and when for batch data. Furthermore, this course covers several technologies on Google Cloud for data transformation including BigQuery, executing Spark on Dataproc, pipeline graphs in Cloud Data Fusion and serverless data processing with Dataflow. Learners will get hands-on experience building data pipeline components on Google Cloud using Qwiklabs.</p></div>
# <div class="course-badge">
# <img alt="Badge for Building Batch Data Pipelines on Google Cloud" src="https://cdn.qwiklabs.com/1hVzGcLHWb4EK2Ikakf2Gbd%2FxmXnp7%2BGzoGQfihCAfg%3D"/>
# <p>When you complete this course, you can earn the badge displayed above! View all the badges you have earned by visiting your profile page. Boost your cloud career by showing the world the skills you have developed!</p>
# </div>
# <div class="course-registration">
# <ql-button href="/users/sign_up" label="Join to enroll in this course"></ql-button>
# </div>
# </div>
# <div class="course-curriculum">
# <ql-course courseid="12305" modules='[{"id":"59338","title":"Introduction","description":"\u003cp\u003eIn this module, we introduce the course and agenda\u003c/p\u003e","steps":[{"id":"386567","prompt":null,"isOptional":true,"activities":[{"id":"379215","href":null,"isLocked":false,"duration":55000,"title":"Course Introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59339","title":"Introduction to Building Batch Data Pipelines","description":"\u003cp\u003eThis module reviews different methods of data loading: EL, ELT and ETL and when to use what\u003c/p\u003e","steps":[{"id":"386568","prompt":null,"isOptional":true,"activities":[{"id":"379216","href":null,"isLocked":false,"duration":69000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386569","prompt":null,"isOptional":true,"activities":[{"id":"379217","href":null,"isLocked":false,"duration":220000,"title":"EL, ELT, ETL","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386570","prompt":null,"isOptional":true,"activities":[{"id":"379218","href":null,"isLocked":false,"duration":168000,"title":"Quality considerations","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386571","prompt":null,"isOptional":true,"activities":[{"id":"379219","href":null,"isLocked":false,"duration":180000,"title":"How to carry out operations in BigQuery","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386572","prompt":null,"isOptional":true,"activities":[{"id":"379220","href":null,"isLocked":false,"duration":208000,"title":"Shortcomings","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386573","prompt":null,"isOptional":true,"activities":[{"id":"379221","href":null,"isLocked":false,"duration":428000,"title":"ETL to solve data quality issues","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386574","prompt":null,"isOptional":false,"activities":[{"id":"379222","href":null,"isLocked":false,"duration":0,"title":"Introduction to Building Batch Data Pipelines","type":"quiz","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59340","title":"Executing Spark on Dataproc","description":"\u003cp\u003eThis module shows how to run Hadoop on Dataproc, how to leverage Cloud Storage, and how to optimize your Dataproc jobs.\u003c/p\u003e","steps":[{"id":"386575","prompt":null,"isOptional":true,"activities":[{"id":"379223","href":null,"isLocked":false,"duration":27000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386576","prompt":null,"isOptional":true,"activities":[{"id":"379224","href":null,"isLocked":false,"duration":286000,"title":"The Hadoop ecosystem","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386577","prompt":null,"isOptional":true,"activities":[{"id":"379225","href":null,"isLocked":false,"duration":602000,"title":"Running Hadoop on Dataproc","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386578","prompt":null,"isOptional":true,"activities":[{"id":"379226","href":null,"isLocked":false,"duration":379000,"title" ...
# <ql-collapsible class="course-info">
# <div class="course-info-header" slot="header">
# <ql-icon>info</ql-icon>
# <div class="ql-subhead-1">Course Info</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# <ql-expandable-list>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Objectives</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# <ul>
# <li>
#     Review different methods of data loading: EL, ELT and ETL and when to use what
#   </li>
# <li>
#     Run Hadoop on Dataproc, leverage Cloud Storage, and optimize Dataproc jobs
#   </li>
# <li>
#     Build your data processing pipelines using Dataflow
#   </li>
# <li>
#     Manage data pipelines with Data Fusion and Cloud Composer
#   </li>
# </ul>
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Prerequisites</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# To benefit from this course, participants should have completed “Google Cloud Big Data and Machine Learning Fundamentals” or have equivalent experience. Participant should also have: • Basic proficiency with a common query language such as SQL. • Experience with data modeling and ETL (extract, transform, load) activities. • Experience with developing applications using a common programming language such as Python. • Familiarity with machine learning and/or statistics
#
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Audience</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# Developers responsible for designing pipelines and architectures for data processing.
#
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Available languages</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# English
#
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">What do I do when I finish this course?</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# After finishing this course, you can explore additional content in your learning path or browse the catalog.
#
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">What badges can I earn?</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# Upon finishing the required items in a course, you will earn a badge of completion. Badges can be viewed on your profile and shared with your social network.
#
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Interested in taking this course with one of our authorized on-demand partners? </div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# Explore Google Cloud content on <a href="https://www.coursera.org/googlecloud" target="_blank"> Coursera </a> and <a href="https://www.pluralsight.com/authors/google-cloud" target="_blank"> Pluralsight. </a>
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Prefer learning with an instructor? </div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# View the public classroom schedule <a href="https://cloud.google.com/training/courses" target="_blank"> here. </a>
# </div>
# </ql-collapsible>
# <ql-collapsible>
# <div slot="header">
# <div class="ql-subhead-2">Can I take this course for free?</div>
# </div>
# <div class="ql-body-2" slot="collapsible">
# When you enroll into most courses, you will be able to consume course materials like videos and documents for free. If a course consists of labs, you will need to purchase an individual subscription or credits to be able consume the labs. Labs can also be unlocked by any campaigns you participate in. All required activities in a course must be completed to be awarded the completion badge.
#
# </div>
# </ql-collapsible>
# </ql-expandable-list>
# </div>
# </ql-collapsible>
# </div>
# </div>
# </div>
# </ql-drawer-content>
# </ql-drawer-container>
# </main>
# <footer class="application-footer">
# <a href="/privacy_policy" target="_blank">Privacy</a>
# <a href="/terms_of_service">Terms</a>
# <div class="powered-by">
# <span aria-hidden="">Powered by</span>
# <img alt="Powered by Qwiklabs" src="https://cdn.qwiklabs.com/assets/qwiklabs_logo_grayscale-55ad6830defd63d1284618a702f470409d7044b293858d0dbdd7963d5eb16626.svg"/>
# </div>
# </footer>
# </ql-drawer-content>
# </ql-drawer-container>
# <span class="hidden" id="flash-sibling-before"></span>
# <ql-snackbar></ql-snackbar>
# <script data-glue-cookie-notification-bar-category="2B" src="https://www.gstatic.com/glue/cookienotificationbar/cookienotificationbar.min.js"></script>
# <ql-dialog dismissallabel="Cancel" headline="A newer version of this course is available. Your progress will carry over if you choose to upgrade. However, your completion percentage may change if the new version has added or removed any learning activities. Click the preview button to see the course changes before upgrading." icon="error" id="course-session-upgrade-modal">
# <ql-button href="/course_templates/53/preview" label="Preview" slot="action">
# Preview
# </ql-button>
# </ql-dialog>
# <script>
#   $(function() {
#     ql.initMaterialInputs();
#     initChosen();
#     initSearch();
#     initTabs();
#     ql.list.init();
#     ql.favoriting.init();
#     ql.header.myAccount.init();
#     initTooltips();
#     ql.autocomplete.init();
#     ql.modals.init();
#     ql.toggleButtons.init();
#     ql.analytics.init();
#     ql.jumpContent.init();
#
#   });
# </script>
# </body>
# </html>

# %% [markdown]
# #### Information from Parsed HTML Data

# %%
print(type(modules))
print("\n\n")
print(modules)
# Out:
# <class 'str'>
#
#
#
# [{"id":"59338","title":"Introduction","description":"\u003cp\u003eIn this module, we introduce the course and agenda\u003c/p\u003e","steps":[{"id":"386567","prompt":null,"isOptional":true,"activities":[{"id":"379215","href":null,"isLocked":false,"duration":55000,"title":"Course Introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59339","title":"Introduction to Building Batch Data Pipelines","description":"\u003cp\u003eThis module reviews different methods of data loading: EL, ELT and ETL and when to use what\u003c/p\u003e","steps":[{"id":"386568","prompt":null,"isOptional":true,"activities":[{"id":"379216","href":null,"isLocked":false,"duration":69000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386569","prompt":null,"isOptional":true,"activities":[{"id":"379217","href":null,"isLocked":false,"duration":220000,"title":"EL, ELT, ETL","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386570","prompt":null,"isOptional":true,"activities":[{"id":"379218","href":null,"isLocked":false,"duration":168000,"title":"Quality considerations","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386571","prompt":null,"isOptional":true,"activities":[{"id":"379219","href":null,"isLocked":false,"duration":180000,"title":"How to carry out operations in BigQuery","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386572","prompt":null,"isOptional":true,"activities":[{"id":"379220","href":null,"isLocked":false,"duration":208000,"title":"Shortcomings","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386573","prompt":null,"isOptional":true,"activities":[{"id":"379221","href":null,"isLocked":false,"duration":428000,"title":"ETL to solve data quality issues","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386574","prompt":null,"isOptional":false,"activities":[{"id":"379222","href":null,"isLocked":false,"duration":0,"title":"Introduction to Building Batch Data Pipelines","type":"quiz","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false}],"expanded":false},{"id":"59340","title":"Executing Spark on Dataproc","description":"\u003cp\u003eThis module shows how to run Hadoop on Dataproc, how to leverage Cloud Storage, and how to optimize your Dataproc jobs.\u003c/p\u003e","steps":[{"id":"386575","prompt":null,"isOptional":true,"activities":[{"id":"379223","href":null,"isLocked":false,"duration":27000,"title":"Module introduction","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386576","prompt":null,"isOptional":true,"activities":[{"id":"379224","href":null,"isLocked":false,"duration":286000,"title":"The Hadoop ecosystem","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386577","prompt":null,"isOptional":true,"activities":[{"id":"379225","href":null,"isLocked":false,"duration":602000,"title":"Running Hadoop on Dataproc","type":"video","isComplete":false,"inProgress":false,"score":null,"disabled":false}],"isComplete":false,"allActivitiesRequired":false},{"id":"386578","prompt":null,"isOptional":true,"activities":[{"id":"379226","href":null,"isLocked":false,"duration":379000,"title":"Cloud Storage instead of HDFS","typ ...

# %% [markdown]
# ## 4) Data Preprocessing
# ___
# Before performing keyword extraction, it is essential to preprocess the data like text cleaning, tokenization and removing stopwords.
#
# 1. **Text Cleaning**: Remove any special characters, HTML tags or irrelevant formatting from the descriptions.
# 2. **Tokenization**: Split the text into individual words or tokens.
# 3. **Stopword Removal**: Eliminate common stopwords from the text.

# %% [markdown]
# #### Converting the extracted `modules` data (JSON string) into a Python dictionary

# %%
json_modules = json.loads(modules)
print(type(json_modules))
print("\n\n")
pprint(json_modules[0])
# Out:
# <class 'list'>
#
#
#
# {'description': '<p>In this module, we introduce the course and agenda</p>',
#  'expanded': False,
#  'id': '59338',
#  'steps': [{'activities': [{'disabled': False,
#                             'duration': 55000,
#                             'href': None,
#                             'id': '379215',
#                             'inProgress': False,
#                             'isComplete': False,
#                             'isLocked': False,
#                             'score': None,
#                             'title': 'Course Introduction',
#                             'type': 'video'}],
#             'allActivitiesRequired': False,
#             'id': '386567',
#             'isComplete': False,
#             'isOptional': True,
#             'prompt': None}],
#  'title': 'Introduction'}

# %% [markdown]
# - `json_modules = json.loads(modules)`: This line uses the `json.loads()` function to convert the `modules` string assumed to be in JSON format into a Python data structure. In this case, it is a list of dictionaries.

# %% [markdown]
# #### Converting to Pandas DataFrame

# %%
df = pd.DataFrame(json_modules)
df
# Out:
#       id                                              title  \
# 0  59338                                       Introduction
# 1  59339      Introduction to Building Batch Data Pipelines
# 2  59340                        Executing Spark on Dataproc
# 3  59341           Serverless Data Processing with Dataflow
# 4  59342  Manage Data Pipelines with Cloud Data Fusion a...
# 5  59343                                     Course Summary
# 6  59344                                   Course Resources
#
#                                          description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module shows how to run Hadoop on Data...
# 3  <p>This module covers using Dataflow to build ...
# 4  <p>This module shows how to manage data pipeli...
# 5                              <p>Course Summary</p>
# 6                    <p>PDF links to all modules</p>
#
#                                                steps  expanded
# 0  [{'id': '386567', 'prompt': None, 'isOptional'...     False
# 1  [{'id': '386568', 'prompt': None, 'isOptional'...     False
# 2  [{'id': '386575', 'prompt': None, 'isOptional'...     False
# 3  [{'id': '386587', 'prompt': None, 'isOptional'...     False
# 4  [{'id': '386604', 'prompt': None, 'isOptional'...     False
# 5  [{'id': '386620', 'prompt': None, 'isOptional'...     False
# 6  [{'id': '386621', 'prompt': None, 'isOptional'...     False

# %%
print('The size of Dataframe is: ', df.shape)
print('-'*100)
print('The Column Name, Record Count and Data Types are as follows: ')
df.info()
print('-'*100)
# Out:
# The size of Dataframe is:  (7, 5)
# ----------------------------------------------------------------------------------------------------
# The Column Name, Record Count and Data Types are as follows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           7 non-null      object
#  1   title        7 non-null      object
#  2   description  7 non-null      object
#  3   steps        7 non-null      object
#  4   expanded     7 non-null      bool
# dtypes: bool(1), object(4)
# memory usage: 359.0+ bytes
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Flattening JSON Data into a Pandas DataFrame

# %%
flatten_df = pd.json_normalize(json_modules, 
                               record_path=['steps', ['activities']], 
                               meta=['id','title', 'description'], 
                               meta_prefix='meta-', 
                               record_prefix='record-')
flatten_df.head(3)
# Out:
#   record-id record-href  record-isLocked  record-duration  \
# 0    379215        None            False            55000
# 1    379216        None            False            69000
# 2    379217        None            False           220000
#
#           record-title record-type  record-isComplete  record-inProgress  \
# 0  Course Introduction       video              False              False
# 1  Module introduction       video              False              False
# 2         EL, ELT, ETL       video              False              False
#
#   record-score  record-disabled meta-id  \
# 0         None            False   59338
# 1         None            False   59339
# 2         None            False   59339
#
#                                       meta-title  \
# 0                                   Introduction
# 1  Introduction to Building Batch Data Pipelines
# 2  Introduction to Building Batch Data Pipelines
#
#                                     meta-description
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...

# %% [markdown]
# This code is taking a JSON data structure with nested arrays, extracting specific nested records while preserving some top-level metadata and converting the structured data into a Pandas DataFrame. The resulting DataFrame will be a tabular representation of the nested JSON data, making it easier to analyze and work with in a tabular format.

# %%
print('The size of Dataframe is: ', flatten_df.shape)
print('-'*100)
print('The Column Name, Record Count and Data Types are as follows: ')
flatten_df.info()
print('-'*100)
# Out:
# The size of Dataframe is:  (58, 13)
# ----------------------------------------------------------------------------------------------------
# The Column Name, Record Count and Data Types are as follows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   record-id          58 non-null     object
#  1   record-href        0 non-null      object
#  2   record-isLocked    58 non-null     bool
#  3   record-duration    58 non-null     int64
#  4   record-title       58 non-null     object
#  5   record-type        58 non-null     object
#  6   record-isComplete  58 non-null     bool
#  7   record-inProgress  58 non-null     bool
#  8   record-score       0 non-null      object
#  9   record-disabled    58 non-null     bool
#  10  meta-id            58 non-null     object
#  11  meta-title         58 non-null     object
#  12  meta-description   58 non-null     object
# dtypes: bool(4), int64(1), object(8)
# memory usage: 4.4+ KB
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Dropping Unwanted Columns

# %%
flatten_df.drop(['record-href', 
                 'record-isLocked', 
                 'record-isComplete', 
                 'record-inProgress',
                 'record-score',
                 'meta-id',
                 'record-id'], axis=1, inplace=True)

# %%
print('The size of Dataframe is: ', flatten_df.shape)
print('-'*100)
print('The Column Name, Record Count and Data Types are as follows: ')
flatten_df.info()
print('-'*100)
# Out:
# The size of Dataframe is:  (58, 6)
# ----------------------------------------------------------------------------------------------------
# The Column Name, Record Count and Data Types are as follows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   record-duration   58 non-null     int64
#  1   record-title      58 non-null     object
#  2   record-type       58 non-null     object
#  3   record-disabled   58 non-null     bool
#  4   meta-title        58 non-null     object
#  5   meta-description  58 non-null     object
# dtypes: bool(1), int64(1), object(4)
# memory usage: 2.4+ KB
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Aggregating and Grouping the Data

# %%
grouped_df = flatten_df.groupby(['meta-title', 'meta-description'])
print(grouped_df.ngroups)
# Out:
# 7

# %% [markdown]
# - There are 7(Seven) unique groups(combinations) of `meta-title` and `meta-description` in the grouped DataFrame

# %%
grouped_df.head()
# Out:
#     record-duration                                   record-title  \
# 0             55000                            Course Introduction
# 1             69000                            Module introduction
# 2            220000                                   EL, ELT, ETL
# 3            168000                         Quality considerations
# 4            180000        How to carry out operations in BigQuery
# 5            208000                                   Shortcomings
# 8             27000                            Module introduction
# 9            286000                           The Hadoop ecosystem
# 10           602000                     Running Hadoop on Dataproc
# 11           379000                  Cloud Storage instead of HDFS
# 12           172000                            Optimizing Dataproc
# 20            53000                            Module introduction
# 21           342000                       Introduction to Dataflow
# 22           171000                   Why customers value Dataflow
# 23           228000            Building Dataflow pipelines in code
# 24           127000    Key considerations with designing pipelines
# 40            19000                            Module introduction
# 41           219000              Introduction to Cloud Data Fusion
# 42            74000                Components of Cloud Data Fusion
# 43            95000                           Cloud Data Fusion UI
# 44           291000                               Build a pipeline
# 56           197000                                 Course Summary
# 57                0  Building Batch Data Pipelines on Google Cloud
#
#    record-type  record-disabled  \
# 0        video            False
# 1        video            False
# 2        video            False
# 3        video            False
# 4        video            False
# 5        video            False
# 8        video            False
# 9        video            False
# 10       video            False
# 11       video            False
# 12       video            False
# 20       video            False
# 21       video            False
# 22       video            False
# 23       video            False
# 24       video            False
# 40       video            False
# 41       video            False
# 42       video            False
# 43       video            False
# 44       video            False
# 56       video            False
# 57    document            False
#
#                                            meta-title  \
# 0                                        Introduction
# 1       Introduction to Building Batch Data Pipelines
# 2       Introduction to Building Batch Data Pipelines
# 3       Introduction to Building Batch Data Pipelines
# 4       Introduction to Building Batch Data Pipelines
# 5       Introduction to Building Batch Data Pipelines
# 8                         Executing Spark on Dataproc
# 9                         Executing Spark on Dataproc
# 10                        Executing Spark on Dataproc
# 11                        Executing Spark on Dataproc
# 12                        Executing Spark on Dataproc
# 20           Serverless Data Processing with Dataflow
# 21           Serverless Data Processing with Dataflow
# 22           Serverless Data Processing with Dataflow
# 23           Serverless Data Processing with Dataflow
# 24           Serverless Data Processing with Dataflow
# 40  Manage Data Pipelines with Cloud Data Fusion a...
# 41  Manage Data Pipelines with Cloud Data Fusion a...
# 42  Manage Data Pipelines with Cloud Data Fusion a...
# 43  Manage Data Pipelines with Cloud Data Fusion a...
# 44  Manage Data Pipelines with Cloud Data Fusion a...
# 56                                     Course Summary
# 57                                   Course Resources
#
#                                      meta-description
# 0   <p>In this module, we introduce the course and...
# 1   <p>This module reviews different methods of da...
# 2   <p>This module reviews different methods of da...
# 3   <p>This module reviews different methods of da...
# 4   <p>This module reviews different methods of da...
# 5   <p>This module reviews different methods of da...
# 8   <p>This module shows how to run Hadoop on Data...
# 9   <p>This module shows how to run Hadoop on Data...
# 10  <p>This module shows how to run Hadoop on Data...
# 11  <p>This module shows how to run Hadoop on Data...
# 12  <p>This module shows how to run Hadoop on Data...
# 20  <p>This module covers using Dataflow to build ...
# 21  <p>This module covers using Dataflow to build ...
# 22  <p>This module covers using Dataflow to build ...
# 23  <p>This module covers using Dataflow to build ...
# 24  <p>This module covers using Dataflow to build ...
# 40  <p>This module shows how to manage data pipeli...
# 41  <p>This module shows how to manage data pipeli...
# 42  <p>This module shows how to manage data pipeli...
# 43  <p>This module shows how to manage data pipeli...
# 44  <p>This module shows how to manage data pipeli...
# 56                              <p>Course Summary</p>
# 57                    <p>PDF links to all modules</p>

# %% [markdown]
# #### Combining 'record-title' within Grouped Data

# %%
flatten_df['text'] = flatten_df.groupby(['meta-title', 
                                         'meta-description'])['record-title'].transform(lambda x:'. '.join(x))
flatten_df.head(10)
# Out:
#    record-duration                                   record-title record-type  \
# 0            55000                            Course Introduction       video
# 1            69000                            Module introduction       video
# 2           220000                                   EL, ELT, ETL       video
# 3           168000                         Quality considerations       video
# 4           180000        How to carry out operations in BigQuery       video
# 5           208000                                   Shortcomings       video
# 6           428000               ETL to solve data quality issues       video
# 7                0  Introduction to Building Batch Data Pipelines        quiz
# 8            27000                            Module introduction       video
# 9           286000                           The Hadoop ecosystem       video
#
#    record-disabled                                     meta-title  \
# 0            False                                   Introduction
# 1            False  Introduction to Building Batch Data Pipelines
# 2            False  Introduction to Building Batch Data Pipelines
# 3            False  Introduction to Building Batch Data Pipelines
# 4            False  Introduction to Building Batch Data Pipelines
# 5            False  Introduction to Building Batch Data Pipelines
# 6            False  Introduction to Building Batch Data Pipelines
# 7            False  Introduction to Building Batch Data Pipelines
# 8            False                    Executing Spark on Dataproc
# 9            False                    Executing Spark on Dataproc
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
# 5  <p>This module reviews different methods of da...
# 6  <p>This module reviews different methods of da...
# 7  <p>This module reviews different methods of da...
# 8  <p>This module shows how to run Hadoop on Data...
# 9  <p>This module shows how to run Hadoop on Data...
#
#                                                 text
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
# 5  Module introduction. EL, ELT, ETL. Quality con...
# 6  Module introduction. EL, ELT, ETL. Quality con...
# 7  Module introduction. EL, ELT, ETL. Quality con...
# 8  Module introduction. The Hadoop ecosystem. Run...
# 9  Module introduction. The Hadoop ecosystem. Run...

# %% [markdown]
# This code is adding a new column named `text` to the Pandas DataFrame `flatten_df`. This new column contains concatenated values from the 'record-title' column within each group defined by the 'meta-title' and 'meta-description' columns which can be useful for various analysis and visualization tasks.

# %% [markdown]
# ## 5) Keyword Extraction
# ___

# %% [markdown]
# ### 5.1) KeyBERT
#
# 1. `model`: (str) The name of the language model to use for keyword extraction. It specifies the pre-trained model architecture, such as 'distilbert-base-nli-mean-tokens', 'roberta-base-nli-stsb-mean-tokens', 'bert-base-nli-mean-tokens', etc.
#
# 2. `top_n`: (int, optional) The number of top keywords to extract. It determines how many keywords will be returned by the model. The default value is 5.
#
# 3. `min_kw`: (int, optional) The minimum number of characters required for a keyword to be considered. Keywords shorter than this length are filtered out. The default value is 1.
#
# 4. `stop_words`: (str or list, optional) A list of stop words to be removed from the extracted keywords. Stop words are common words like 'the', 'and', 'in', etc., that are often removed to focus on more meaningful keywords. You can specify a list of stop words or 'english' to use a predefined list of English stop words. The default is None, which means no stop words are removed.
#
# 5. `use_mmr`: (bool, optional) If True, the Maximum Marginal Relevance (MMR) algorithm is applied to select a diverse set of keywords. MMR promotes diversity by selecting keywords that are not too similar to each other. The default value is False.
#
# 6. `diversity`: (float, optional) The diversity parameter for MMR. It controls the trade-off between relevance and diversity. A higher value encourages more diverse keywords. It only applies if `use_mmr` is set to True. The default value is 0.7.
#
# 7. `keyphrase_ngram_range`: (tuple, optional) The ngram range for keyphrase extraction. It determines the length of the keyphrases that the model will extract. For example, setting it to `(1, 1)` will extract single words as keyphrases, while `(1, 2)` will extract both single words and two-word phrases as keyphrases. The default value is `(1, 1)

# %% [markdown]
# ### Sample Demo KeyBERT

# %%
sample_text ="""
         Supervised learning is the machine learning task of
         learning a function that maps an input to an output based
         on example input-output pairs.[1] It infers a function
         from labeled training data consisting of a set of
         training examples.[2] In supervised learning, each
         example is a pair consisting of an input object
         (typically a vector) and a desired output value (also
         called the supervisory signal). A supervised learning
         algorithm analyzes the training data and produces an
         inferred function, which can be used for mapping new
         examples. An optimal scenario will allow for the algorithm
         to correctly determine the class labels for unseen
         instances. This requires the learning algorithm to
         generalize from the training data to unseen situations
         in a 'reasonable' way (see inductive bias).
      """


from keybert import KeyBERT
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(sample_text)

# %%
keywords
# Out:
# [('supervised', 0.6523),
#  ('labeled', 0.4702),
#  ('learning', 0.467),
#  ('training', 0.3858),
#  ('labels', 0.3728)]

# %%
keywords = [x[0] for x in keywords]
keywords
# Out:
# ['supervised', 'labeled', 'learning', 'training', 'labels']

# %% [markdown]
# ### Extracting Keywords using KeyBERT from course modules

# %% [markdown]
# #### Step-1: Define a list of parameter values to tune

# %%
ngram_range_values = [(1, 1), (1, 2), (1, 3)]
stop_words_values = [None, "english"]

# %% [markdown]
# #### Step-2: Define a list of model names to tune

# %%
model_names = ['distilbert-base-nli-mean-tokens', 
               'roberta-base-nli-stsb-mean-tokens', 
               'bert-base-nli-mean-tokens']

# %% [markdown]
# The models used in the code are all part of the **Hugging Face Transformers library** and are pre-trained models for various natural language processing (NLP) tasks.These models are designed to generate meaningful sentence embeddings and can be used for various NLP tasks including keyword extraction, document similarity and more.
#
# 1. `distilbert-base-nli-mean-tokens`: This is a distilled version of the **BERT (Bidirectional Encoder Representations from Transformers) model**. It has been trained on various NLP tasks and is fine-tuned to generate sentence embeddings, making it useful for tasks like keyword extraction and semantic similarity.
#
# 2. `roberta-base-nli-stsb-mean-tokens`: This is a **RoBERTa model** which is another variant of the BERT architecture. It has been fine-tuned for the Natural Language Inference (NLI) task and uses sentence embeddings. The "stsb" in the name stands for the **Semantic Textual Similarity Benchmark**.
#
# 3. `bert-base-nli-mean-tokens`: This is a **standard BERT model** that has been fine-tuned for generating sentence embeddings and is suitable for tasks involving semantic similarity and keyword extraction.

# %% [markdown]
# #### Step-3: Create a function for extracting keywords for a specific model and parameters

# %%
def get_keywords_keybert(text, model_name, ngram_range, stop_words):
    """
    Extracts keywords from the given text using the KeyBERT model.

    Parameters:
    - text (str): The input text from which keywords will be extracted.
    - model_name (str): The name of the KeyBERT model to use for keyword extraction.
    - ngram_range (tuple): A tuple specifying the range of n-grams to consider during keyword extraction.
                          Example: (1, 2) for unigrams and bigrams.
    - stop_words (str or list): A list of stop words to be removed from the extracted keywords.
                              It can also be "english" to use a predefined list of English stop words.
                              If None, no stop words are removed.

    Returns:
    - list of str: A list of extracted keywords from the input text.
    """
    model = KeyBERT(model_name)
    keywords_arr = model.extract_keywords(text)
    return [x[0] for x in keywords_arr]

# %% [markdown]
# #### Step-4: Iterate through different models with different parameter combinations

# %%
for model_name in model_names:
    for ngram_range in ngram_range_values:
        for stop_words in stop_words_values:
            column_name = f'keywords_{model_name}_{ngram_range}_{stop_words}'
            
            flatten_df[column_name] = flatten_df['text'].apply(lambda x: get_keywords_keybert(x, 
                                                                                              model_name, 
                                                                                              ngram_range, 
                                                                                              stop_words))

# %% [markdown]
# This code is responsible for iterating through a set of predefined model names, n-gram range values, and stop words values to perform keyword extraction for different combinations of models and keyword extraction parameters. It creates new columns in a DataFrame to store the extracted keywords for each combination.
#
# - The outermost loop iterates through a list of model names (`model_names`). These model names represent different pre-trained models for keyword extraction.
#
# - The first nested loop iterates through a list of n-gram range values (`ngram_range_values`). N-gram range specifies the range of n-grams (e.g., unigrams, bigrams) to consider during keyword extraction.
#
# - The second nested loop iterates through a list of stop words values (`stop_words_values`). Stop words are common words (e.g., "the," "and," "in") that are often removed from extracted keywords to focus on more meaningful terms.
#
# - For each combination of model name, n-gram range and stop words, a unique column name is generated using string formatting. This column name will be used to store the extracted keywords in the DataFrame.
#
# - Inside the innermost loop, the `get_keywords_keybert` function is applied to each row of the DataFrame. This function takes the input text, the current model name, n-gram range and stop words as parameters. It extracts keywords using the specified model and parameters.
#
# - The extracted keywords are then stored in the corresponding column in the DataFrame.

# %%
print('The size of Dataframe is: ', flatten_df.shape)
print('-'*100)
print('The Column Name, Record Count and Data Types are as follows: ')
flatten_df.info()
print('-'*100)
# Out:
# The size of Dataframe is:  (58, 25)
# ----------------------------------------------------------------------------------------------------
# The Column Name, Record Count and Data Types are as follows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   record-duration                                            58 non-null     int64
#  1   record-title                                               58 non-null     object
#  2   record-type                                                58 non-null     object
#  3   record-disabled                                            58 non-null     bool
#  4   meta-title                                                 58 non-null     object
#  5   meta-description                                           58 non-null     object
#  6   text                                                       58 non-null     object
#  7   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None       58 non-null     object
#  8   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english    58 non-null     object
#  9   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None       58 non-null     object
#  10  keywords_distilbert-base-nli-mean-tokens_(1, 2)_english    58 non-null     object
#  11  keywords_distilbert-base-nli-mean-tokens_(1, 3)_None       58 non-null     object
#  12  keywords_distilbert-base-nli-mean-tokens_(1, 3)_english    58 non-null     object
#  13  keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_None     58 non-null     object
#  14  keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_english  58 non-null     object
#  15  keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_None     58 non-null     object
#  16  keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  58 non-null     object
#  17  keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None     58 non-null     object
#  18  keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  58 non-null     object
#  19  keywords_bert-base-nli-mean-tokens_(1, 1)_None             58 non-null     object
#  20  keywords_bert-base-nli-mean-tokens_(1, 1)_english          58 non-null     object
#  21  keywords_bert-base-nli-mean-tokens_(1, 2)_None             58 non-null     object
#  22  keywords_bert-base-nli-mean-tokens_(1, 2)_english          58 non-null     object
#  23  keywords_bert-base-nli-mean-tokens_(1, 3)_None             58 non-null     object
#  24  keywords_bert-base-nli-mean-tokens_(1, 3)_english          58 non-null     object
# dtypes: bool(1), int64(1), object(23)
# memory usage: 11.1+ KB
# ----------------------------------------------------------------------------------------------------

# %%
flatten_df.head()
# Out:
#    record-duration                             record-title record-type  \
# 0            55000                      Course Introduction       video
# 1            69000                      Module introduction       video
# 2           220000                             EL, ELT, ETL       video
# 3           168000                   Quality considerations       video
# 4           180000  How to carry out operations in BigQuery       video
#
#    record-disabled                                     meta-title  \
# 0            False                                   Introduction
# 1            False  Introduction to Building Batch Data Pipelines
# 2            False  Introduction to Building Batch Data Pipelines
# 3            False  Introduction to Building Batch Data Pipelines
# 4            False  Introduction to Building Batch Data Pipelines
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
#
#                                                 text  \
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None  ...  \
# 0                             [introduction, course]    ...
# 1  [pipelines, introduction, batch, building, con...    ...
# 2  [pipelines, introduction, batch, building, con...    ...
# 3  [pipelines, introduction, batch, building, con...    ...
# 4  [pipelines, introduction, batch, building, con...    ...
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_None  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#       keywords_bert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 2)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 2)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 3)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 3)_english
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 5.2) WordWise
#
# WordWise is a Python library designed for keyword extraction and keyphrase generation from text data. This library is particularly useful for tasks such as content summarization, document categorization and information retrieval, where identifying key terms can provide valuable insights.
# However, this library may not have as extensive and customizable parameter options as some other libraries like KeyBERT.
#
# 1. `spacy_model` (str, optional): Specifies the spaCy model to use for text processing. Default is "en_core_web_sm".
#
# 2. `top_k` (int, optional): Determines the number of top keywords to extract. Default is 5.

# %% [markdown]
# ### Sample Demo WordWise

# %%
sample_text ="""
         Supervised learning is the machine learning task of
         learning a function that maps an input to an output based
         on example input-output pairs.[1] It infers a function
         from labeled training data consisting of a set of
         training examples.[2] In supervised learning, each
         example is a pair consisting of an input object
         (typically a vector) and a desired output value (also
         called the supervisory signal). A supervised learning
         algorithm analyzes the training data and produces an
         inferred function, which can be used for mapping new
         examples. An optimal scenario will allow for the algorithm
         to correctly determine the class labels for unseen
         instances. This requires the learning algorithm to
         generalize from the training data to unseen situations
         in a 'reasonable' way (see inductive bias).
      """


from wordwise import Extractor
extractor = Extractor()
extractor.generate(sample_text)
# Out:
# ['supervised learning', 'learning', 'inductive bias', 'labels', 'example']

# %% [markdown]
# ### Extracting Keywords using WordWise from course modules

# %% [markdown]
# #### Creating Function to get keywords using WordWise

# %%
def get_keywords_wordwise(text):
    """
    Extract keywords from the given text using the WordWise library.

    Parameters:
        text (str): The input text from which keywords are to be extracted.

    Returns:
        list: A list of extracted keywords or an empty list if the extraction fails.

    Notes:
        - This function uses the WordWise library to extract keywords from the input text.
        - If the input text is empty or if an error occurs during keyword extraction, an
          empty list is returned.
        - Errors encountered during keyword extraction are printed to the console.

    Example:
        keywords = get_keywords_wordwise("This is a sample text for keyword extraction.")
        print(keywords)  # ['sample text', 'keyword extraction']
    """
    if not text:  # Check if text is empty
        print(f"Empty text encountered: {text}")
        return []  # Return an empty list if text is empty
    extractor = Extractor()
    try:
        return extractor.generate(text)
    except Exception as e:
        print(f"Error processing text: {text}")
        print(f"Error details: {str(e)}")
        return []

# %% [markdown]
# #### Applying Function to the DataFrame

# %%
flatten_df['wordwise_keywords'] = flatten_df['text'].apply(get_keywords_wordwise)
# Out:
# Error processing text: Course Introduction
# Error details: list index out of range
# Error processing text: Course Summary
# Error details: list index out of range
# Error processing text: Building Batch Data Pipelines on Google Cloud
# Error details: list index out of range

# %%
print('The size of Dataframe is: ', flatten_df.shape)
print('-'*100)
print('The Column Name, Record Count and Data Types are as follows: ')
flatten_df.info()
print('-'*100)
# Out:
# The size of Dataframe is:  (58, 26)
# ----------------------------------------------------------------------------------------------------
# The Column Name, Record Count and Data Types are as follows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 26 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   record-duration                                            58 non-null     int64
#  1   record-title                                               58 non-null     object
#  2   record-type                                                58 non-null     object
#  3   record-disabled                                            58 non-null     bool
#  4   meta-title                                                 58 non-null     object
#  5   meta-description                                           58 non-null     object
#  6   text                                                       58 non-null     object
#  7   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None       58 non-null     object
#  8   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english    58 non-null     object
#  9   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None       58 non-null     object
#  10  keywords_distilbert-base-nli-mean-tokens_(1, 2)_english    58 non-null     object
#  11  keywords_distilbert-base-nli-mean-tokens_(1, 3)_None       58 non-null     object
#  12  keywords_distilbert-base-nli-mean-tokens_(1, 3)_english    58 non-null     object
#  13  keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_None     58 non-null     object
#  14  keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_english  58 non-null     object
#  15  keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_None     58 non-null     object
#  16  keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  58 non-null     object
#  17  keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None     58 non-null     object
#  18  keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  58 non-null     object
#  19  keywords_bert-base-nli-mean-tokens_(1, 1)_None             58 non-null     object
#  20  keywords_bert-base-nli-mean-tokens_(1, 1)_english          58 non-null     object
#  21  keywords_bert-base-nli-mean-tokens_(1, 2)_None             58 non-null     object
#  22  keywords_bert-base-nli-mean-tokens_(1, 2)_english          58 non-null     object
#  23  keywords_bert-base-nli-mean-tokens_(1, 3)_None             58 non-null     object
#  24  keywords_bert-base-nli-mean-tokens_(1, 3)_english          58 non-null     object
#  25  wordwise_keywords                                          58 non-null     object
# dtypes: bool(1), int64(1), object(24)
# memory usage: 11.5+ KB
# ----------------------------------------------------------------------------------------------------

# %%
flatten_df.head()
# Out:
#    record-duration                             record-title record-type  \
# 0            55000                      Course Introduction       video
# 1            69000                      Module introduction       video
# 2           220000                             EL, ELT, ETL       video
# 3           168000                   Quality considerations       video
# 4           180000  How to carry out operations in BigQuery       video
#
#    record-disabled                                     meta-title  \
# 0            False                                   Introduction
# 1            False  Introduction to Building Batch Data Pipelines
# 2            False  Introduction to Building Batch Data Pipelines
# 3            False  Introduction to Building Batch Data Pipelines
# 4            False  Introduction to Building Batch Data Pipelines
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
#
#                                                 text  \
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None  ...  \
# 0                             [introduction, course]    ...
# 1  [pipelines, introduction, batch, building, con...    ...
# 2  [pipelines, introduction, batch, building, con...    ...
# 3  [pipelines, introduction, batch, building, con...    ...
# 4  [pipelines, introduction, batch, building, con...    ...
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#       keywords_bert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 2)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 2)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 3)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 3)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#                                    wordwise_keywords
# 0                                                 []
# 1  [quality, data, introduction, considerations, ...
# 2  [quality, data, introduction, considerations, ...
# 3  [quality, data, introduction, considerations, ...
# 4  [quality, data, introduction, considerations, ...
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Reaaranging and Renaming Columns

# %%
index_df = flatten_df.set_index(['meta-title', 'meta-description','record-title'])

# %%
flatten_df.head()
# Out:
#    record-duration                             record-title record-type  \
# 0            55000                      Course Introduction       video
# 1            69000                      Module introduction       video
# 2           220000                             EL, ELT, ETL       video
# 3           168000                   Quality considerations       video
# 4           180000  How to carry out operations in BigQuery       video
#
#    record-disabled                                     meta-title  \
# 0            False                                   Introduction
# 1            False  Introduction to Building Batch Data Pipelines
# 2            False  Introduction to Building Batch Data Pipelines
# 3            False  Introduction to Building Batch Data Pipelines
# 4            False  Introduction to Building Batch Data Pipelines
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
#
#                                                 text  \
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None  ...  \
# 0                             [introduction, course]    ...
# 1  [pipelines, introduction, batch, building, con...    ...
# 2  [pipelines, introduction, batch, building, con...    ...
# 3  [pipelines, introduction, batch, building, con...    ...
# 4  [pipelines, introduction, batch, building, con...    ...
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#       keywords_bert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 2)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 2)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 3)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 3)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#                                    wordwise_keywords
# 0                                                 []
# 1  [quality, data, introduction, considerations, ...
# 2  [quality, data, introduction, considerations, ...
# 3  [quality, data, introduction, considerations, ...
# 4  [quality, data, introduction, considerations, ...
#
# [5 rows x 26 columns]

# %%
print(f'index names ----> {index_df.index.names}')
print('\n')
print(f'column names ----> {index_df.columns}')
# Out:
# index names ----> ['meta-title', 'meta-description', 'record-title']
#
#
# column names ----> Index(['record-duration', 'record-type', 'record-disabled', 'text',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 1)_None',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 1)_english',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 2)_None',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 2)_english',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 3)_None',
#        'keywords_distilbert-base-nli-mean-tokens_(1, 3)_english',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_None',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 1)_english',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_None',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None',
#        'keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english',
#        'keywords_bert-base-nli-mean-tokens_(1, 1)_None',
#        'keywords_bert-base-nli-mean-tokens_(1, 1)_english',
#        'keywords_bert-base-nli-mean-tokens_(1, 2)_None',
#        'keywords_bert-base-nli-mean-tokens_(1, 2)_english',
#        'keywords_bert-base-nli-mean-tokens_(1, 3)_None',
#        'keywords_bert-base-nli-mean-tokens_(1, 3)_english',
#        'wordwise_keywords'],
#       dtype='object')

# %%
index_df.index.names = ['Titles', 'Description', 'Activities']
index_df.rename(columns={'record-duration':'Duration', 'record-type':'Type'}, errors='raise')
# Out:
#                                                                                                                                                           Duration  \
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                    55000
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                    69000
#                                                                                                       EL, ELT, ETL                                          220000
#                                                                                                       Quality considerations                                168000
#                                                                                                       How to carry out operations in BigQuery               180000
#                                                                                                       Shortcomings                                          208000
#                                                                                                       ETL to solve data quality issues                      428000
#                                                                                                       Introduction to Building Batch Data Pipelines              0
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                    27000
#                                                                                                       The Hadoop ecosystem                                  286000
#                                                                                                       Running Hadoop on Dataproc                            602000
#                                                                                                       Cloud Storage instead of HDFS                         379000
#                                                                                                       Optimizing Dataproc                                   172000
#                                                                                                       Optimizing Dataproc storage                           567000
#                                                                                                       Optimizing Dataproc templates and autoscaling         312000
#                                                                                                       Optimizing Dataproc monitoring                        186000
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc       28000
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc          5400000
#                                                                                                       Summary                                                34000
#                                                                                                       Executing Spark on Dataproc                                0
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                    53000
#                                                                                                       Introduction to Dataflow                              342000
#                                                                                                       Why customers value Dataflow                          171000
#                                                                                                       Building Dataflow pipelines in code                   228000
#                                                                                                       Key considerations with designing pipelines           127000
#                                                                                                       Transforming data with PTransforms                    188000
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline         10000
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5              5400000
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...   5400000
#                                                                                                       Aggregate with GroupByKey and Combine                 335000
#                                                                                                       Lab Intro: MapReduce in Beam                           21000
#                                                                                                       MapReduce in Beam (Python) 2.5                       5400000
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...   5400000
#                                                                                                       Side inputs and windows of data                       283000
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs             18000
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...   5400000
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...   5400000
#                                                                                                       Creating and re-using pipeline templates              210000
#                                                                                                       Summary                                               126000
#                                                                                                       Serverless Data Processing with Dataflow                   0
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    19000
#                                                                                                       Introduction to Cloud Data Fusion                     219000
#                                                                                                       Components of Cloud Data Fusion                        74000
#                                                                                                       Cloud Data Fusion UI                                   95000
#                                                                                                       Build a pipeline                                      291000
#                                                                                                       Explore data using wrangler                           108000
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     18000
#                                                                                                       Building and Executing a Pipeline Graph with Da...   9000000
#                                                                                                       Orchestrate work between Google Cloud services ...     64000
#                                                                                                       Apache Airflow environment                             74000
#                                                                                                       DAGs and Operators                                    470000
#                                                                                                       Workflow scheduling                                   335000
#                                                                                                       Monitoring and Logging                                208000
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           22000
#                                                                                                       An Introduction to Cloud Composer 2.5                5400000
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...         0
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                        197000
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud              0
#
#                                                                                                                                                               Type  \
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                    video
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                    video
#                                                                                                       EL, ELT, ETL                                           video
#                                                                                                       Quality considerations                                 video
#                                                                                                       How to carry out operations in BigQuery                video
#                                                                                                       Shortcomings                                           video
#                                                                                                       ETL to solve data quality issues                       video
#                                                                                                       Introduction to Building Batch Data Pipelines           quiz
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                    video
#                                                                                                       The Hadoop ecosystem                                   video
#                                                                                                       Running Hadoop on Dataproc                             video
#                                                                                                       Cloud Storage instead of HDFS                          video
#                                                                                                       Optimizing Dataproc                                    video
#                                                                                                       Optimizing Dataproc storage                            video
#                                                                                                       Optimizing Dataproc templates and autoscaling          video
#                                                                                                       Optimizing Dataproc monitoring                         video
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc       video
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc              lab
#                                                                                                       Summary                                                video
#                                                                                                       Executing Spark on Dataproc                             quiz
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                    video
#                                                                                                       Introduction to Dataflow                               video
#                                                                                                       Why customers value Dataflow                           video
#                                                                                                       Building Dataflow pipelines in code                    video
#                                                                                                       Key considerations with designing pipelines            video
#                                                                                                       Transforming data with PTransforms                     video
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline         video
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5                  lab
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...       lab
#                                                                                                       Aggregate with GroupByKey and Combine                  video
#                                                                                                       Lab Intro: MapReduce in Beam                           video
#                                                                                                       MapReduce in Beam (Python) 2.5                           lab
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...       lab
#                                                                                                       Side inputs and windows of data                        video
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs             video
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...       lab
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...       lab
#                                                                                                       Creating and re-using pipeline templates               video
#                                                                                                       Summary                                                video
#                                                                                                       Serverless Data Processing with Dataflow                quiz
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    video
#                                                                                                       Introduction to Cloud Data Fusion                      video
#                                                                                                       Components of Cloud Data Fusion                        video
#                                                                                                       Cloud Data Fusion UI                                   video
#                                                                                                       Build a pipeline                                       video
#                                                                                                       Explore data using wrangler                            video
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     video
#                                                                                                       Building and Executing a Pipeline Graph with Da...       lab
#                                                                                                       Orchestrate work between Google Cloud services ...     video
#                                                                                                       Apache Airflow environment                             video
#                                                                                                       DAGs and Operators                                     video
#                                                                                                       Workflow scheduling                                    video
#                                                                                                       Monitoring and Logging                                 video
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           video
#                                                                                                       An Introduction to Cloud Composer 2.5                    lab
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...      quiz
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                         video
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud       document
#
#                                                                                                                                                           record-disabled  \
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                           False
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                           False
#                                                                                                       EL, ELT, ETL                                                  False
#                                                                                                       Quality considerations                                        False
#                                                                                                       How to carry out operations in BigQuery                       False
#                                                                                                       Shortcomings                                                  False
#                                                                                                       ETL to solve data quality issues                              False
#                                                                                                       Introduction to Building Batch Data Pipelines                 False
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                           False
#                                                                                                       The Hadoop ecosystem                                          False
#                                                                                                       Running Hadoop on Dataproc                                    False
#                                                                                                       Cloud Storage instead of HDFS                                 False
#                                                                                                       Optimizing Dataproc                                           False
#                                                                                                       Optimizing Dataproc storage                                   False
#                                                                                                       Optimizing Dataproc templates and autoscaling                 False
#                                                                                                       Optimizing Dataproc monitoring                                False
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc              False
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc                   False
#                                                                                                       Summary                                                       False
#                                                                                                       Executing Spark on Dataproc                                   False
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                           False
#                                                                                                       Introduction to Dataflow                                      False
#                                                                                                       Why customers value Dataflow                                  False
#                                                                                                       Building Dataflow pipelines in code                           False
#                                                                                                       Key considerations with designing pipelines                   False
#                                                                                                       Transforming data with PTransforms                            False
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline                False
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5                       False
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...            False
#                                                                                                       Aggregate with GroupByKey and Combine                         False
#                                                                                                       Lab Intro: MapReduce in Beam                                  False
#                                                                                                       MapReduce in Beam (Python) 2.5                                False
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...            False
#                                                                                                       Side inputs and windows of data                               False
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs                    False
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...            False
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...            False
#                                                                                                       Creating and re-using pipeline templates                      False
#                                                                                                       Summary                                                       False
#                                                                                                       Serverless Data Processing with Dataflow                      False
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                           False
#                                                                                                       Introduction to Cloud Data Fusion                             False
#                                                                                                       Components of Cloud Data Fusion                               False
#                                                                                                       Cloud Data Fusion UI                                          False
#                                                                                                       Build a pipeline                                              False
#                                                                                                       Explore data using wrangler                                   False
#                                                                                                       Lab Intro: Building and executing a pipeline gr...            False
#                                                                                                       Building and Executing a Pipeline Graph with Da...            False
#                                                                                                       Orchestrate work between Google Cloud services ...            False
#                                                                                                       Apache Airflow environment                                    False
#                                                                                                       DAGs and Operators                                            False
#                                                                                                       Workflow scheduling                                           False
#                                                                                                       Monitoring and Logging                                        False
#                                                                                                       Lab Intro: An Introduction to Cloud Composer                  False
#                                                                                                       An Introduction to Cloud Composer 2.5                         False
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...            False
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                False
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud                 False
#
#                                                                                                                                                                                                        text  \
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                                               Course Introduction
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                 Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       EL, ELT, ETL                                        Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Quality considerations                              Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       How to carry out operations in BigQuery             Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Shortcomings                                        Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       ETL to solve data quality issues                    Module introduction. EL, ELT, ETL. Quality con...
#                                                                                                       Introduction to Building Batch Data Pipelines       Module introduction. EL, ELT, ETL. Quality con...
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                 Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       The Hadoop ecosystem                                Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Running Hadoop on Dataproc                          Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Cloud Storage instead of HDFS                       Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc                                 Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc storage                         Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc templates and autoscaling       Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Optimizing Dataproc monitoring                      Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc    Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc         Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Summary                                             Module introduction. The Hadoop ecosystem. Run...
#                                                                                                       Executing Spark on Dataproc                         Module introduction. The Hadoop ecosystem. Run...
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                 Module introduction. Introduction to Dataflow....
#                                                                                                       Introduction to Dataflow                            Module introduction. Introduction to Dataflow....
#                                                                                                       Why customers value Dataflow                        Module introduction. Introduction to Dataflow....
#                                                                                                       Building Dataflow pipelines in code                 Module introduction. Introduction to Dataflow....
#                                                                                                       Key considerations with designing pipelines         Module introduction. Introduction to Dataflow....
#                                                                                                       Transforming data with PTransforms                  Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline      Module introduction. Introduction to Dataflow....
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5             Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...  Module introduction. Introduction to Dataflow....
#                                                                                                       Aggregate with GroupByKey and Combine               Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: MapReduce in Beam                        Module introduction. Introduction to Dataflow....
#                                                                                                       MapReduce in Beam (Python) 2.5                      Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...  Module introduction. Introduction to Dataflow....
#                                                                                                       Side inputs and windows of data                     Module introduction. Introduction to Dataflow....
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs          Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  Module introduction. Introduction to Dataflow....
#                                                                                                       Creating and re-using pipeline templates            Module introduction. Introduction to Dataflow....
#                                                                                                       Summary                                             Module introduction. Introduction to Dataflow....
#                                                                                                       Serverless Data Processing with Dataflow            Module introduction. Introduction to Dataflow....
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                 Module introduction. Introduction to Cloud Dat...
#                                                                                                       Introduction to Cloud Data Fusion                   Module introduction. Introduction to Cloud Dat...
#                                                                                                       Components of Cloud Data Fusion                     Module introduction. Introduction to Cloud Dat...
#                                                                                                       Cloud Data Fusion UI                                Module introduction. Introduction to Cloud Dat...
#                                                                                                       Build a pipeline                                    Module introduction. Introduction to Cloud Dat...
#                                                                                                       Explore data using wrangler                         Module introduction. Introduction to Cloud Dat...
#                                                                                                       Lab Intro: Building and executing a pipeline gr...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Building and Executing a Pipeline Graph with Da...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Orchestrate work between Google Cloud services ...  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Apache Airflow environment                          Module introduction. Introduction to Cloud Dat...
#                                                                                                       DAGs and Operators                                  Module introduction. Introduction to Cloud Dat...
#                                                                                                       Workflow scheduling                                 Module introduction. Introduction to Cloud Dat...
#                                                                                                       Monitoring and Logging                              Module introduction. Introduction to Cloud Dat...
#                                                                                                       Lab Intro: An Introduction to Cloud Composer        Module introduction. Introduction to Cloud Dat...
#                                                                                                       An Introduction to Cloud Composer 2.5               Module introduction. Introduction to Cloud Dat...
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...  Module introduction. Introduction to Cloud Dat...
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                                         Course Summary
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud           Building Batch Data Pipelines on Google Cloud
#
#                                                                                                                                                          keywords_distilbert-base-nli-mean-tokens_(1, 1)_None  \
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                                            [introduction, course]
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                 [pipelines, introduction, batch, building, con...
#                                                                                                       EL, ELT, ETL                                        [pipelines, introduction, batch, building, con...
#                                                                                                       Quality considerations                              [pipelines, introduction, batch, building, con...
#                                                                                                       How to carry out operations in BigQuery             [pipelines, introduction, batch, building, con...
#                                                                                                       Shortcomings                                        [pipelines, introduction, batch, building, con...
#                                                                                                       ETL to solve data quality issues                    [pipelines, introduction, batch, building, con...
#                                                                                                       Introduction to Building Batch Data Pipelines       [pipelines, introduction, batch, building, con...
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                   [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       The Hadoop ecosystem                                  [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Running Hadoop on Dataproc                            [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Cloud Storage instead of HDFS                         [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Optimizing Dataproc                                   [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Optimizing Dataproc storage                           [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Optimizing Dataproc templates and autoscaling         [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Optimizing Dataproc monitoring                        [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc      [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc           [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Summary                                               [dataproc, autoscaling, apache, lab, templates]
#                                                                                                       Executing Spark on Dataproc                           [dataproc, autoscaling, apache, lab, templates]
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                         [python, java, dataflow, lab, groupbykey]
#                                                                                                       Introduction to Dataflow                                    [python, java, dataflow, lab, groupbykey]
#                                                                                                       Why customers value Dataflow                                [python, java, dataflow, lab, groupbykey]
# ...
#                                                                                                       Introduction to Cloud Data Fusion                             [google, workflow, logging, lab, graph]
#                                                                                                       Components of Cloud Data Fusion                               [google, workflow, logging, lab, graph]
#                                                                                                       Cloud Data Fusion UI                                          [google, workflow, logging, lab, graph]
#                                                                                                       Build a pipeline                                              [google, workflow, logging, lab, graph]
#                                                                                                       Explore data using wrangler                                   [google, workflow, logging, lab, graph]
#                                                                                                       Lab Intro: Building and executing a pipeline gr...            [google, workflow, logging, lab, graph]
#                                                                                                       Building and Executing a Pipeline Graph with Da...            [google, workflow, logging, lab, graph]
#                                                                                                       Orchestrate work between Google Cloud services ...            [google, workflow, logging, lab, graph]
#                                                                                                       Apache Airflow environment                                    [google, workflow, logging, lab, graph]
#                                                                                                       DAGs and Operators                                            [google, workflow, logging, lab, graph]
#                                                                                                       Workflow scheduling                                           [google, workflow, logging, lab, graph]
#                                                                                                       Monitoring and Logging                                        [google, workflow, logging, lab, graph]
#                                                                                                       Lab Intro: An Introduction to Cloud Composer                  [google, workflow, logging, lab, graph]
#                                                                                                       An Introduction to Cloud Composer 2.5                         [google, workflow, logging, lab, graph]
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...            [google, workflow, logging, lab, graph]
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                                      [summary, course]
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud              [google, data, pipelines, batch, building]
#
#                                                                                                                                                                                           wordwise_keywords
# Titles                                             Description                                        Activities
# Introduction                                       <p>In this module, we introduce the course and ... Course Introduction                                                                                []
# Introduction to Building Batch Data Pipelines      <p>This module reviews different methods of dat... Module introduction                                 [quality, data, introduction, considerations, ...
#                                                                                                       EL, ELT, ETL                                        [quality, data, introduction, considerations, ...
#                                                                                                       Quality considerations                              [quality, data, introduction, considerations, ...
#                                                                                                       How to carry out operations in BigQuery             [quality, data, introduction, considerations, ...
#                                                                                                       Shortcomings                                        [quality, data, introduction, considerations, ...
#                                                                                                       ETL to solve data quality issues                    [quality, data, introduction, considerations, ...
#                                                                                                       Introduction to Building Batch Data Pipelines       [quality, data, introduction, considerations, ...
# Executing Spark on Dataproc                        <p>This module shows how to run Hadoop on Datap... Module introduction                                 [introduction, templates, storage, jobs, monit...
#                                                                                                       The Hadoop ecosystem                                [introduction, templates, storage, jobs, monit...
#                                                                                                       Running Hadoop on Dataproc                          [introduction, templates, storage, jobs, monit...
#                                                                                                       Cloud Storage instead of HDFS                       [introduction, templates, storage, jobs, monit...
#                                                                                                       Optimizing Dataproc                                 [introduction, templates, storage, jobs, monit...
#                                                                                                       Optimizing Dataproc storage                         [introduction, templates, storage, jobs, monit...
#                                                                                                       Optimizing Dataproc templates and autoscaling       [introduction, templates, storage, jobs, monit...
#                                                                                                       Optimizing Dataproc monitoring                      [introduction, templates, storage, jobs, monit...
#                                                                                                       Lab Intro: Running Apache Spark jobs on Dataproc    [introduction, templates, storage, jobs, monit...
#                                                                                                       Running Apache Spark jobs on Cloud Dataproc         [introduction, templates, storage, jobs, monit...
#                                                                                                       Summary                                             [introduction, templates, storage, jobs, monit...
#                                                                                                       Executing Spark on Dataproc                         [introduction, templates, storage, jobs, monit...
# Serverless Data Processing with Dataflow           <p>This module covers using Dataflow to build y... Module introduction                                 [pipelines, data, introduction, templates, pip...
#                                                                                                       Introduction to Dataflow                            [pipelines, data, introduction, templates, pip...
#                                                                                                       Why customers value Dataflow                        [pipelines, data, introduction, templates, pip...
#                                                                                                       Building Dataflow pipelines in code                 [pipelines, data, introduction, templates, pip...
#                                                                                                       Key considerations with designing pipelines         [pipelines, data, introduction, templates, pip...
#                                                                                                       Transforming data with PTransforms                  [pipelines, data, introduction, templates, pip...
#                                                                                                       Lab Intro: Building a Simple Dataflow Pipeline      [pipelines, data, introduction, templates, pip...
#                                                                                                       A Simple Dataflow Pipeline (Python) 2.5             [pipelines, data, introduction, templates, pip...
#                                                                                                       Serverless Data Analysis with Dataflow: A Simpl...  [pipelines, data, introduction, templates, pip...
#                                                                                                       Aggregate with GroupByKey and Combine               [pipelines, data, introduction, templates, pip...
#                                                                                                       Lab Intro: MapReduce in Beam                        [pipelines, data, introduction, templates, pip...
#                                                                                                       MapReduce in Beam (Python) 2.5                      [pipelines, data, introduction, templates, pip...
#                                                                                                       Serverless Data Analysis with Beam: MapReduce i...  [pipelines, data, introduction, templates, pip...
#                                                                                                       Side inputs and windows of data                     [pipelines, data, introduction, templates, pip...
#                                                                                                       Lab Intro: Practicing Pipeline Side Inputs          [pipelines, data, introduction, templates, pip...
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  [pipelines, data, introduction, templates, pip...
#                                                                                                       Serverless Data Analysis with Dataflow: Side In...  [pipelines, data, introduction, templates, pip...
#                                                                                                       Creating and re-using pipeline templates            [pipelines, data, introduction, templates, pip...
#                                                                                                       Summary                                             [pipelines, data, introduction, templates, pip...
#                                                                                                       Serverless Data Processing with Dataflow            [pipelines, data, introduction, templates, pip...
# Manage Data Pipelines with Cloud Data Fusion an... <p>This module shows how to manage data pipelin... Module introduction                                    [introduction, data, services, wrangler, work]
#                                                                                                       Introduction to Cloud Data Fusion                      [introduction, data, services, wrangler, work]
#                                                                                                       Components of Cloud Data Fusion                        [introduction, data, services, wrangler, work]
#                                                                                                       Cloud Data Fusion UI                                   [introduction, data, services, wrangler, work]
#                                                                                                       Build a pipeline                                       [introduction, data, services, wrangler, work]
#                                                                                                       Explore data using wrangler                            [introduction, data, services, wrangler, work]
#                                                                                                       Lab Intro: Building and executing a pipeline gr...     [introduction, data, services, wrangler, work]
#                                                                                                       Building and Executing a Pipeline Graph with Da...     [introduction, data, services, wrangler, work]
#                                                                                                       Orchestrate work between Google Cloud services ...     [introduction, data, services, wrangler, work]
#                                                                                                       Apache Airflow environment                             [introduction, data, services, wrangler, work]
#                                                                                                       DAGs and Operators                                     [introduction, data, services, wrangler, work]
#                                                                                                       Workflow scheduling                                    [introduction, data, services, wrangler, work]
#                                                                                                       Monitoring and Logging                                 [introduction, data, services, wrangler, work]
#                                                                                                       Lab Intro: An Introduction to Cloud Composer           [introduction, data, services, wrangler, work]
#                                                                                                       An Introduction to Cloud Composer 2.5                  [introduction, data, services, wrangler, work]
#                                                                                                       Manage Data Pipelines with Cloud Data Fusion an...     [introduction, data, services, wrangler, work]
# Course Summary                                     <p>Course Summary</p>                              Course Summary                                                                                     []
# Course Resources                                   <p>PDF links to all modules</p>                    Building Batch Data Pipelines on Google Cloud                                                      []
#
# [58 rows x 23 columns]

# %%
flatten_df.head()
# Out:
#    record-duration                             record-title record-type  \
# 0            55000                      Course Introduction       video
# 1            69000                      Module introduction       video
# 2           220000                             EL, ELT, ETL       video
# 3           168000                   Quality considerations       video
# 4           180000  How to carry out operations in BigQuery       video
#
#    record-disabled                                     meta-title  \
# 0            False                                   Introduction
# 1            False  Introduction to Building Batch Data Pipelines
# 2            False  Introduction to Building Batch Data Pipelines
# 3            False  Introduction to Building Batch Data Pipelines
# 4            False  Introduction to Building Batch Data Pipelines
#
#                                     meta-description  \
# 0  <p>In this module, we introduce the course and...
# 1  <p>This module reviews different methods of da...
# 2  <p>This module reviews different methods of da...
# 3  <p>This module reviews different methods of da...
# 4  <p>This module reviews different methods of da...
#
#                                                 text  \
# 0                                Course Introduction
# 1  Module introduction. EL, ELT, ETL. Quality con...
# 2  Module introduction. EL, ELT, ETL. Quality con...
# 3  Module introduction. EL, ELT, ETL. Quality con...
# 4  Module introduction. EL, ELT, ETL. Quality con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [pipelines, introduction, batch, building, con...
# 2  [pipelines, introduction, batch, building, con...
# 3  [pipelines, introduction, batch, building, con...
# 4  [pipelines, introduction, batch, building, con...
#
#   keywords_distilbert-base-nli-mean-tokens_(1, 2)_None  ...  \
# 0                             [introduction, course]    ...
# 1  [pipelines, introduction, batch, building, con...    ...
# 2  [pipelines, introduction, batch, building, con...    ...
# 3  [pipelines, introduction, batch, building, con...    ...
# 4  [pipelines, introduction, batch, building, con...    ...
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 2)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_None  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#   keywords_roberta-base-nli-stsb-mean-tokens_(1, 3)_english  \
# 0                             [course, introduction]
# 1          [introduction, etl, module, quality, elt]
# 2          [introduction, etl, module, quality, elt]
# 3          [introduction, etl, module, quality, elt]
# 4          [introduction, etl, module, quality, elt]
#
#       keywords_bert-base-nli-mean-tokens_(1, 1)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 1)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 2)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 2)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#       keywords_bert-base-nli-mean-tokens_(1, 3)_None  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#    keywords_bert-base-nli-mean-tokens_(1, 3)_english  \
# 0                             [introduction, course]
# 1  [introduction, data, pipelines, building, bigq...
# 2  [introduction, data, pipelines, building, bigq...
# 3  [introduction, data, pipelines, building, bigq...
# 4  [introduction, data, pipelines, building, bigq...
#
#                                    wordwise_keywords
# 0                                                 []
# 1  [quality, data, introduction, considerations, ...
# 2  [quality, data, introduction, considerations, ...
# 3  [quality, data, introduction, considerations, ...
# 4  [quality, data, introduction, considerations, ...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 6) Exporting Keyword Extracted Output as Excel File
# ---

# %%
with pd.ExcelWriter('Keyword_Extraction_Comparison.xlsx', engine='xlsxwriter') as writer:
    index_df.to_excel(writer, sheet_name="Keyword_Extraction_Comparison")

# %% [markdown]
# **`Note:`** Information, when saved as a CSV (Comma Separated Values) file, may lose certain formatting or structural details, depending on the complexity of the data. CSV files are primarily used for storing tabular data and may not preserve specialized data types, hierarchical structures, or formatting elements found in the original data.

# %% [markdown]
# **No Significant change found in Keyword Extraction with different model and parameter tunning**
